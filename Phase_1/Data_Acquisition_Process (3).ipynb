# %% [markdown]
# # Getting Your Data From Yelp!

# %% [markdown]
# ## Part 2 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %% [markdown]
# - Write a function to make a call to the yelp API

# %%
import pandas as pd
import requests
import json
url = 'https://api.yelp.com/v3/businesses/search'
api_key = "S3cROVIGs17gTiCO6iy8-2ycbL999zhz84ANxStc2mYNESu0cKfM4qdarKNZ69t-2bnTPSR_RRTTCTKmpQidQYhD1mpVN1zvyo0EGTVthI7SVumcOA3IZrRgj5omYHYx"
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }
# what type of business do you want to search
term = 'Thai'
term2 = 'Mexican'
#where do you want to perform this search
location = 'NYC'

# what is your other parameter you want to search against
categories = 'restaurants'
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50,
                "offset": None
    
            }
url_params2 = {
                "term": term2.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50,
    
            }

# %%
def yelp_call(url_params):
    
    response = requests.get(url, headers=headers, params=url_params)
    return response.json()['businesses']

# %% [markdown]
# - Write a function to parse the API response so that you can easily insert the data in to the DB

# %%
def parse_results(list_of_data):
    # create a container to hold our parsed data
    biz_list = []
    # loop through our business and 
    for business in list_of_data:
    # parse each individual business into a tuple
    
    #parseing out transactions
    if 'pickup'in business['transactions']:
        pickup = True
        
    #checking if price is there
    if 'price' not in business:
        business['price'] = np.nan
        
        try:
            biz_tuple = (business['id'],
                     business['name'],
                     business['location']['address1'],
                     business['rating'],
                     business['price'],
                     business['location']['zip_code'],
                     business['transactions'],
                     business['review_count'],
                     business['categories'])   
    # add each individual business tuple to our data container
            biz_list.append(biz_tuple)
        except:
            continue
    # return the container with all of the parsed results
    return biz_list

# %% [markdown]
# - Write a function to take your parsed data and add it to the csv file where you will store all of your results.

# %%
thai_df = pd.DataFrame(parsed_thai, columns = ['Id','Name', 'Location', 'Rating', 'Price', 'Zipcode', 'Transactions', 'Review Count', 'Categories'])

# %%
mex_df = pd.DataFrame(parsed_mex, columns = ['Id','Name', 'Location', 'Rating', 'Price', 'Zipcode', 'Transactions', 'Review Count', 'Categories'])

# %%
def df_save(csv_file_path, parsed_results):
    # your code to open the csv file, concat the current data, and save the data. 
    business_df = pd.DataFrame(parsed_results, columns = ['Id','Name', 'Location', 'Rating', 'Price', 'Zipcode', 'Transactions', 'Review Count', 'Categories'])
    business_df.to_csv(csv_file_path, mode = 'a')
    new_df = pd.read_csv(csv_file_path, delimiter = ",")
    return new_df.shape
#     pd.DataFrame(parsed_results).to_csv()

# %%
thai_csv = df_save('thai_csv', parsed_thai)

# %%
mex_csv = df_save('mex_csv', parsed_mex)

# %% [markdown]
# - Write a script that combines the three functions above into a single process.

# %% [markdown]
# While it will take some experimentation to write the functions above, once you get them working it will be best to put them in a `.py` file and then import the functions to use in a script

# %%
url_params['offset'] = 0

# %%
url_params
# Out:
# {'term': 'Thai',
#  'location': 'NYC',
#  'categories': 'restaurants',
#  'limit': 50,
#  'offset': 0}

# %%
yelp_call(url_params)
# Out:
# [{'id': '9WgsvzaiXNAmmQGD0uQxFQ',
#   'alias': 'thai-holic-brooklyn',
#   'name': 'Thai Holic',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iUqXan4GX7zWw8U7agjZBQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-holic-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 455,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.693005, 'longitude': -73.971286},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '372 Myrtle Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['372 Myrtle Ave', 'Brooklyn, NY 11205']},
#   'phone': '+17182229992',
#   'display_phone': '(718) 222-9992',
#   'distance': 2383.5456137420542},
#  {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#   'alias': 'thai-villa-new-york-2',
#   'name': 'Thai Villa',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oELHjgVFiisZdXpn91cd5A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 3549,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73902, 'longitude': -73.99065},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5 E 19th St',
#    'address2': 'G Floor',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003']},
#   'phone': '+12128029999',
#   'display_phone': '(212) 802-9999',
#   'distance': 3744.570399827637},
#  {'id': 'f_a1oO8-y2qorh_-K8xWHw',
#   'alias': 'thai-farm-kitchen-seaport-new-york',
#   'name': 'Thai Farm Kitchen Seaport',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xRN_veYjK9TmF5B1rA7pQA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-farm-kitchen-seaport-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 67,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70824, 'longitude': -74.0017},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'location': {'address1': '21 Peck Slip',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['21 Peck Slip', 'New York, NY 10038']},
#   'phone': '+12123494433',
#   'display_phone': '(212) 349-4433',
#   'distance': 697.4169959225349},
#  {'id': 'jjJc_CrkB2HodEinB6cWww',
#   'alias': 'lovemama-new-york',
#   'name': 'LoveMama',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 5198,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'malaysian', 'title': 'Malaysian'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.730408722512074,
#    'longitude': -73.98612673033213},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '174 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#   'phone': '+12122545370',
#   'display_phone': '(212) 254-5370',
#   'distance': 2859.902795118878},
#  {'id': 'wGFSTTB6b4MHJJUzBnVJeg',
#   'alias': 'top-thai-greenwich-new-york',
#   'name': 'Top Thai Greenwich',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4xK8iIj2rZrRvP9MMG7yOA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/top-thai-greenwich-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 1536,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'halal', 'title': 'Halal'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.729771, 'longitude': -73.999392},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '235 Sullivan St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Sullivan St', 'New York, NY 10012']},
#   'phone': '+16467264418',
#   'display_phone': '(646) 726-4418',
#   'distance': 2739.489773141031},
#  {'id': '-OixbLnFLCzQclxCSbUQ8w',
#   'alias': 'up-thai-new-york',
#   'name': 'Up Thai',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i4TPZkTUWJn8aljC0UeU9Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/up-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 2382,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7698275926665,
#    'longitude': -73.9576330868512},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1411 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10021',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1411 2nd Ave', 'New York, NY 10021']},
#   'phone': '+12122561188',
#   'display_phone': '(212) 256-1188',
#   'distance': 7796.9126757590075},
#  {'id': 'feY7PgoRjCp2qReaIitRkQ',
#   'alias': 'boran-brooklyn-2',
#   'name': 'Boran',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DKm6I7QA_JNaEkwCUOgWyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boran-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 179,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6782327, 'longitude': -73.998062},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '462 Court St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['462 Court St', 'Brooklyn, NY 11231']},
#   'phone': '+17184900207',
#   'display_phone': '(718) 490-0207',
#   'distance': 3042.489267250247},
#  {'id': '-XYp6w50XbZfS90YddS5ew',
#   'alias': 'soothr-new-york-2',
#   'name': 'Soothr',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Kg74WVsVfMB-2eG0I_QAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/soothr-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 108,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.732318, 'longitude': -73.9873417},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '204 E 13th St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['204 E 13th St', 'New York, NY 10003']},
#   'phone': '+12128449789',
#   'display_phone': '(212) 844-9789',
#   'distance': 3045.0417633367397},
#  {'id': 'qrydcGQpeDP_1oFvx3qOeg',
#   'alias': 'somtum-der-new-york',
#   'name': 'Somtum Der',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85AftnoxLOq0T0HKHPSdgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 753,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7252151982238,
#    'longitude': -73.9842741682317},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '85 Ave A',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['85 Ave A', 'New York, NY 10009']},
#   'phone': '+12122608570',
#   'display_phone': '(212) 260-8570',
#   'distance': 2354.956408341586},
#  {'id': 'MhceeLrM2_3mcKw5EGLY6A',
#   'alias': 'pure-thai-cookhouse-new-york',
#   'name': 'Pure Thai Cookhouse',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QFYS-7MPGlOjUUy_2TkwLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pure-thai-cookhouse-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 2566,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.764291, 'longitude': -73.988159},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '766 9th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['766 9th Ave', 'New York, NY 10019']},
#   'phone': '+12125810999',
#   'display_phone': '(212) 581-0999',
#   'distance': 6563.765009094688},
#  {'id': 'l_gQf_4NgPMJcx2OkjsMfg',
#   'alias': 'noods-n-chill-brooklyn',
#   'name': 'Noods n’ Chill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aEbw8f72-M1la2L-ONR2pg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noods-n-chill-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 77,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71194, 'longitude': -73.96121},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '170 S 3rd St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['170 S 3rd St', 'Brooklyn, NY 11211']},
#   'phone': '+17183887695',
#   'display_phone': '(718) 388-7695',
#   'distance': 2874.5347935406644},
#  {'id': 'XgiG7K7ubHsj2JJ-c2sXnw',
#   'alias': 'thai-diner-new-york',
#   'name': 'Thai Diner',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sABqmLTN1es_i4Ugu4DkpQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-diner-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 110,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.720714, 'longitude': -73.9956057},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '186 Mott St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['186 Mott St', 'New York, NY 10012']},
#   'phone': '+16465594140',
#   'display_phone': '(646) 559-4140',
#   'distance': 1701.4484352726947},
#  {'id': 'liGIz8CzhyS1udx1aefjng',
#   'alias': 'williamsburg-thai-cuisine-brooklyn',
#   'name': 'Williamsburg Thai Cuisine',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rb4WdnfScKrktF0O_ZWqqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/williamsburg-thai-cuisine-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 238,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71699, 'longitude': -73.9588799},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '212 Bedford Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['212 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+19293377651',
#   'display_phone': '(929) 337-7651',
#   'distance': 3250.468442566167},
#  {'id': 'No1PU4NbOdoaG1lSikfeNg',
#   'alias': '7-elephants-new-york',
#   'name': '7 Elephants',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RylEgFXmusdxb6sLLrxvBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/7-elephants-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 11,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.714099, 'longitude': -73.986987},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '221 East Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['221 East Broadway', 'New York, NY 10002']},
#   'phone': '+16467527940',
#   'display_phone': '(646) 752-7940',
#   'distance': 1142.856596202019},
#  {'id': 'RrPIJvmje1qb9iaYd6jH0g',
#   'alias': 'pinto-restaurant-brooklyn-heights-2',
#   'name': 'Pinto Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QzRfSeXdqIx4y7Vbov9vHg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pinto-restaurant-brooklyn-heights-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 220,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6947735368336,
#    'longitude': -73.9943484261754},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '128 Montague St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn Heights',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['128 Montague St', 'Brooklyn Heights, NY 11201']},
#   'phone': '+19293377732',
#   'display_phone': '(929) 337-7732',
#   'distance': 1186.6053037950712},
#  {'id': 'VoAuIReq_cPUrFwxbWqG_Q',
#   'alias': 'salathai-restaurant-new-york',
#   'name': 'SalaThai Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rY-GxvSeet0K4kPzB44gXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/salathai-restaurant-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 401,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7801199, 'longitude': -73.98032},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '307 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10023',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['307 Amsterdam Ave', 'New York, NY 10023']},
#   'phone': '+12124333999',
#   'display_phone': '(212) 433-3999',
#   'distance': 8383.821131514791},
#  {'id': '0IFDnYf3bhqxJR6hVrG7Gw',
#   'alias': 'top-thai-55-carmine-new-york-2',
#   'name': 'Top Thai 55 - Carmine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-ZoEVVSfXiLLw8NLKSF9BA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/top-thai-55-carmine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 381,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'halal', 'title': 'Halal'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.729967, 'longitude': -74.004229},
#   'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '55 Carmine St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 Carmine St', 'New York, NY 10014']},
#   'phone': '+16466092272',
#   'display_phone': '(646) 609-2272',
#   'distance': 2850.6467662416635},
#  {'id': '5ZjNZd3Yg0jOkJ9WRx1r6g',
#   'alias': 'kor-tor-mor-brooklyn',
#   'name': 'Kor Tor Mor',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g8vp1MFooFU7-mUZbnjOAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kor-tor-mor-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 260,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6846634, 'longitude': -73.9918633},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '204 Smith St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['204 Smith St', 'Brooklyn, NY 11201']},
#   'phone': '+17187975100',
#   'display_phone': '(718) 797-5100',
#   'distance': 2319.8537216888553},
#  {'id': '0L03onqNwxWLrbb_FCK79A',
#   'alias': 'sripraphai-thai-restaurant-woodside',
#   'name': 'SriPraPhai Thai Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 2380,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '64-13 39th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Woodside',
#    'zip_code': '11377',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#   'phone': '+17188999599',
#   'display_phone': '(718) 899-9599',
#   'distance': 9219.94935152076},
#  {'id': 'AkoNWXRhZWyJInoWI1AaZw',
#   'alias': 'pad-thai-kitchen-brooklyn',
#   'name': 'Pad Thai Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PXIRNktDhsZAxP0oppcYYQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pad-thai-kitchen-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 42,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.620614, 'longitude': -73.989027},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '6218 18th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11204',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6218 18th Ave', 'Brooklyn, NY 11204']},
#   'phone': '+17184840156',
#   'display_phone': '(718) 484-0156',
#   'distance': 9442.140183514946},
#  {'id': 'WJS06XxRdc6DD1s4LWE9HA',
#   'alias': 'fish-cheeks-new-york',
#   'name': 'Fish Cheeks',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 720,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7258, 'longitude': -73.9927},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '55 Bond St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['55 Bond St', 'New York, NY 10012']},
#   'phone': '+12126772223',
#   'display_phone': '(212) 677-2223',
#   'distance': 2258.7720584764224},
#  {'id': 'p2sAfaFyfFj9nYPyqcmQdw',
#   'alias': 'thai-sidewalk-brooklyn-5',
#   'name': 'Thai Sidewalk',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8VY5opp0KuYAekshjrEl1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-sidewalk-brooklyn-5?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 40,
#   'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7024794, 'longitude': -73.9885649},
#   'transactions': [],
#   'location': {'address1': 'Adams St And Front St',
#    'address2': None,
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['Adams St And Front St', 'Brooklyn, NY 11201']},
#   'phone': '+16466418333',
#   'display_phone': '(646) 641-8333',
#   'distance': 583.9836845783237},
#  {'id': '0GftSP2dRwEzujkv2VKIgA',
#   'alias': 'wok-wok-southeast-asian-kitchen-new-york',
#   'name': 'Wok Wok Southeast Asian Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XOc7n_rq6kYGXySwasouRQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wok-wok-southeast-asian-kitchen-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 995,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'malaysian', 'title': 'Malaysian'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7140555, 'longitude': -73.9988387116394},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '11 Mott St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['11 Mott St', 'New York, NY 10013']},
#   'phone': '+19173883627',
#   'display_phone': '(917) 388-3627',
#   'distance': 1031.2690925773445},
#  {'id': 'O1fUmxt3kbV-rnyjBtzAfw',
#   'alias': 'thep-thai-restaurant-new-york-5',
#   'name': 'THEP Thai Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MKCdkV2v209he52ImIOSeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thep-thai-restaurant-new-york-5?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 1339,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.77078, 'longitude': -73.95727},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1439 2nd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10021',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1439 2nd Ave', 'New York, NY 10021']},
#   'phone': '+12128999995',
#   'display_phone': '(212) 899-9995',
#   'distance': 7904.787644740089},
#  {'id': 'xRvMOTMzDrMfyAWbYhkA8A',
#   'alias': 'terra-thai-new-york',
#   'name': 'Terra Thai',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fQoIcwFwbbUOwx0VT-GS3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/terra-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 29,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.724896, 'longitude': -73.983031},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '518 E 6th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['518 E 6th St', 'New York, NY 10009']},
#   'phone': '+16464787415',
#   'display_phone': '(646) 478-7415',
#   'distance': 2361.9100123091093},
#  {'id': 'liZmIO0FqZwslLJfLDkfgw',
#   'alias': 'wayla-new-york',
#   'name': 'Wayla',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Se9IRHfGW8z9-292HJyKsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wayla-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 299,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7183, 'longitude': -73.9926038},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '100 Forsyth St',
#    'address2': 'Basement',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['100 Forsyth St', 'Basement', 'New York, NY 10002']},
#   'phone': '+12122062500',
#   'display_phone': '(212) 206-2500',
#   'distance': 1436.4990587768912},
#  {'id': 'mpD_kUFo8POQDLoLgRSfCg',
#   'alias': 'sage-brooklyn',
#   'name': 'SAGE',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8_3u0uJLvInOMgqwuUN8YQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sage-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 607,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7129736, 'longitude': -73.9442765},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '299-301 Graham Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['299-301 Graham Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17182186644',
#   'display_phone': '(718) 218-6644',
#   'distance': 4298.170607587344},
#  {'id': '1sEr-BDi2LD6HH6K960pfQ',
#   'alias': 'ace-thai-kitchen-brooklyn-3',
#   'name': 'ACE Thai Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DDDufVScz4Ae3wjz_i0e1g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ace-thai-kitchen-brooklyn-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 102,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.69315, 'longitude': -73.97328},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '330 Myrtle Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['330 Myrtle Ave', 'Brooklyn, NY 11205']},
#   'phone': '+13479874100',
#   'display_phone': '(347) 987-4100',
#   'distance': 2240.064612841999},
#  {'id': 'StFf9fVnAlhwrUWan0C4Ww',
#   'alias': 'wanisa-home-kitchen-brooklyn',
#   'name': 'Wanisa Home Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/azd794dZJoROs5zyEizhrA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wanisa-home-kitchen-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 145,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.687, 'longitude': -73.99042},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '142 Smith St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['142 Smith St', 'Brooklyn, NY 11201']},
#   'phone': '+17185223027',
#   'display_phone': '(718) 522-3027',
#   'distance': 2074.755884968529},
#  {'id': 'UC3n_0vZ5zI1fvi7UzNZAg',
#   'alias': 'sabai-thai-restaurant-new-york-3',
#   'name': 'Sabai Thai Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n7zcZ-9Z_m1zWtQO50y9Iw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sabai-thai-restaurant-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 291,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.74422, 'longitude': -73.98365},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '432 Park Ave S',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10016',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['432 Park Ave S', 'New York, NY 10016']},
#   'phone': '+16464764521',
#   'display_phone': '(646) 476-4521',
#   'distance': 4412.21786588836},
#  {'id': 'hSiTqxKKgvQSI5x5VdMjoQ',
#   'alias': 'top-thai-brooklyn-brooklyn',
#   'name': 'Top Thai - Brooklyn',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XDqz5GxZC5X-msp2l4Cx3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/top-thai-brooklyn-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 310,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.62325, 'longitude': -74.02838},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8510 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8510 4th Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17183335811',
#   'display_phone': '(718) 333-5811',
#   'distance': 9578.460130007345},
#  {'id': 'pSSajdYNKTyAGV8-fk7fWQ',
#   'alias': 'joya-brooklyn',
#   'name': 'Joya',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X4HbR16EFVcywHtrW7BPqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joya-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 1321,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.686672, 'longitude': -73.993544},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '215 Court St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['215 Court St', 'Brooklyn, NY 11201']},
#   'phone': '+17182223484',
#   'display_phone': '(718) 222-3484',
#   'distance': 2087.041238313192},
#  {'id': 'I4FWrwXDC91lsfQLXYSeXA',
#   'alias': 'malii-new-york',
#   'name': 'Malii',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gdozp_PB-IovNYjpkMLjyA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/malii-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 283,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.789432, 'longitude': -73.942962},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2028 2nd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10029',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['2028 2nd Ave', 'New York, NY 10029']},
#   'phone': '+12122892729',
#   'display_phone': '(212) 289-2729',
#   'distance': 10291.839523057411},
#  {'id': 'ZQHZAvw1jvNznbo1wFb_4w',
#   'alias': 'bay-thai-brooklyn-4',
#   'name': 'Bay Thai',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KNIE3kWO8r2ON-lHQEBXYg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bay-thai-brooklyn-4?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 144,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.63688, 'longitude': -74.02526},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6735 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11220',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6735 3rd Ave', 'Brooklyn, NY 11220']},
#   'phone': '+16462605964',
#   'display_phone': '(646) 260-5964',
#   'distance': 8057.177592598429},
#  {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#   'alias': 'pye-boat-noodle-astoria',
#   'name': 'Pye Boat Noodle',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 838,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '35-13 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Astoria',
#    'zip_code': '11106',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#   'phone': '+17186852329',
#   'display_phone': '(718) 685-2329',
#   'distance': 8656.427099874069},
#  {'id': 'IdHZfmpp8MmQ4_KZL2qXbg',
#   'alias': 'makiinny-new-york-3',
#   'name': 'MAKIINNY',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k49zoEEai5yB9_D_0tnaSw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/makiinny-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 60,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72831, 'longitude': -73.98914},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '32 E7th St',
#    'address2': 'Front 2',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 E7th St', 'Front 2', 'New York, NY 10003']},
#   'phone': '+12126734610',
#   'display_phone': '(212) 673-4610',
#   'distance': 2566.784676576643},
#  {'id': 'tx-gxkns4uFyve7Eu5mYKA',
#   'alias': 'tana-thai-bronx',
#   'name': 'Tana Thai',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FWqfkWekjDyGFV-xn4qcHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tana-thai-bronx?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 199,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.8513635, 'longitude': -73.8439993},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1890 Eastchester Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Bronx',
#    'zip_code': '10461',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1890 Eastchester Rd', 'Bronx, NY 10461']},
#   'phone': '+17186841900',
#   'display_phone': '(718) 684-1900',
#   'distance': 20591.422965460595},
#  {'id': 'RdGWCbcxA79G1ZMPVL3SGQ',
#   'alias': 'nora-thai-brooklyn-4',
#   'name': 'Nora Thai',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pKgSo4nNsd0-FiRAvahoXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nora-thai-brooklyn-4?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 82,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71864, 'longitude': -73.95625},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '176 N 9th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['176 N 9th St', 'Brooklyn, NY 11211']},
#   'phone': '+17183021499',
#   'display_phone': '(718) 302-1499',
#   'distance': 3511.550118914059},
#  {'id': 'p2zm0HnXZkI2yCAuYLb45g',
#   'alias': 'thai-market-new-york',
#   'name': 'Thai Market',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jPGJaYsRiU_se_UJzphxkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-market-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 1014,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.80132, 'longitude': -73.96529},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '960 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10025',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['960 Amsterdam Ave', 'New York, NY 10025']},
#   'phone': '+12122804575',
#   'display_phone': '(212) 280-4575',
#   'distance': 10940.010065176182},
#  {'id': 'SBy46BviyBKowPjbTjDsHQ',
#   'alias': 'lantern-brooklyn',
#   'name': 'Lantern',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YwkmxTrk3iZOELiCLfwecA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lantern-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 467,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.69533, 'longitude': -73.99544},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '101 Montague St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['101 Montague St', 'Brooklyn, NY 11201']},
#   'phone': '+17182372594',
#   'display_phone': '(718) 237-2594',
#   'distance': 1132.8854453675879},
#  {'id': 'Nvhx093-K2xwHIZVnFstJw',
#   'alias': 'copper-throat-thai-cuisine-new-york',
#   'name': 'Copper Throat Thai Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kU4KGhCSqEKP43D20XoZuA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/copper-throat-thai-cuisine-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 117,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71978, 'longitude': -73.98877},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '123 Ludlow St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['123 Ludlow St', 'New York, NY 10002']},
#   'phone': '+19172617891',
#   'display_phone': '(917) 261-7891',
#   'distance': 1664.2227246686566},
#  {'id': 'dVR5KHPMZoU9rQvxhY5Otw',
#   'alias': 'thai-terminal-new-york-2',
#   'name': 'Thai Terminal',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pYpcqmmsmWS_wX2qOUEzVA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-terminal-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 570,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73039, 'longitude': -73.98381},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '349 E 12th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['349 E 12th St', 'New York, NY 10003']},
#   'phone': '+12126140155',
#   'display_phone': '(212) 614-0155',
#   'distance': 2909.1995849569603},
#  {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#   'alias': 'kind-fresh-meadows',
#   'name': "Kin'd",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ajh9pCuYLNiVdoBY9ZbeHg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 768,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '192-03 Union Tpke',
#    'address2': '',
#    'address3': None,
#    'city': 'Fresh Meadows',
#    'zip_code': '11366',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#   'phone': '+17184680888',
#   'display_phone': '(718) 468-0888',
#   'distance': 18401.011784437622},
#  {'id': 'NN3mOWF5e_pnR1ArqM2bHQ',
#   'alias': 'obao-new-york-3',
#   'name': 'OBAO',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CpVI2XJLrvg09Fm83bfPog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/obao-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 2638,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7606544, 'longitude': -73.991332},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '647 9th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10036',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['647 9th Ave', 'New York, NY 10036']},
#   'phone': '+12122458880',
#   'display_phone': '(212) 245-8880',
#   'distance': 6144.081737145313},
#  {'id': 'TUoya6mwmxr0Zpr8oZSXlg',
#   'alias': 'thip-osha-brooklyn-2',
#   'name': 'Thip Osha',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AexQnAuV99JTkUsoe7edng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thip-osha-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 81,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.712123, 'longitude': -73.941437},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '795 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['795 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17183887787',
#   'display_phone': '(718) 388-7787',
#   'distance': 4514.165073687724},
#  {'id': 'jfnDwWBGK4JoWE5jbeKxSw',
#   'alias': 'chu-ros-thai-new-york',
#   'name': 'Chu-Ros Thai',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CPuUhG3gTTDGgjCVjcD1iQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chu-ros-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 90,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.78922, 'longitude': -73.94873},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '1590 Lexington Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10029',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1590 Lexington Ave', 'New York, NY 10029']},
#   'phone': '+19172658432',
#   'display_phone': '(917) 265-8432',
#   'distance': 10082.249947035149},
#  {'id': 'UO4kyXfdQIlAhM-TRgM9cw',
#   'alias': 'look-by-plant-love-house-brooklyn-2',
#   'name': 'Look By Plant Love House',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mvx6ONrNJHgVhnqHxsxo6w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/look-by-plant-love-house-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 329,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.679893, 'longitude': -73.964447},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '622 Washington Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['622 Washington Ave', 'Brooklyn, NY 11238']},
#   'phone': '+17186220026',
#   'display_phone': '(718) 622-0026',
#   'distance': 3798.9064789978547},
#  {'id': 'rKeLuHDI3PQZsPSVCEMHtw',
#   'alias': 'wondee-siam-new-york-3',
#   'name': 'Wondee Siam',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8S7WgzeqeS0Y-Hy1yESx_w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wondee-siam-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 1028,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76495, 'longitude': -73.98747},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '792 9th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['792 9th Ave', 'New York, NY 10019']},
#   'phone': '+12124599057',
#   'display_phone': '(212) 459-9057',
#   'distance': 6639.674884696999},
#  {'id': 'Wq9cARVEwOmoqfg41mNRNg',
#   'alias': 'noree-thai-bazaar-new-york',
#   'name': 'Noree Thai Bazaar',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o2rQ3DMNnTaRaoiUIFBtMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noree-thai-bazaar-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 178,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7178949956625,
#    'longitude': -73.9928582310677},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '274 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['274 Grand St', 'New York, NY 10002']},
#   'phone': '+16468640338',
#   'display_phone': '(646) 864-0338',
#   'distance': 1389.6632483859646},
#  {'id': '1uuxUq-QrUYX-Zal9TvFFQ',
#   'alias': 'charm-thai-express-new-york',
#   'name': 'Charm Thai Express',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/hHzsvvkkCKfxQZpOwy2W7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/charm-thai-express-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#   'review_count': 78,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.8139028640919,
#    'longitude': -73.9561226963997},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '1346 Amsterdam Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10027',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1346 Amsterdam Ave', 'New York, NY 10027']},
#   'phone': '+16467264548',
#   'display_phone': '(646) 726-4548',
#   'distance': 12481.123107854419}]

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
response.json()['total']
# Out:
# 2600

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < 150:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    print(cur)
    #make your API call with the new offset number
    results = yelp_call(url_params)
#     results_mex=yelp_call(url_params2)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    parsed_results_mex=parse_results(results_mex)
#     use your function to insert your parsed results into the db
    df_save('thai.csv', parsed_results)
    df_save('mex.csv', parsed_results_mex)
    #increment the counter by 50 to move on to the next results
    cur += 50
# Out:
# 0
# 50
# 100

# %%
thaidf = pd.read_csv('thai.csv', index_col=0)
mexdf = pd.read_csv('mex.csv', index_col=0)

# %%
thaidf['Categories'].value_counts()
# Out:
# [{'alias': 'thai', 'title': 'Thai'}]                                                                                                                         70
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'noodles', 'title': 'Noodles'}]                                                                                4
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]                                                                     4
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'noodles', 'title': 'Noodles'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]                             3
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'bars', 'title': 'Bars'}]                                                                                      2
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]                                                                       2
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'noodles', 'title': 'Noodles'}, {'alias': 'soup', 'title': 'Soup'}]                                            2
# Categories                                                                                                                                                    2
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'noodles', 'title': 'Noodles'}]                                      2
# [{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]                       2
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'soup', 'title': 'Soup'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]                                 1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'soup', 'title': 'Soup'}]                                            1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'lounges', 'title': 'Lounges'}, {'alias': 'noodles', 'title': 'Noodles'}]                                      1
# [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'thai', 'title': 'Thai'}]                                   1
# [{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'thai', 'title': 'Thai'}]                                                                         1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'noodles', 'title': 'Noodles'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]                          1
# [{'alias': 'foodtrucks', 'title': 'Food Trucks'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'catering', 'title': 'Caterers'}]                             1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]                                   1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}]                  1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'seafood', 'title': 'Seafood'}]                                    1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]                          1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'salad', 'title': 'Salad'}]                                          1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'soup', 'title': 'Soup'}]                                   1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'noodles', 'title': 'Noodles'}, {'alias': 'comfortfood', 'title': 'Comfort Food'}]                             1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'ramen', 'title': 'Ramen'}, {'alias': 'sushi', 'title': 'Sushi Bars'}]                                         1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'salad', 'title': 'Salad'}]                                                                                    1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'malaysian', 'title': 'Malaysian'}, {'alias': 'vietnamese', 'title': 'Vietnamese'}]                            1
# [{'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'raw_food', 'title': 'Live/Raw Food'}]                               1
# [{'alias': 'chinese', 'title': 'Chinese'}, {'alias': 'malaysian', 'title': 'Malaysian'}, {'alias': 'thai', 'title': 'Thai'}]                                  1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'halal', 'title': 'Halal'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]                               1
# [{'alias': 'laotian', 'title': 'Laotian'}]                                                                                                                    1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'chickenshop', 'title': 'Chicken Shop'}, {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]                 1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'desserts', 'title': 'Desserts'}, {'alias': 'soup', 'title': 'Soup'}]                                          1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'halal', 'title': 'Halal'}]                               1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'noodles', 'title': 'Noodles'}, {'alias': 'ramen', 'title': 'Ramen'}]                                          1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'desserts', 'title': 'Desserts'}]                                                                              1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'noodles', 'title': 'Noodles'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]                           1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'salad', 'title': 'Salad'}, {'alias': 'soup', 'title': 'Soup'}]                                                1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}, {'alias': 'noodles', 'title': 'Noodles'}]                                  1
# [{'alias': 'malaysian', 'title': 'Malaysian'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'halal', 'title': 'Halal'}]                                      1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'bubbletea', 'title': 'Bubble Tea'}, {'alias': 'noodles', 'title': 'Noodles'}]                                 1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'bars', 'title': 'Bars'}, {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}]                         1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'venues', 'title': 'Venues & Event Spaces'}]     1
# [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'salad', 'title': 'Salad'}]                                          1
# [{'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'thai', 'title': 'Thai'}, {'alias': 'panasian', 'title': 'Pan Asian'}]                          1
# Name: Categories, dtype: int64

# %%
mexdf = pd.read_csv('mex_csv')

# %%
df=pd.concat([thaidf,mexdf])

# %%
df
# Out:
#                           Id                              Name  \
# 0.0   9WgsvzaiXNAmmQGD0uQxFQ                        Thai Holic
# 1.0   B3_K2kUVbYOU0VaLcj_LTw                        Thai Villa
# 2.0   jjJc_CrkB2HodEinB6cWww                          LoveMama
# 3.0   wGFSTTB6b4MHJJUzBnVJeg                Top Thai Greenwich
# 4.0   -OixbLnFLCzQclxCSbUQ8w                           Up Thai
# ...                      ...                               ...
# 34.0  1ux5rxwWjKxoXHUyGynwSg                         Purepecha
# 35.0  zBORlLYwMqqJ_GOX6K31mw  Pedro's Mexican Bar & Restaurant
# 36.0  -kVueEw_fyO1Q2Gkmj6Few                 Taqueria Santa Fe
# 37.0  tvqtAjAyc7dplVVwhw3VZQ                 La Contenta Oeste
# 38.0  ifGXrRqs-zp6ek7LsoozrQ                    Taqueria Diana
#
#              Location Rating Price Zipcode            Transactions  \
# 0.0    372 Myrtle Ave    4.5    $$   11205  ['pickup', 'delivery']
# 1.0       5 E 19th St    4.5    $$   10003  ['pickup', 'delivery']
# 2.0       174 2nd Ave    4.5    $$   10003  ['pickup', 'delivery']
# 3.0   235 Sullivan St    4.5    $$   10012  ['pickup', 'delivery']
# 4.0      1411 2nd Ave    4.5    $$   10021  ['pickup', 'delivery']
# ...               ...    ...   ...     ...                     ...
# 34.0     213 Smith St    4.0    $$   11201  ['pickup', 'delivery']
# 35.0        73 Jay St    2.5    $$   11201  ['pickup', 'delivery']
# 36.0    4708 47th Ave    4.5     $   11377  ['pickup', 'delivery']
# 37.0     78 W 11th St    4.0    $$   10011  ['pickup', 'delivery']
# 38.0      129 2nd Ave    4.0     $   10003  ['pickup', 'delivery']
#
#      Review Count                                         Categories
# 0.0           455  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 1.0          3549  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 2.0          5198  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 3.0          1536  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 4.0          2382  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# ...           ...                                                ...
# 34.0           50         [{'alias': 'mexican', 'title': 'Mexican'}]
# 35.0          493         [{'alias': 'mexican', 'title': 'Mexican'}]
# 36.0          381         [{'alias': 'mexican', 'title': 'Mexican'}]
# 37.0          238  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 38.0          735         [{'alias': 'mexican', 'title': 'Mexican'}]
#
# [647 rows x 9 columns]

# %% [markdown]
# ## Part 3 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews. Above you ahve a model of the functions you will need to write, and how to pull them together in one script. For this part, you have the process below

# %% [markdown]
# - In order to pull the reveiws, you will need the business ids. So your first step will be to get all of the business ids from your businesses csv.

# %%
business_id = list(thaidf['Id'])

# for ID in business_id[:100]:
#     url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(ID)
#     response = requests.get(url, headers=headers)
    
api_key = 'S3cROVIGs17gTiCO6iy8-2ycbL999zhz84ANxStc2mYNESu0cKfM4qdarKNZ69t-2bnTPSR_RRTTCTKmpQidQYhD1mpVN1zvyo0EGTVthI7SVumcOA3IZrRgj5omYHYx'
headers = {
        'Authorization': 'Bearer {}'.format(api_key)}

categories = 'restaurants'
url_params_rev = {"limit": 50}

# response = requests.get(url, headers=headers, params=url_params)
# response.status_code

urls =[]
for x in business_id:
    url_rev = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(x)
    urls.append(url_rev)

# %%
response = requests.get(url, headers=headers, params=url_params)
response.status_code
# Out:
# 200

# %%
def yelp_call_rev(url_params):
    responses=[]
    for business in business_id[:100]:
        url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
        try:
            response = requests.get(url, headers=headers)
            responses.append((response.json()['reviews'],business))
        except:
            continue
    return responses

# %%
yelp_call_rev(url_params)
# Out:
# [([{'id': 'XYau75rutUUL73LsF2vaMg',
#     'url': 'https://www.yelp.com/biz/thai-holic-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=XYau75rutUUL73LsF2vaMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I ordered - lunch special Pad see ew for only $9\n noodles were broad and saucy. Perfect balance of soy and sweet and tofu was crispy. \nCame with 2 veggie...',
#     'rating': 5,
#     'time_created': '2020-12-06 11:39:38',
#     'user': {'id': 'kjlL0LPNI4FlkRbdtB4Y5A',
#      'profile_url': 'https://www.yelp.com/user_details?userid=kjlL0LPNI4FlkRbdtB4Y5A',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/WOTXqhZxOyMxEYJK95la5g/o.jpg',
#      'name': 'Garima G.'}},
#    {'id': 'BBRGdFcDv3ahbgYsfW_Sjg',
#     'url': 'https://www.yelp.com/biz/thai-holic-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=BBRGdFcDv3ahbgYsfW_Sjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'This is the best Thai food I have had. Dishes are flavorful and really well priced. They also have a few delicious cocktails. Obviously take out is only...',
#     'rating': 5,
#     'time_created': '2021-01-23 09:01:55',
#     'user': {'id': '2JtAn6UF7LGMEsXjI9RkUQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=2JtAn6UF7LGMEsXjI9RkUQ',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/jAIVJEwSd0GKnN9B-n515w/o.jpg',
#      'name': 'Oscar P.'}},
#    {'id': 'mhM7ECSaJVzmURJMEDRf2w',
#     'url': 'https://www.yelp.com/biz/thai-holic-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=mhM7ECSaJVzmURJMEDRf2w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Really solid Thai food!! Portions are big and the food was ready for pick up within ten minutes from placing my order.\n\nThe key lime tea was very aromatic...',
#     'rating': 5,
#     'time_created': '2020-06-17 15:45:01',
#     'user': {'id': '9bIajy5dWoVtgBxA7YCsLw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=9bIajy5dWoVtgBxA7YCsLw',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/QYSwqvNZW3LFNrEWGNm9bA/o.jpg',
#      'name': 'Jam H.'}}],
#   '9WgsvzaiXNAmmQGD0uQxFQ'),
#  ([{'id': '1CKI5RATDbfdtAMiGYLMHA',
#     'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=1CKI5RATDbfdtAMiGYLMHA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "First things first, I LOVED the venue and I'm not talking about the indoor decor. I absolutely adored the little cabins the restaurant created to house us...",
#     'rating': 5,
#     'time_created': '2021-02-05 19:39:18',
#     'user': {'id': 'CU4tpNjjbOprDGsK-vWWCw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=CU4tpNjjbOprDGsK-vWWCw',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/8XWOoqD8d3fa9uIggprBpA/o.jpg',
#      'name': 'Dan W.'}},
#    {'id': '9yCBLNsyfdsekrOYbvYWQw',
#     'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=9yCBLNsyfdsekrOYbvYWQw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Very safe and cozy outdoor seating. Great cocktails and dishes. I recommend their crispy duck. The interior is very swanky, so I can't wait till we reach...",
#     'rating': 5,
#     'time_created': '2021-02-15 20:13:37',
#     'user': {'id': '0Zy3hfgvmD3PbkXz_gc7QA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=0Zy3hfgvmD3PbkXz_gc7QA',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/JqwaZmRTmYyHBCOSJ5tBhA/o.jpg',
#      'name': 'Fumi S.'}},
#    {'id': 'vJbttqvzPsuRqjkaQ6M5nQ',
#     'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=vJbttqvzPsuRqjkaQ6M5nQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I loved this place, honestly. Everything I ate was super flavorful, and exactly what I wanted to be in my stomach. I love Thai food and I wish I had...',
#     'rating': 5,
#     'time_created': '2021-01-25 14:53:07',
#     'user': {'id': '4XIl3uPHIkF1pC_Hp1Wyrg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=4XIl3uPHIkF1pC_Hp1Wyrg',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/dCFqpQaKUwTCHpJ9cUKVXA/o.jpg',
#      'name': 'Insia Z.'}}],
#   'B3_K2kUVbYOU0VaLcj_LTw'),
#  ([{'id': 'pWWqEQb86iGs7gYoML3thw',
#     'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=pWWqEQb86iGs7gYoML3thw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'my friends and i were all craving different food when we were trying to decide what to eat, and i recommended that we try out this place. i can definitely...',
#     'rating': 5,
#     'time_created': '2021-02-06 09:37:55',
#     'user': {'id': 'CAIOQ1vxnb9Sifd18aWjSg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=CAIOQ1vxnb9Sifd18aWjSg',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/QDPa0avR0I3z99TkV73Opg/o.jpg',
#      'name': 'Brooke Z.'}},
#    {'id': 'CWFwiYEkzHvb2fuDFTAupA',
#     'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=CWFwiYEkzHvb2fuDFTAupA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I was in NYC on Christmas Day and we were searching for Thai food around Chinatown area. Most of the restaurants were closed (as expected because it is...',
#     'rating': 5,
#     'time_created': '2020-12-27 15:57:44',
#     'user': {'id': 'm-cM4C61m6d3iusOS9X1pA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=m-cM4C61m6d3iusOS9X1pA',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/bEDggOf_Mj67jPwivFBEVw/o.jpg',
#      'name': 'Pauline C.'}},
#    {'id': 'yrCJUsjsXzIwNBALVCz3EA',
#     'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=yrCJUsjsXzIwNBALVCz3EA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Came back yesterday after 3 years!!! Sorry I waited so long, when I said I would return sooner! But even though it's been 3 years, the moment I had a bite...",
#     'rating': 5,
#     'time_created': '2020-11-10 08:38:19',
#     'user': {'id': 'iYNEVdHbEWI4eHPJ8s5WNg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=iYNEVdHbEWI4eHPJ8s5WNg',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/_dJL-UCBkPQFRg6Cbx5Bqw/o.jpg',
#      'name': 'Kelly L.'}}],
#   'jjJc_CrkB2HodEinB6cWww'),
#  ([{'id': '8ykkiVYMAhIl7A3vW6WCGQ',
#     'url': 'https://www.yelp.com/biz/top-thai-greenwich-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=8ykkiVYMAhIl7A3vW6WCGQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'There is heated and partitioned seating! Win :) \n\nI have been here preCovid and would highly recommend the pad see ew with fried tofu & veggies, with the...',
#     'rating': 5,
#     'time_created': '2021-01-10 16:26:35',
#     'user': {'id': 'SYJzu_zmWTKwVhWtMfGgtQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=SYJzu_zmWTKwVhWtMfGgtQ',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/0U_ITC99BJH1lMFGSJqKlg/o.jpg',
#      'name': 'Anna D.'}},
#    {'id': '_SmvTuTIJEX7xWOBcwtohw',
#     'url': 'https://www.yelp.com/biz/top-thai-greenwich-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=_SmvTuTIJEX7xWOBcwtohw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'We just finished our delivery first order from Top Thai on Carmine St.  Mango Red Curry with Beef, Pad Thai with Shrimp and Papaya Salad. This is the best...',
#     'rating': 5,
#     'time_created': '2021-02-13 17:11:48',
#     'user': {'id': 'r3INb3HwMRvig0m9pFxXdw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=r3INb3HwMRvig0m9pFxXdw',
#      'image_url': None,
#      'name': 'Scott R.'}},
#    {'id': 'CTwT4LbuegW4-Y-XtQkgwg',
#     'url': 'https://www.yelp.com/biz/top-thai-greenwich-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=CTwT4LbuegW4-Y-XtQkgwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'We came here for happy hour drinks and food and were very happy with our decision!\n\nThe lychee mojito was delicious as was the red and white sangrias. I was...',
#     'rating': 5,
#     'time_created': '2020-08-29 09:40:14',
#     'user': {'id': 'yVS0746EB5gBNGE8FG5p-w',
#      'profile_url': 'https://www.yelp.com/user_details?userid=yVS0746EB5gBNGE8FG5p-w',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/FXPwPB1LFoWCNStCxXrSjQ/o.jpg',
#      'name': 'Kim X.'}}],
#   'wGFSTTB6b4MHJJUzBnVJeg'),
#  ([{'id': 'gabWS7rNznqkIwpB9I_-VQ',
#     'url': 'https://www.yelp.com/biz/up-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=gabWS7rNznqkIwpB9I_-VQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Up Thai is by far one of my favorite Thai restaurants to go if not the favorite haha \nThey have good food and it is a pity with the pandemic that we have to...',
#     'rating': 5,
#     'time_created': '2021-02-12 07:27:30',
#     'user': {'id': 'kwXgNBH28vLj705RqXeyLQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=kwXgNBH28vLj705RqXeyLQ',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/vl_dJ-7GJS7b7fJR08LmhQ/o.jpg',
#      'name': 'Gina D.'}},
#    {'id': '9ohvJv7_zNAP45rSQYNbRA',
#     'url': 'https://www.yelp.com/biz/up-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=9ohvJv7_zNAP45rSQYNbRA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'So my foodie friend and I had actually planned on going to THEP Thai which is about a block away but they cut off their waitlist. We had our heart set on...',
#     'rating': 5,
#     'time_created': '2021-02-06 11:38:37',
#     'user': {'id': 'ETrjemTEoaSiA87JxfV56w',
#      'profile_url': 'https://www.yelp.com/user_details?userid=ETrjemTEoaSiA87JxfV56w',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/ZFcziET_SIv3k8C9gRGsWg/o.jpg',
#      'name': 'Jessica B.'}},
#    {'id': 'nTAhstWPFwelNz7W2FdvBQ',
#     'url': 'https://www.yelp.com/biz/up-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=nTAhstWPFwelNz7W2FdvBQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'If you are craving tasty, well seasoned Thai food with *FAST* service, then this is the spot for you. I have ordered delivery a few times with DoorDash and...',
#     'rating': 5,
#     'time_created': '2020-11-05 08:59:03',
#     'user': {'id': 'Vi5ER8kThHK_YckNVYo6AQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=Vi5ER8kThHK_YckNVYo6AQ',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/gCk-3y2L2sbaVuMEWYJeZw/o.jpg',
#      'name': 'Maryam A.'}}],
#   '-OixbLnFLCzQclxCSbUQ8w'),
#  ([{'id': 'WNrd3pyWSchjl1wr6z0XrA',
#     'url': 'https://www.yelp.com/biz/boran-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=WNrd3pyWSchjl1wr6z0XrA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "One of my favorite Thai restaurants ever, and not just because it's conveniently in my neighborhood. Delicious, authentic Thai food and great service. It's...",
#     'rating': 5,
#     'time_created': '2020-06-18 06:24:42',
#     'user': {'id': 'cceP469ZdQVMD73zkG21FA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=cceP469ZdQVMD73zkG21FA',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/AyxW3N2UYbhAVvU3L4JRsQ/o.jpg',
#      'name': 'Steph C.'}},
#    {'id': 'pA8i2-mG9l_6WDOYrlndhw',
#     'url': 'https://www.yelp.com/biz/boran-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=pA8i2-mG9l_6WDOYrlndhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'My girlfriend hates me because all I ever want to get is Boran. Everything is great. But their food is much better in the restaurant than as take out. For...',
#     'rating': 5,
#     'time_created': '2020-06-27 16:16:14',
#     'user': {'id': 'QMjVujFhHQh-8dfB6mcwgg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=QMjVujFhHQh-8dfB6mcwgg',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/4gA0GAgxQKsgKwNIrC9DPg/o.jpg',
#      'name': 'Max C.'}},
#    {'id': 'eIePDunnVg_9hC2i_GP1EQ',
#     'url': 'https://www.yelp.com/biz/boran-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=eIePDunnVg_9hC2i_GP1EQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "YESSSSSSSS. YES. yep. Uh huh! The best I've had in NYC. Will be ordering again. Spice level was right and delivery friendly.",
#     'rating': 5,
#     'time_created': '2020-04-24 17:30:58',
#     'user': {'id': 'QZ7GJcjF-U1MdUfMUhb_oA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=QZ7GJcjF-U1MdUfMUhb_oA',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/YO-1A7TANq9fb_ZIfkXETQ/o.jpg',
#      'name': 'Mike P.'}}],
#   'feY7PgoRjCp2qReaIitRkQ'),
#  ([{'id': '6Uyd4IToAofC-KCUUXEpig',
#     'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=6Uyd4IToAofC-KCUUXEpig&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I used to travel extensively to Thailand in the 1990's.\n\nThe food there is absolutely nothing like the Thai food I was used to eating in the USA. I realized...",
#     'rating': 5,
#     'time_created': '2020-11-15 05:07:10',
#     'user': {'id': 'HZjtaysrgatDEBcRfFdKyw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=HZjtaysrgatDEBcRfFdKyw',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/9rgQrrtelf25buBscnQrVw/o.jpg',
#      'name': 'Stinky G.'}},
#    {'id': 'DAI0yWKAruaxQKbTaoJPrQ',
#     'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=DAI0yWKAruaxQKbTaoJPrQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I was there last night after had so many oyster with my friend . \n1. Fast service with big smile .\n2. Super clean and conscious about Covid19.\n3. 5 stars...',
#     'rating': 5,
#     'time_created': '2020-10-18 23:26:47',
#     'user': {'id': 'kF8JRkSYKUp6CbvVMnbcfw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=kF8JRkSYKUp6CbvVMnbcfw',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/wlBtySxc4Jlm5FTx-3CDvg/o.jpg',
#      'name': 'Araya M.'}},
#    {'id': 'LIyuhWBeETKkqio4lqmuoQ',
#     'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=LIyuhWBeETKkqio4lqmuoQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "[pre-COVID dine-in review]\n\nShort version: loved it, you can't go wrong, but standouts for me the seafood suki and beef skewers. \n\nAbsolutely loved loved...",
#     'rating': 5,
#     'time_created': '2020-08-14 11:20:53',
#     'user': {'id': 'r2ES4hClsS5TkQdCcp5ZQw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=r2ES4hClsS5TkQdCcp5ZQw',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/I2lvgsnQq6Rzeis0hKn0HA/o.jpg',
#      'name': 'Jennie B.'}}],
#   'qrydcGQpeDP_1oFvx3qOeg'),
#  ([{'id': 'euF8gyEv8sJOPwTSylzvIw',
#     'url': 'https://www.yelp.com/biz/pure-thai-cookhouse-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=euF8gyEv8sJOPwTSylzvIw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I love this place! When I found this little restaurant in New York I was reminded of the warm atmosphere and exquisite food I ate in unassuming little...',
#     'rating': 5,
#     'time_created': '2021-02-02 11:13:36',
#     'user': {'id': 'TT1v-DsBCHv3FKDI1JVP-Q',
#      'profile_url': 'https://www.yelp.com/user_details?userid=TT1v-DsBCHv3FKDI1JVP-Q',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/jsGT3zHiHYYeElauF784zg/o.jpg',
#      'name': 'Igor M.'}},
#    {'id': 'lYSlYgB8fMbGjFcPrNMY3g',
#     'url': 'https://www.yelp.com/biz/pure-thai-cookhouse-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=lYSlYgB8fMbGjFcPrNMY3g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Update: Edited Review. I had initially given 3/5 stars based on a tiny portion size for delivery. I went back in-person the next day and was wowed with...',
#     'rating': 5,
#     'time_created': '2020-10-06 18:38:39',
#     'user': {'id': 'Ix_FQIYo3ouaTaUQ_LEyUw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=Ix_FQIYo3ouaTaUQ_LEyUw',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/osjxofdcvtupoEa1dXcBTw/o.jpg',
#      'name': 'Vinay R.'}},
#    {'id': '5dFYdMwsaVvZs9NnsiK9gQ',
#     'url': 'https://www.yelp.com/biz/pure-thai-cookhouse-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=5dFYdMwsaVvZs9NnsiK9gQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Pure Thai is probably one of the best Thai restaurants in Hell's Kitchen, an area heavily saturated with Thai restaurants already. My go to dish is the Crab...",
#     'rating': 5,
#     'time_created': '2020-08-24 15:47:42',
#     'user': {'id': 'Osw38ONkzRSvI5xFjDKTXQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=Osw38ONkzRSvI5xFjDKTXQ',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/HDj0cVEHERDz3k9jhmoxnA/o.jpg',
#      'name': 'Scott L.'}}],
#   'MhceeLrM2_3mcKw5EGLY6A'),
#  ([{'id': 'F0ceV4jC7HlKbuariwRCgA',
#     'url': 'https://www.yelp.com/biz/noods-n-chill-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=F0ceV4jC7HlKbuariwRCgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Consistently our favorite delivery spot. Food comes hot, fresh and quickly every time. We've eaten about half the menu at this point and never been...",
#     'rating': 5,
#     'time_created': '2021-02-14 16:03:04',
#     'user': {'id': 'I8jH7FtHqj37MS9KlSvSEQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=I8jH7FtHqj37MS9KlSvSEQ',
#      'image_url': None,
#      'name': 'Charlie D.'}},
#    {'id': '2S9pemh6KcyebwehygBzqQ',
#     'url': 'https://www.yelp.com/biz/noods-n-chill-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=2S9pemh6KcyebwehygBzqQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Absolutely delicious. Not sure if they have heated outdoor seating, but the takeout is most likely just as delicious. The drunken noodle is some of the best...',
#     'rating': 5,
#     'time_created': '2020-12-28 18:40:16',
#     'user': {'id': 'peyZiTqMfIjw9aEIHVmUIw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=peyZiTqMfIjw9aEIHVmUIw',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/4zYyTDr8cWeqtTBFiDkOFg/o.jpg',
#      'name': 'Ryan M.'}},
#    {'id': 'Rt8HsbCV3xOAjU7dKTv-nw',
#     'url': 'https://www.yelp.com/biz/noods-n-chill-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=Rt8HsbCV3xOAjU7dKTv-nw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Ordered delivery from here and was not disappointed. We tried the papaya salad and pork dumplings to start. Both were great - the papaya salad was very...',
#     'rating': 5,
#     'time_created': '2020-05-05 06:20:57',
#     'user': {'id': '1Gtn-hyAjnphWyARrevYmA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=1Gtn-hyAjnphWyARrevYmA',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/wZfD6mjzXzLAaNi3dSTRgA/o.jpg',
#      'name': 'Emily C.'}}],
#   'l_gQf_4NgPMJcx2OkjsMfg'),
#  ([{'id': 'PsvCfZhr0vtSuTHiXinWVg',
#     'url': 'https://www.yelp.com/biz/thai-diner-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=PsvCfZhr0vtSuTHiXinWVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "GREAT OUTDOOR SETUP FOR DINING DURING COVID!! Ya'll this is the same people that was behind opening Uncle Boon's Michelin Star Thai restaurant! And if ya'll...",
#     'rating': 5,
#     'time_created': '2021-02-05 17:04:32',
#     'user': {'id': 'PYU55GS49zUD_u4GJ_jVIQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=PYU55GS49zUD_u4GJ_jVIQ',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/JMo9jWQqDS26RqMnrSZ8-w/o.jpg',
#      'name': 'Monica P.'}},
#    {'id': 'H_VfMLScTvFxea2vTQ8Z0g',
#     'url': 'https://www.yelp.com/biz/thai-diner-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=H_VfMLScTvFxea2vTQ8Z0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "My favorite Thai-inspired restaurant!\n\nEverything from cocktails to main dishes are fantastic. They change their menu every few months or so. I'm not...",
#     'rating': 5,
#     'time_created': '2021-02-05 14:55:27',
#     'user': {'id': '0Zy3hfgvmD3PbkXz_gc7QA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=0Zy3hfgvmD3PbkXz_gc7QA',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/JqwaZmRTmYyHBCOSJ5tBhA/o.jpg',
#      'name': 'Fumi S.'}},
#    {'id': 'bYGg7aKlcv8EgLBAzlr1nQ',
#     'url': 'https://www.yelp.com/biz/thai-diner-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=bYGg7aKlcv8EgLBAzlr1nQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I went to Thai Diner for brunch recently and had a lovely meal! I was the biggest advocate for Uncle Boons (so sad they closed, damn COVID!) and was...',
#     'rating': 5,
#     'time_created': '2021-01-16 12:03:30',
#     'user': {'id': 'HW5mYuF5RzkbYvJhceq7_w',
#      'profile_url': 'https://www.yelp.com/user_details?userid=HW5mYuF5RzkbYvJhceq7_w',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/WP8epuIRvK-WL88uF7RB6w/o.jpg',
#      'name': 'Laurel F.'}}],
#   'XgiG7K7ubHsj2JJ-c2sXnw'),
#  ([{'id': 'wJH3YC5iDbU7QXFI86ZZvQ',
#     'url': 'https://www.yelp.com/biz/williamsburg-thai-cuisine-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=wJH3YC5iDbU7QXFI86ZZvQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I really like how they had the restaurant set up the take out I feel they took the pains of figuring out how to serve the customers best while still...',
#     'rating': 5,
#     'time_created': '2020-06-14 13:43:50',
#     'user': {'id': 'ARFM4LrI_zxogm1L29ZKng',
#      'profile_url': 'https://www.yelp.com/user_details?userid=ARFM4LrI_zxogm1L29ZKng',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/biTd3s8nyyfm53kdTA9l7Q/o.jpg',
#      'name': 'Farrah B.'}},
#    {'id': '7Go6t9ef33sv5Cz1QVGZ7g',
#     'url': 'https://www.yelp.com/biz/williamsburg-thai-cuisine-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=7Go6t9ef33sv5Cz1QVGZ7g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Very flavorful and yummy. Good portions and great taste! I would definitely drive out here for this again. During this quarantine I'm just driving around...",
#     'rating': 5,
#     'time_created': '2020-07-08 20:51:26',
#     'user': {'id': 'APtcnlC_vulvHXn1kE9uZA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=APtcnlC_vulvHXn1kE9uZA',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/Tx85lLBbFQ0xAbmFnSK_WQ/o.jpg',
#      'name': 'Amaka D.'}},
#    {'id': 'mEwdZIQ7XgdoQeK6PxQ1iQ',
#     'url': 'https://www.yelp.com/biz/williamsburg-thai-cuisine-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=mEwdZIQ7XgdoQeK6PxQ1iQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "OMG! Everything was delicious! I love pad thai. It's my go to dish. But a lot of times it's not fresh. This pad Thai was so go and fresh. I ain't get to...",
#     'rating': 5,
#     'time_created': '2020-11-11 03:19:32',
#     'user': {'id': 'bvF-4vHIMPWA4KEbX2sfGQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=bvF-4vHIMPWA4KEbX2sfGQ',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/ODvtkzyyQD4pIjCCZTOhkQ/o.jpg',
#      'name': 'Serqit H.'}}],
#   'liGIz8CzhyS1udx1aefjng'),
#  ([{'id': 'jgg-XSmWxV6y0Go5N3eN9Q',
#     'url': 'https://www.yelp.com/biz/pinto-restaurant-brooklyn-heights-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=jgg-XSmWxV6y0Go5N3eN9Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'BF and I have eaten there before COVID but yesterday was first time since. Love the cute kitschy vibe they created for outdoor dining. Very cozy. We had pad...',
#     'rating': 5,
#     'time_created': '2020-09-26 05:33:43',
#     'user': {'id': 'rtqQeJkYH1hRBDwnktyf9w',
#      'profile_url': 'https://www.yelp.com/user_details?userid=rtqQeJkYH1hRBDwnktyf9w',
#      'image_url': None,
#      'name': 'Milly M.'}},
#    {'id': 'yXN72vBW9BdvEnR2t5_8IQ',
#     'url': 'https://www.yelp.com/biz/pinto-restaurant-brooklyn-heights-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=yXN72vBW9BdvEnR2t5_8IQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Cute set up if outdoors was still feasible. They have a floral border along their entrance way that my puppy was a big fan of (trying to put in her mouth)....',
#     'rating': 4,
#     'time_created': '2020-11-30 14:27:56',
#     'user': {'id': 'nx5-LzxIVXlQrKpWL_3PVQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=nx5-LzxIVXlQrKpWL_3PVQ',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/PvDBq1X_CNTzJdH2rs1xMw/o.jpg',
#      'name': 'Mary P.'}},
#    {'id': 'FzYEp816X9zO2WK9Efe_1Q',
#     'url': 'https://www.yelp.com/biz/pinto-restaurant-brooklyn-heights-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=FzYEp816X9zO2WK9Efe_1Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I've come here a few times and really enjoyed the food. They have outdoor seating (with heaters now) and are open for indoor as well although I haven't...",
#     'rating': 4,
#     'time_created': '2020-12-10 08:42:54',
#     'user': {'id': '66aQlAX0nWEdJRks53pa-w',
#      'profile_url': 'https://www.yelp.com/user_details?userid=66aQlAX0nWEdJRks53pa-w',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/tLMYppWC2Tgib45uZoPdEg/o.jpg',
#      'name': 'Allana D.'}}],
#   'RrPIJvmje1qb9iaYd6jH0g'),
#  ([{'id': 'KELkFyHVLYp5caGsnomAzA',
#     'url': 'https://www.yelp.com/biz/salathai-restaurant-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=KELkFyHVLYp5caGsnomAzA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'NYC indoor dining is back!! \n\nThis restaurant has a cozy feel to it inside. I love the decor and ambiance. \n\nWe were seated right away and felt completely...',
#     'rating': 5,
#     'time_created': '2021-02-12 17:15:42',
#     'user': {'id': 'ClQAJtZBdbrLiXWw2KAqSA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=ClQAJtZBdbrLiXWw2KAqSA',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/iYyPdDaDAMGcpH-ONTkM6g/o.jpg',
#      'name': 'Michaela R.'}},
#    {'id': 'oRcnooceJP1mOPOVGwmxGg',
#     'url': 'https://www.yelp.com/biz/salathai-restaurant-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=oRcnooceJP1mOPOVGwmxGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'The best Thai restaurant outside of Thailand. \n\nI have probably ate in and ordered food over 200 times in the last 3 years. The food is incomparable. Always...',
#     'rating': 5,
#     'time_created': '2021-01-12 05:42:39',
#     'user': {'id': 'TFWAPd6thp1i2FyCEu8Dsg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=TFWAPd6thp1i2FyCEu8Dsg',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/oXqSZJIDBWItjaiKiR4xoA/o.jpg',
#      'name': 'Lexy A.'}},
#    {'id': 'OMzJ_byor_cYum8FJQUsRg',
#     'url': 'https://www.yelp.com/biz/salathai-restaurant-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=OMzJ_byor_cYum8FJQUsRg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "My favorite Thai restaurant around me! Delivery is quick and the food is very yummy! I've ordered the Pad Se Ew, Pad Thai, another noodle dish that I cannot...",
#     'rating': 5,
#     'time_created': '2021-01-19 08:48:46',
#     'user': {'id': '6shuV1HV8Amqy44rbyVcmA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=6shuV1HV8Amqy44rbyVcmA',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/HXhKxPDr-boiVmllcGfgPA/o.jpg',
#      'name': 'Cynthia H.'}}],
#   'VoAuIReq_cPUrFwxbWqG_Q'),
#  ([{'id': '3pfB3wISIj9jnG6xwcaDsg',
#     'url': 'https://www.yelp.com/biz/top-thai-55-carmine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=3pfB3wISIj9jnG6xwcaDsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'OH. MY. GOD.  What kind of magic sparkles did they put in their food to make my mouth light up with every bite?!?  And this was delivery- sitting in a...',
#     'rating': 5,
#     'time_created': '2020-12-06 17:19:34',
#     'user': {'id': 'xvu8G900tezTzbbfqmTKvA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=xvu8G900tezTzbbfqmTKvA',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/ErhBwhybLmsoH4SP3j2Qgw/o.jpg',
#      'name': 'Anne R.'}},
#    {'id': '6MBUg-rRVyWILLpGiLrcBA',
#     'url': 'https://www.yelp.com/biz/top-thai-55-carmine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=6MBUg-rRVyWILLpGiLrcBA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': '*Pre-COVID*\n\nVisited Top Thai 55 on Carmine right before COVID started hitting the city. Note: this is their second location as their main & original...',
#     'rating': 5,
#     'time_created': '2020-11-21 17:16:41',
#     'user': {'id': 'mJFdoZB8prD--oaSY4WOfg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=mJFdoZB8prD--oaSY4WOfg',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/7f7e8ypimRORfXpKOecDDQ/o.jpg',
#      'name': 'Nick T.'}},
#    {'id': 'WUmSnk9OjApiWsxFqWImjg',
#     'url': 'https://www.yelp.com/biz/top-thai-55-carmine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=WUmSnk9OjApiWsxFqWImjg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Came here with friends for lunch on a weekend and felt safe with the COVID-19 precautions taken here. We sat outside of the booths, and the tables were...',
#     'rating': 5,
#     'time_created': '2021-01-05 15:26:45',
#     'user': {'id': 'WJsX5np_L-d2JqPS7udJkQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=WJsX5np_L-d2JqPS7udJkQ',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/XSXemzKGVQMXb9QJGS0H6Q/o.jpg',
#      'name': 'Jessica M.'}}],
#   '0IFDnYf3bhqxJR6hVrG7Gw'),
#  ([{'id': 'oqT-_Mg9hPZmMxoPBjXbRw',
#     'url': 'https://www.yelp.com/biz/kor-tor-mor-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=oqT-_Mg9hPZmMxoPBjXbRw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Best Thai in the Cobble Hill/Boerum Hill neighborhood.  Very fresh and fast delivery as well as a bigger menu than most.',
#     'rating': 5,
#     'time_created': '2021-02-14 09:01:10',
#     'user': {'id': 'ogp1U3d259zLkpsXb7ep-A',
#      'profile_url': 'https://www.yelp.com/user_details?userid=ogp1U3d259zLkpsXb7ep-A',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/snMtBH2x64i5zDqSgyCjaw/o.jpg',
#      'name': 'Edward L.'}},
#    {'id': '6pTTOXDz2AYLPFI3UfqtAw',
#     'url': 'https://www.yelp.com/biz/kor-tor-mor-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=6pTTOXDz2AYLPFI3UfqtAw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'A week or so before life as we know it changed, I took some time away from the demands of work & motherhood to enjoyed a little "me time." I stumbled upon...',
#     'rating': 5,
#     'time_created': '2020-04-04 17:51:36',
#     'user': {'id': '_C8Xy4LQeLc3eRBdfpWOzw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=_C8Xy4LQeLc3eRBdfpWOzw',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/CaoRuSGTlHqo5-sCTB4K0g/o.jpg',
#      'name': 'Timberly W.'}},
#    {'id': 'dYXXCVZ5yXA_LjMuXlZr0A',
#     'url': 'https://www.yelp.com/biz/kor-tor-mor-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=dYXXCVZ5yXA_LjMuXlZr0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "This is a solid choice for Thai; one of my preferred in the neighborhood. I've only ever ordered in from here but when I've walked by it seemed cute....",
#     'rating': 4,
#     'time_created': '2020-04-22 17:03:25',
#     'user': {'id': '66aQlAX0nWEdJRks53pa-w',
#      'profile_url': 'https://www.yelp.com/user_details?userid=66aQlAX0nWEdJRks53pa-w',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/tLMYppWC2Tgib45uZoPdEg/o.jpg',
#      'name': 'Allana D.'}}],
#   '5ZjNZd3Yg0jOkJ9WRx1r6g'),
#  ([{'id': '58NlugJSPZkGRDZtZ_Xnbw',
#     'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=58NlugJSPZkGRDZtZ_Xnbw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'No Woodside/Sunnyside food crawl would be completely without Thai food. SirPraPhai is a must-hit (and judging by the 2300+ reviews, it seems like a ton of...',
#     'rating': 5,
#     'time_created': '2021-01-31 14:17:23',
#     'user': {'id': 'xJpvRrk04rb4rgWtMXaPUQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=xJpvRrk04rb4rgWtMXaPUQ',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/3ZcqE7gLobWD8LWD_WvYlg/o.jpg',
#      'name': 'Kenny C.'}},
#    {'id': 'DY895QKPCPEFG1x2ZicPOw',
#     'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=DY895QKPCPEFG1x2ZicPOw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I've been a regular here all these years while  living in the neighborhood and always find a time to eat here every time I come back. I come here so often...",
#     'rating': 5,
#     'time_created': '2020-11-12 00:08:31',
#     'user': {'id': 'UfYdKEzUaFq7oCOig1SCKA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=UfYdKEzUaFq7oCOig1SCKA',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/kUsGSmGiw7YVitfRdYfL-Q/o.jpg',
#      'name': 'Catherine W.'}},
#    {'id': 'EgSkZxmR3CP3nB8nI2sMsg',
#     'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=EgSkZxmR3CP3nB8nI2sMsg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I can't even remember the last time I had Thai food (thanks, COVID) so was stoked when my friend had suggested SriPraPhai for a weekend lunch.  The front of...",
#     'rating': 5,
#     'time_created': '2020-10-29 11:44:20',
#     'user': {'id': 'gUhM-6VAU3ZyoKtqARWq4Q',
#      'profile_url': 'https://www.yelp.com/user_details?userid=gUhM-6VAU3ZyoKtqARWq4Q',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/9VF5KK9BLhDr3Y4z6TaPGA/o.jpg',
#      'name': 'Michele Q.'}}],
#   '0L03onqNwxWLrbb_FCK79A'),
#  ([{'id': 'bDDOvQi6DO8Vj_dP0EESRQ',
#     'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=bDDOvQi6DO8Vj_dP0EESRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Still so excellent.  Came here for lunch today around noon on Monday.  Sat outside in a small separate booth for 2 with no reservation.  There were outdoor...',
#     'rating': 5,
#     'time_created': '2021-02-15 17:55:44',
#     'user': {'id': 'cEiHy_mkk4nr4TCu0q_6HA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=cEiHy_mkk4nr4TCu0q_6HA',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/lRRuEAY9YZEmitvdeWdXew/o.jpg',
#      'name': 'Tessa C.'}},
#    {'id': 'YhmDw9tG_dygqN8vtz5T5w',
#     'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=YhmDw9tG_dygqN8vtz5T5w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Reservations east on RESY (yes they hold deposit in case you don't show up); they do not take reservations via telephone day off; both covered and uncovered...",
#     'rating': 5,
#     'time_created': '2021-01-15 06:55:41',
#     'user': {'id': 'BBSYyLG824fZjP-kulhLgw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=BBSYyLG824fZjP-kulhLgw',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/dIeDu0QLOW4etQszgYas0g/o.jpg',
#      'name': 'Dessa R.'}},
#    {'id': 'fhrLkQyLEg2qJvKRCHqupA',
#     'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=fhrLkQyLEg2qJvKRCHqupA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Fish Cheeks is now easily one of my favorite Thai restaurants in the city. This place does NOT cater at all to Americanized versions of Thai cuisine. There...',
#     'rating': 5,
#     'time_created': '2020-10-11 17:49:33',
#     'user': {'id': 'e6YSPujPSkFiL1ofovbUJg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=e6YSPujPSkFiL1ofovbUJg',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/t0WjlRPJk-KJRMM8P0PN9Q/o.jpg',
#      'name': 'Diane J.'}}],
#   'WJS06XxRdc6DD1s4LWE9HA'),
#  ([{'id': 'CGCPRKteoTBGOJekZbyniw',
#     'url': 'https://www.yelp.com/biz/wok-wok-southeast-asian-kitchen-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=CGCPRKteoTBGOJekZbyniw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "i decided to pick up something from here on my way home, and this place's pad thai really never disappoints me!\n-they're available for delivery on caviar,...",
#     'rating': 4,
#     'time_created': '2021-02-15 06:35:45',
#     'user': {'id': 'CAIOQ1vxnb9Sifd18aWjSg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=CAIOQ1vxnb9Sifd18aWjSg',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/QDPa0avR0I3z99TkV73Opg/o.jpg',
#      'name': 'Brooke Z.'}},
#    {'id': 'fbKiWgeqdu9RsK0JKxH6aQ',
#     'url': 'https://www.yelp.com/biz/wok-wok-southeast-asian-kitchen-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=fbKiWgeqdu9RsK0JKxH6aQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': '-BEFORE COVID-\nLast time I came in was before Covid with the strict guidelines. I came 2/11/2020 after shopping at Macys. The family was hungry and Wok Wok...',
#     'rating': 4,
#     'time_created': '2021-01-28 14:30:54',
#     'user': {'id': 'MQI6gchdfTFlU8s9ZVUXhA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=MQI6gchdfTFlU8s9ZVUXhA',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/TsMWbb-g7FWCSXjEbG_T4w/o.jpg',
#      'name': 'Sherry W.'}},
#    {'id': 'gkfnPnvXHHrk6X2WG9fGnw',
#     'url': 'https://www.yelp.com/biz/wok-wok-southeast-asian-kitchen-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=gkfnPnvXHHrk6X2WG9fGnw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I've been getting takeout here pretty often during COVID. The staff has recognized me by now, and they're all so friendly and super accomodating to whatever...",
#     'rating': 5,
#     'time_created': '2021-01-26 10:37:53',
#     'user': {'id': 'CITBYQM0xdmUgVti4vj10A',
#      'profile_url': 'https://www.yelp.com/user_details?userid=CITBYQM0xdmUgVti4vj10A',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/9H8hAbvYJuL_VLM0khRePg/o.jpg',
#      'name': 'Sherry F.'}}],
#   '0GftSP2dRwEzujkv2VKIgA'),
#  ([{'id': 'SGoiIE9Z06tWOKufmkedMg',
#     'url': 'https://www.yelp.com/biz/thep-thai-restaurant-new-york-5?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=SGoiIE9Z06tWOKufmkedMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'COVID report: THEP currently has individual heated wooden cabins with sliding doors. I visited on a freezing day and it was a little chilly in our cabin,...',
#     'rating': 5,
#     'time_created': '2021-01-17 15:01:13',
#     'user': {'id': 'HVQKFDi-vZbawtmLMq3ZOw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=HVQKFDi-vZbawtmLMq3ZOw',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/hR3klUhVTFCrNjnUhYb2hA/o.jpg',
#      'name': 'Gab G.'}},
#    {'id': 'jOdub8WTpzmeTYOk8vzs_g',
#     'url': 'https://www.yelp.com/biz/thep-thai-restaurant-new-york-5?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=jOdub8WTpzmeTYOk8vzs_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I literally cannot get enough of this place. I am putting it out there its the best Thai in NYC (I'm open to debating but there is none.)\nThey are very...",
#     'rating': 5,
#     'time_created': '2021-01-03 03:19:19',
#     'user': {'id': 'VEjMxVnvI3g1CvjMjj5PSg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=VEjMxVnvI3g1CvjMjj5PSg',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/LGxbQl6-S08hqIo8hDbVCQ/o.jpg',
#      'name': 'Johnny G.'}},
#    {'id': 'Z1B4b9h732455VwyU4gw6Q',
#     'url': 'https://www.yelp.com/biz/thep-thai-restaurant-new-york-5?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=Z1B4b9h732455VwyU4gw6Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Deeeelicious! Everytime. We got the calamari, basil fried rice, pad se ew, crispy duck in penang curry. Covid safe.',
#     'rating': 5,
#     'time_created': '2021-02-14 14:40:03',
#     'user': {'id': 'hcKyBbGJ4p3o71DKrWH4kw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=hcKyBbGJ4p3o71DKrWH4kw',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/0OGhrp4uLew2cId_qH3Q2w/o.jpg',
#      'name': 'Sayeeda A.'}}],
#   'O1fUmxt3kbV-rnyjBtzAfw'),
#  ([{'id': 'AOeeh2Vbw-S6ae3WRytNhw',
#     'url': 'https://www.yelp.com/biz/wayla-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=AOeeh2Vbw-S6ae3WRytNhw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Covid: Contract tracing & temperature check upon arrival. Staff wears masks. There's a front outdoor dining area, indoor dining and the cutest backyard...",
#     'rating': 5,
#     'time_created': '2020-11-25 17:42:53',
#     'user': {'id': 'c1nxcvSI8wDjkij3hOutzw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=c1nxcvSI8wDjkij3hOutzw',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/iMgJthjmaRyIF_c7tnf3Gw/o.jpg',
#      'name': 'Carrie C.'}},
#    {'id': 'm40P029HzByec4721AWtmw',
#     'url': 'https://www.yelp.com/biz/wayla-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=m40P029HzByec4721AWtmw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Wayla is such a vibe!!!\n\nI set my timer to go off at midnight in order to snag a reservation at peak hours. So happy I did!\n\nMy friend and I dined on a...',
#     'rating': 5,
#     'time_created': '2020-09-08 05:46:26',
#     'user': {'id': 'xpDVPSLlZnU8MQaOS2HAwA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=xpDVPSLlZnU8MQaOS2HAwA',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/4tqsLxPnuOobyLmIkeuf7A/o.jpg',
#      'name': 'Lorraine T.'}},
#    {'id': '1eRKB3rgbrDllg4l0V7eqg',
#     'url': 'https://www.yelp.com/biz/wayla-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=1eRKB3rgbrDllg4l0V7eqg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I've been wanting to eat at Wayla since before the pandemic & finally got to do so with a good friend late in the summer. Boy, Wayla did not...",
#     'rating': 5,
#     'time_created': '2020-11-22 18:56:36',
#     'user': {'id': 'TV0V5o9M9iVZihUAzm0PIw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=TV0V5o9M9iVZihUAzm0PIw',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/mMNDa_cwp87h_8WYICBmaQ/o.jpg',
#      'name': 'Olivia S.'}}],
#   'liZmIO0FqZwslLJfLDkfgw'),
#  ([{'id': 'M1W5a_VlB5Crlg6_Q2R0XQ',
#     'url': 'https://www.yelp.com/biz/sage-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=M1W5a_VlB5Crlg6_Q2R0XQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "This is my favorite thai place hands down, been going here for years. Food is great and inexpensive. I've never had any issues with delivery, it's always...",
#     'rating': 5,
#     'time_created': '2020-11-12 17:29:23',
#     'user': {'id': 'pFvJD_u68-FSvXKnluTDqA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=pFvJD_u68-FSvXKnluTDqA',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/WPAkcPD45PAFr4-eaBJnIA/o.jpg',
#      'name': 'Ofelia E.'}},
#    {'id': '1rrA1lTyh_Z-QaXjE0RQgA',
#     'url': 'https://www.yelp.com/biz/sage-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=1rrA1lTyh_Z-QaXjE0RQgA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I love Sage. They have the best lunch specials in east Williamsburg and are still delivering during the pandemic. Their orders always arrive quicker than...',
#     'rating': 5,
#     'time_created': '2020-05-18 10:53:24',
#     'user': {'id': 'fys0X9T65lRMT0SCK4GWbg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=fys0X9T65lRMT0SCK4GWbg',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/WWsUKdn7qH4RZM-lBpnN0Q/o.jpg',
#      'name': 'Cathy D.'}},
#    {'id': 'IgvDZgIHJ8Nek_ysVLxVLg',
#     'url': 'https://www.yelp.com/biz/sage-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=IgvDZgIHJ8Nek_ysVLxVLg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Great lunch specials, im getting into thai because of them! the portions are quite large for me but for the average person. they have a shrimp app thats...',
#     'rating': 5,
#     'time_created': '2020-10-21 19:36:49',
#     'user': {'id': 'Butq-0nTDYKFtSlpjmud3g',
#      'profile_url': 'https://www.yelp.com/user_details?userid=Butq-0nTDYKFtSlpjmud3g',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/6Ar8bOzKbwFnuAElxOZ1mA/o.jpg',
#      'name': 'Melanie D.'}}],
#   'mpD_kUFo8POQDLoLgRSfCg'),
#  ([{'id': 'a82e2sP6nR2yn7QcocED6w',
#     'url': 'https://www.yelp.com/biz/ace-thai-kitchen-brooklyn-3?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=a82e2sP6nR2yn7QcocED6w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I talked out order Drunken noodle today was so great.\nThe server so nice and she good take care of sanitation during covid19.\n\nLove Ace',
#     'rating': 5,
#     'time_created': '2020-11-14 11:37:12',
#     'user': {'id': 'NQIAktLMBYec_Zh_oGkB6A',
#      'profile_url': 'https://www.yelp.com/user_details?userid=NQIAktLMBYec_Zh_oGkB6A',
#      'image_url': None,
#      'name': 'Wilaiporn K.'}},
#    {'id': 'AZLQabOyC6tVMoJc3CvT3Q',
#     'url': 'https://www.yelp.com/biz/ace-thai-kitchen-brooklyn-3?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=AZLQabOyC6tVMoJc3CvT3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
# ...
#     'rating': 4,
#     'time_created': '2020-08-11 20:08:13',
#     'user': {'id': 'ErEf2Xr-1qF1JAB-u9lwjg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=ErEf2Xr-1qF1JAB-u9lwjg',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/9U7IWN-NmkQmZ_P-Wr5EQg/o.jpg',
#      'name': 'Johanna B.'}}],
#   'GSOwJ5Gr8X4eGbkIjCzMWA'),
#  ([{'id': 'JFdta29J8xgqzXmmE5voGg',
#     'url': 'https://www.yelp.com/biz/thai-basil-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=JFdta29J8xgqzXmmE5voGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Awesome Thai spot in the area! Despite the low reviews, I took a chance to order from them because I never had a problem with their food before covid. I...',
#     'rating': 5,
#     'time_created': '2021-02-15 15:53:01',
#     'user': {'id': 'Pf3jabLlHkWE2BjnJHhqkw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=Pf3jabLlHkWE2BjnJHhqkw',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Oe0Sz4nmwSFzUoFmwJwEJA/o.jpg',
#      'name': 'Angel J.'}},
#    {'id': '1oU-uukUBRBXggsL6I_VKQ',
#     'url': 'https://www.yelp.com/biz/thai-basil-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=1oU-uukUBRBXggsL6I_VKQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Decided to try this place out despite all the negative reviews. It was definitely a gamble but a friend of my boyfriends said it wasn't as bad as the...",
#     'rating': 4,
#     'time_created': '2021-02-01 11:32:52',
#     'user': {'id': 'ScQP4J1Npxyk4m6upl4JLA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=ScQP4J1Npxyk4m6upl4JLA',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/NpNAs5yQj3RLIZBtyxK3VA/o.jpg',
#      'name': 'Amy W.'}},
#    {'id': 'ek3_4dClxIXGg3e3hCEpXQ',
#     'url': 'https://www.yelp.com/biz/thai-basil-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=ek3_4dClxIXGg3e3hCEpXQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Not sure about the negative reviews but I've had nothing but positive (and delicious lol) experiences from  ordering here. Delivery always come quickly and...",
#     'rating': 5,
#     'time_created': '2020-09-29 19:07:23',
#     'user': {'id': 'DDqDYgbqnCwKilSBSCI6GA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=DDqDYgbqnCwKilSBSCI6GA',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/GVq9bJdDpbLdUCzZglb9iw/o.jpg',
#      'name': 'Mary N.'}}],
#   'io73CG07m5_w9TP3_rl8DQ'),
#  ([{'id': 'rH1WH8FPwiMMe5OyHiOzOA',
#     'url': 'https://www.yelp.com/biz/thailicious-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=rH1WH8FPwiMMe5OyHiOzOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Came here a few nights ago. I really liked how their Covid situation was set up. Outdoor dining had ended (or was canceled bc it was raining) and they were...',
#     'rating': 5,
#     'time_created': '2020-10-14 18:23:02',
#     'user': {'id': 'UNR7NA7meZ9LkrAC8tQP2Q',
#      'profile_url': 'https://www.yelp.com/user_details?userid=UNR7NA7meZ9LkrAC8tQP2Q',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/po4-XVjqa5VbsaOx9HTn8Q/o.jpg',
#      'name': 'Zee D.'}},
#    {'id': '5LxcwNodPnlOqRWsvLgL4A',
#     'url': 'https://www.yelp.com/biz/thailicious-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=5LxcwNodPnlOqRWsvLgL4A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "So good!! I really love the owner here too, Jay! She's so kind and goes above and beyond for her customers. Tried many things here and all have been yum:...",
#     'rating': 5,
#     'time_created': '2021-01-24 15:36:46',
#     'user': {'id': 'Gdoqudgdal_VaETJpHuxaA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=Gdoqudgdal_VaETJpHuxaA',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/1nsKgoBXdaWOln3UyAbWow/o.jpg',
#      'name': 'Liz M.'}},
#    {'id': 'XN0K6tkQFtBYskMygMgUHQ',
#     'url': 'https://www.yelp.com/biz/thailicious-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=XN0K6tkQFtBYskMygMgUHQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Great place to stop in and sit or take-out! The service is great and really accommodating no matter how busy they are. The food is always delicious, fresh,...',
#     'rating': 5,
#     'time_created': '2020-10-09 09:30:04',
#     'user': {'id': 'HD0TnpwxfzDoaaQjTKReUQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=HD0TnpwxfzDoaaQjTKReUQ',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/K2wtIX2a_euV-bJ2z_R-EA/o.jpg',
#      'name': 'Ian P.'}}],
#   'dqjko5ndMGayALuhwq3ghQ'),
#  ([{'id': 'BSxJhw3Xo-ctay4G8CA2kw',
#     'url': 'https://www.yelp.com/biz/thai-me-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=BSxJhw3Xo-ctay4G8CA2kw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'This place has been my saving grace especially during work from home. The food is consistently good, the delivery times within reason and pricing...',
#     'rating': 5,
#     'time_created': '2020-11-30 14:23:11',
#     'user': {'id': 'QNNY_lA1Wjn0QoLxsQoKzg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=QNNY_lA1Wjn0QoLxsQoKzg',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/UcWZ7MVlFjBN6d414m8x-Q/o.jpg',
#      'name': 'Natalie G.'}},
#    {'id': 'IUHQR6rOF8HlflAPikalYw',
#     'url': 'https://www.yelp.com/biz/thai-me-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=IUHQR6rOF8HlflAPikalYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I got the Beef Noodle Soup with extra vegetables and Beef with Grub-Hub delivered for $16.00. You pay a extra $3.00 for extra Beef however it's worth it!...",
#     'rating': 5,
#     'time_created': '2020-05-10 18:29:38',
#     'user': {'id': 'ngHtWv-R0YJZQBgPs4hOsA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=ngHtWv-R0YJZQBgPs4hOsA',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/sk80lw8D1hZTBdMw8Cflyg/o.jpg',
#      'name': 'Judah H.'}},
#    {'id': 'wR_48wNfxKBQa83zNCwUqw',
#     'url': 'https://www.yelp.com/biz/thai-me-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=wR_48wNfxKBQa83zNCwUqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Best thai in Brooklyn. Food is always fresh and hot upon delivery. Cooked to perfection, no other place I go to for thai food!',
#     'rating': 5,
#     'time_created': '2021-02-06 20:07:08',
#     'user': {'id': 'aV9Szr7wzMc8HMk7TrwzjQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=aV9Szr7wzMc8HMk7TrwzjQ',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/pB71GvBJ4EEJ0Bu0TOrrBw/o.jpg',
#      'name': 'Kenne L.'}}],
#   'B0e6kXT0doU-n6EvMVGzQQ'),
#  ([{'id': 't23gUygG18mYfpWyjMROaA',
#     'url': 'https://www.yelp.com/biz/der-krung-thai-cuisine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=t23gUygG18mYfpWyjMROaA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Came by to pick up an online order for lunch to go. Food was ready pretty quickly which was convenient timing for walking over from the office. Solid and...',
#     'rating': 4,
#     'time_created': '2020-09-29 01:00:49',
#     'user': {'id': 'lVvldO56wrpfpC1sQ-TyGg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=lVvldO56wrpfpC1sQ-TyGg',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/V4WLsoKxwps8CD00H9oeXg/o.jpg',
#      'name': 'Eric F.'}},
#    {'id': 'Rr9EYYr-EPW1uBzjJS4lXw',
#     'url': 'https://www.yelp.com/biz/der-krung-thai-cuisine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=Rr9EYYr-EPW1uBzjJS4lXw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': '- We ordered for pick up\n- The pad thai was average but I really enjoyed the pork pad see ew\n- One of the few thai places still open that have pork\n- The...',
#     'rating': 4,
#     'time_created': '2020-05-20 17:39:09',
#     'user': {'id': 'BF2LSRonaqjNtWoKxH-s5g',
#      'profile_url': 'https://www.yelp.com/user_details?userid=BF2LSRonaqjNtWoKxH-s5g',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/zC_TDgopLtXscLXYP_whow/o.jpg',
#      'name': 'Sherry J.'}},
#    {'id': 'XaO4tO1cv1kJO3KeRLh2IA',
#     'url': 'https://www.yelp.com/biz/der-krung-thai-cuisine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=XaO4tO1cv1kJO3KeRLh2IA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "We love everything at Der Krung. We're so grateful that in the time of Covid we can still order from our favorite Thai place! Best times are: Pad See Ew,...",
#     'rating': 5,
#     'time_created': '2020-11-02 18:57:43',
#     'user': {'id': 'wKzswHDGBoA5OdHatjt5PA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=wKzswHDGBoA5OdHatjt5PA',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/xdVxAyQh2CO0d1hE3jk6sw/o.jpg',
#      'name': 'Nancy C.'}}],
#   '5-cv4xv4IBao7N1LSH6tHA'),
#  ([{'id': 'UHQ9o2AgA1p6uD2_KYhdqA',
#     'url': 'https://www.yelp.com/biz/viv-new-york-32?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=UHQ9o2AgA1p6uD2_KYhdqA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Solid Thai place in the neighborhood.\n\nGot this for takeout, ordered at the store and took probably 10 minutes for the food to he ready. Very quick.\n\nRed...',
#     'rating': 5,
#     'time_created': '2020-11-30 14:09:47',
#     'user': {'id': 'TPRke-y79fb3MO6StDHXaQ',
#      'profile_url': 'https://www.yelp.com/user_details?userid=TPRke-y79fb3MO6StDHXaQ',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/1woO96r6_NfKZWRGSQyQxw/o.jpg',
#      'name': 'Alice W.'}},
#    {'id': 'e_xee95Zja56pfe0tmasSw',
#     'url': 'https://www.yelp.com/biz/viv-new-york-32?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=e_xee95Zja56pfe0tmasSw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I've been there once before about 4 years ago, and liked this place. Not exactly my type of design since it looks like a night club in my opinion, but it's...",
#     'rating': 5,
#     'time_created': '2020-12-25 16:47:09',
#     'user': {'id': 'OexUWhIqvxkdvj_UYhPKng',
#      'profile_url': 'https://www.yelp.com/user_details?userid=OexUWhIqvxkdvj_UYhPKng',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/Ph6LfX28GrHzxlG8RwZ0Og/o.jpg',
#      'name': 'Seraphim P.'}},
#    {'id': 'GyYuo4aAO22zCrUBYVyKFg',
#     'url': 'https://www.yelp.com/biz/viv-new-york-32?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=GyYuo4aAO22zCrUBYVyKFg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Rated THE third best Pad Thai in NYC (yum!) and accompanied by a great happy hour that is daily from 12-7pm (my fav is the lychee martini!!), this spot is...',
#     'rating': 5,
#     'time_created': '2020-07-24 14:50:44',
#     'user': {'id': 'zz4PqqvxjtPsu8ivyUIR4A',
#      'profile_url': 'https://www.yelp.com/user_details?userid=zz4PqqvxjtPsu8ivyUIR4A',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/EW-p9sNBeN6ZolWfpH_Zog/o.jpg',
#      'name': 'Cody J.'}}],
#   'z1OgXX3L9Ipl2mu-Hf4ADw'),
#  ([{'id': 'Wj0IjgZ5ul5EJDgjPYmOCA',
#     'url': 'https://www.yelp.com/biz/hi-so-thai-weehawken?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=Wj0IjgZ5ul5EJDgjPYmOCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "It's our spot for thai food. We always get it delivered. Their delivery is fast and efficient. Quality of the food is good.",
#     'rating': 4,
#     'time_created': '2021-01-22 13:58:05',
#     'user': {'id': '8KGrrJjrU5HEgOksafE7lw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=8KGrrJjrU5HEgOksafE7lw',
#      'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/zfMqVZP_n3ORfRzpYYE-1Q/o.jpg',
#      'name': 'Natasha D.'}},
#    {'id': 'bYP0s8Mgm54dogSMIfmAfg',
#     'url': 'https://www.yelp.com/biz/hi-so-thai-weehawken?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=bYP0s8Mgm54dogSMIfmAfg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'I love this place. So far ordered twice - fried rice in different variations. Delivery is really fast and food is really tasty. Will order again.',
#     'rating': 5,
#     'time_created': '2020-11-04 16:46:00',
#     'user': {'id': 'WZYdRu9-Qk3naJSMJ_VBNg',
#      'profile_url': 'https://www.yelp.com/user_details?userid=WZYdRu9-Qk3naJSMJ_VBNg',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/6lM1fywgiP8UzbZbGDr0BQ/o.jpg',
#      'name': 'Valentina B.'}},
#    {'id': 'wMF76eQhPnX1846CVSOO1g',
#     'url': 'https://www.yelp.com/biz/hi-so-thai-weehawken?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=wMF76eQhPnX1846CVSOO1g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'We ordered the drunken noodles with beef and Thai Basil with chicken, and both were delicious and not greasy! Delivery was quick and food was still hot....',
#     'rating': 5,
#     'time_created': '2021-01-27 18:05:50',
#     'user': {'id': 'OCiUQFyHf-BE87Qwlmiusw',
#      'profile_url': 'https://www.yelp.com/user_details?userid=OCiUQFyHf-BE87Qwlmiusw',
#      'image_url': None,
#      'name': 'Guada M.'}}],
#   'Tmc90kL5jelJ2c9CiGzSFA'),
#  ([{'id': 'YH3xQhw2MlC3Gezll9tmqA',
#     'url': 'https://www.yelp.com/biz/jintana-thai-farmhouse-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=YH3xQhw2MlC3Gezll9tmqA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': 'Jintana Thai Farmhouse\nNY BK Park Slope\nFive Stars\n\nThis has been some of the best Thai food that I have had in ages. The Chicken Pad See Ew $12 was...',
#     'rating': 5,
#     'time_created': '2020-09-18 02:05:23',
#     'user': {'id': 'L7VEJP1RrpXRRRWsYIu3tA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=L7VEJP1RrpXRRRWsYIu3tA',
#      'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/bE-tXPdurxhChL0IKwePKQ/o.jpg',
#      'name': 'Leonard L.'}},
#    {'id': 'HN6vV1wUXqeSb4suxnWV3Q',
#     'url': 'https://www.yelp.com/biz/jintana-thai-farmhouse-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=HN6vV1wUXqeSb4suxnWV3Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "Ordered takeout on a Sunday evening. Jintana's Original Pad Thai was pretty standard for pad thai. Also ordered the Panang Curry with chicken - It did have...",
#     'rating': 5,
#     'time_created': '2020-09-14 08:50:33',
#     'user': {'id': 'CKOdoh6JG26eHsJd0l56AA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=CKOdoh6JG26eHsJd0l56AA',
#      'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/yyD2s2UYWLtX9di_Y8pZ_Q/o.jpg',
#      'name': 'Marc F.'}},
#    {'id': '3Ua1xjW2B1uLz0cDL7vLow',
#     'url': 'https://www.yelp.com/biz/jintana-thai-farmhouse-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&hrid=3Ua1xjW2B1uLz0cDL7vLow&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=YYinute8YoprX7XHYr6zhg',
#     'text': "I can't say enough about Jintana & I'm surprised it took me this long to review it.  The first time I was there was their opening week.  The credit card...",
#     'rating': 5,
#     'time_created': '2020-09-04 09:03:04',
#     'user': {'id': 'gzwcmN4nOgFw09laP3wMJA',
#      'profile_url': 'https://www.yelp.com/user_details?userid=gzwcmN4nOgFw09laP3wMJA',
#      'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/hMMP0BleGSo-TtjfWvehGw/o.jpg',
#      'name': 'Sarah R.'}}],
#   '2-z6dRAkKupCyz1LF251pQ')]

# %%
responses=[]
for business in df['Id'][:10]:
    url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
    try:
        response = requests.get(url, headers=headers)
        responses.append((response.json()['reviews'],business))
    except:
        continue
return responses
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-3f47a60dd7c0> in <module>
#       1 responses=[]
# ----> 2 for business in df['Id'][:10]:
#       3     url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
#       4     try:
#       5         response = requests.get(url, headers=headers)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     904             return self._get_values(key)
#     905
# --> 906         return self._get_with(key)
#     907
#     908     def _get_with(self, key):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py in _get_with(self, key)
#     911             # _convert_slice_indexer to determine if this slice is positional
#     912             #  or label based, and if the latter, convert to positional
# --> 913             slobj = self.index._convert_slice_indexer(key, kind="getitem")
#     914             return self._slice(slobj)
#     915         elif isinstance(key, ABCDataFrame):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/numeric.py in _convert_slice_indexer(self, key, kind)
#     382         # We always treat __getitem__ slicing as label-based
#     383         # translate to locations
# --> 384         return self.slice_indexer(key.start, key.stop, key.step, kind=kind)
#     385
#     386     # ----------------------------------------------------------------
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4964         slice(1, 3, None)
#    4965         """
# -> 4966         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    4967
#    4968         # return a slice
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5171         end_slice = None
#    5172         if end is not None:
# -> 5173             end_slice = self.get_slice_bound(end, "right", kind)
#    5174         if end_slice is None:
#    5175             end_slice = len(self)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5097                 slc = lib.maybe_indices_to_slice(slc.astype("i8"), len(self))
#    5098             if isinstance(slc, np.ndarray):
# -> 5099                 raise KeyError(
#    5100                     f"Cannot get {side} slice bound for non-unique "
#    5101                     f"label: {repr(original_label)}"
#
# KeyError: 'Cannot get right slice bound for non-unique label: 10'

# %%
yelp_call_rev(url_params_rev)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-a97b52b97462> in <module>
# ----> 1 yelp_call_rev(url_params_rev)
#
# <ipython-input-35-18499cd55752> in yelp_call_rev(url_params)
#       1 def yelp_call_rev(url_params):
#       2     responses=[]
# ----> 3     for business in df['Id'][:10]:
#       4         url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
#       5         try:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     904             return self._get_values(key)
#     905
# --> 906         return self._get_with(key)
#     907
#     908     def _get_with(self, key):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py in _get_with(self, key)
#     911             # _convert_slice_indexer to determine if this slice is positional
#     912             #  or label based, and if the latter, convert to positional
# --> 913             slobj = self.index._convert_slice_indexer(key, kind="getitem")
#     914             return self._slice(slobj)
#     915         elif isinstance(key, ABCDataFrame):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/numeric.py in _convert_slice_indexer(self, key, kind)
#     382         # We always treat __getitem__ slicing as label-based
#     383         # translate to locations
# --> 384         return self.slice_indexer(key.start, key.stop, key.step, kind=kind)
#     385
#     386     # ----------------------------------------------------------------
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4964         slice(1, 3, None)
#    4965         """
# -> 4966         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    4967
#    4968         # return a slice
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5171         end_slice = None
#    5172         if end is not None:
# -> 5173             end_slice = self.get_slice_bound(end, "right", kind)
#    5174         if end_slice is None:
#    5175             end_slice = len(self)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5097                 slc = lib.maybe_indices_to_slice(slc.astype("i8"), len(self))
#    5098             if isinstance(slc, np.ndarray):
# -> 5099                 raise KeyError(
#    5100                     f"Cannot get {side} slice bound for non-unique "
#    5101                     f"label: {repr(original_label)}"
#
# KeyError: 'Cannot get right slice bound for non-unique label: 10'

# %%
for business in df['Id'][:100]:
    url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
    response = requests.get(url, headers=headers)
    print((response.json()['reviews'],business))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c7d2c9cc1c79> in <module>
# ----> 1 for business in df['Id'][:100]:
#       2     url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
#       3     response = requests.get(url, headers=headers)
#       4     print((response.json()['reviews'],business))
#
# NameError: name 'df' is not defined

# %%
# review_list = []
# for l in yelp_call_rev(url_params):
#     for review in l:
#         for t in review:
# #             print (t)
#             try:
#                 review_tuple = (l[1],
#                             t['id'],
#                             t['text'],
#                             t['rating'],
#                             t['time_created'])   
#     # add each individual business tuple to our data container
#                 review_list.append(review_tuple)
#             except:
#                 continue
# review_list
# Out:
# [('uazg6WhYVOw3jhWCG_MDBg',
#   'eoqQ6cSoPLOd7YWAjWNS4A',
#   'Sadly due to Covid 19 disaster , we avoid eating in restaurant, however we end up checking out nearby restaurant and trying out new places for take out.\nOne...',
#   5,
#   '2020-12-25 15:29:31'),
#  ('uazg6WhYVOw3jhWCG_MDBg',
#   'jth1qrL_taRqkxNe0r5xSw',
#   'Sup Thai Kitchen was recommended by our friends and they insisted we should give them a second try. We visited again and did indoor dining on a Friday...',
#   5,
#   '2020-11-14 18:27:22'),
#  ('uazg6WhYVOw3jhWCG_MDBg',
#   'qZbZ7qQ8omuIMgq-Ju5adA',
#   'Sup   means treasure/asset in Thai and this restaurant is such a treasure in Fresh Meadows! The Thai food here is amazing. The dishes are fully cooked and...',
#   5,
#   '2020-11-08 17:15:23'),
#  ('cegA4jf16vEt7NCQ7cpu2w',
#   'rKMbqLwkCBIuh6KXE7jxlA',
#   "I have been ordering from here via Uber eats during COVID. I also went to pick up my own food once, when I wasn't being lazy & I must say, their drink menu...",
#   5,
#   '2021-01-05 03:06:27'),
#  ('cegA4jf16vEt7NCQ7cpu2w',
#   '-MzURutxJoE3hK_QAi3LEQ',
#   'This is my top thai spot for dining-in and delivery. My favorites are the duck pineapple curry. Their appetizers are also delicious. Their pad see ew is...',
#   5,
#   '2020-12-05 19:14:25'),
#  ('cegA4jf16vEt7NCQ7cpu2w',
#   'vQMcfci8zprENUzESEg4og',
#   "I've eaten here a few times in person pre COVID\n\nfood: food is always amazing. With a group of friends with a few dietary restrictions there is never anyone...",
#   5,
#   '2020-12-27 14:48:07'),
#  ('0L03onqNwxWLrbb_FCK79A',
#   '58NlugJSPZkGRDZtZ_Xnbw',
#   'No Woodside/Sunnyside food crawl would be completely without Thai food. SirPraPhai is a must-hit (and judging by the 2300+ reviews, it seems like a ton of...',
#   5,
#   '2021-01-31 14:17:23'),
#  ('0L03onqNwxWLrbb_FCK79A',
#   'DY895QKPCPEFG1x2ZicPOw',
#   "I've been a regular here all these years while  living in the neighborhood and always find a time to eat here every time I come back. I come here so often...",
#   5,
#   '2020-11-12 00:08:31'),
#  ('0L03onqNwxWLrbb_FCK79A',
#   'EgSkZxmR3CP3nB8nI2sMsg',
#   "I can't even remember the last time I had Thai food (thanks, COVID) so was stoked when my friend had suggested SriPraPhai for a weekend lunch.  The front of...",
#   5,
#   '2020-10-29 11:44:20'),
#  ('gr3wUszE1972q0GBkmwEXQ',
#   'i6x_ReJ8oAOqeuwbyiGR1w',
#   "Solid thai restaurant in this neighborhood. It's as close to authentic as you can get around here if you don't want to drive all the way to woodside. Had...",
#   5,
#   '2021-01-24 13:32:21'),
#  ('gr3wUszE1972q0GBkmwEXQ',
#   'wXvalumUKcLZwKi7ElOMIw',
#   'Ordered delivery through Yelp and boy, the food was delivered REAL fast! I was so surprised! Food came hot and is neatly packed. Had the pork pad thai &...',
#   4,
#   '2020-12-26 14:26:17'),
#  ('gr3wUszE1972q0GBkmwEXQ',
#   'RY9smdBoCiofxGEQZ95vTw',
#   'Silver lining during the pandemic is they now have outdoor seating:-) Came here for a drink and enjoyed my first mojito with freshly grated ginger $8 during...',
#   5,
#   '2020-09-29 14:35:59'),
#  ('1ubEg-rrSE8IWXl6lJzIGw',
#   'M5vohQ5yotNe5MsfqzouVw',
#   'ordered chicken pad thai, vege spring roll, about 18 bucks. (take-out)\n\nvege spring rolls on spot, crispy deep fried skin, tasty filling (cabbage, carrot,...',
#   4,
#   '2020-10-25 23:47:21'),
#  ('1ubEg-rrSE8IWXl6lJzIGw',
#   'uVC8PF2BelIf3SEvNwLQTQ',
#   "This place is great. Haven't been inside the restaurant, only ordered delivery. So glad that they deliver pretty far, within a great time frame. Food always...",
#   5,
#   '2021-01-05 18:49:35'),
#  ('1ubEg-rrSE8IWXl6lJzIGw',
#   'Vxp467OjvlwfcB9bSt_0IA',
#   'Very glad they deliver during stay at home orders. Solid lunch special food wise and price wise. I ordered 2 lunch specials: beef pad see ew and red curry...',
#   5,
#   '2020-05-20 11:21:39'),
#  ('-YazuZbXAM_NOny8LpLQpQ',
#   '8aEoBuu3zRDs0bKjZOWuCw',
#   'One of my favorite Thai restaurants in queens. Due to the pandemic indoor dining is suspended for now and there is no outdoor dining. You can call ahead and...',
#   5,
#   '2021-01-11 07:04:57'),
#  ('-YazuZbXAM_NOny8LpLQpQ',
#   'TPjQRT-7e34tQUKtTxLAaA',
#   'BKNY us like a staple of the neighborhood.  Although it looks small from the outside, the place is utterly big on the inside. \n\nDuring these pandemic times,...',
#   4,
#   '2020-11-28 04:45:49'),
#  ('-YazuZbXAM_NOny8LpLQpQ',
#   'eW6udNV6rS8-JjF_nXQNpA',
#   "My favorite Thai restaurant- pretty sure if you live in queens you've been here. If you haven't run there now. They have accommodated for covid guidelines....",
#   5,
#   '2020-11-28 22:41:23'),
#  ('3GMHPnrkFAcqffw3T7JSdQ',
#   '2mr1Z2k1_qk44lFCpEMHvA',
#   'Since my initial visit this place has become a decent go to place for some Thai food in Queens. \nDrinks I tend to always go with the White or Red Lychee...',
#   5,
#   '2020-05-20 11:17:33'),
#  ('3GMHPnrkFAcqffw3T7JSdQ',
#   'UVIkwX9ZdDt6NuewjEsfwQ',
#   "Beautiful indoor decor and outdoor dining area. Food is delicious and very flavorful. COVID guidelines aren't strictly followed and staff was very friendly!...",
#   5,
#   '2020-11-30 14:07:23'),
#  ('3GMHPnrkFAcqffw3T7JSdQ',
#   'dq_cqLzm9OiT53UpCTKx1g',
#   'Very decent Thai priced extremely low for how good the food is! A must try in the Jackson heights area. They have a great space and their takeout is good too!',
#   5,
#   '2020-10-10 18:05:53'),
#  ('fRO4Fwe5uRAajMcTwLbVkA',
#   'v77r6EpHGmXCeveVeSyLLA',
#   "I've been a frequent customer since i discovered this place 10 years ago. Dine in area is small on the inside but the quality if food makes up for it. They...",
#   5,
#   '2021-01-14 16:28:58'),
#  ('fRO4Fwe5uRAajMcTwLbVkA',
#   'K5AWeCkdoQo-GyEzq_l5EA',
#   'Delicious. \n\nI called for pickup on NYE and it seemed busy because they had to put me on hold while taking another persons call. Order was ready for pick up...',
#   5,
#   '2021-01-02 18:26:38'),
#  ('fRO4Fwe5uRAajMcTwLbVkA',
#   'opMB5flfd9v-YN7dFJQpFw',
#   'Got delivery the other day. My wife and I enjoy Thai food and ordered a bunch of items. Everything was delicious and the spice level just as ordered.. The...',
#   5,
#   '2021-02-15 11:30:15'),
#  ('a-Bq_yXFVk2PptoWpmry3w',
#   'CrA0SPuLWPShVSSu_GCskw',
#   'I have been to this restaurant pre and post-COVID and both experiences have been so enjoyable. The outdoor patio is nicely decorated with a small fish pond...',
#   5,
#   '2020-12-30 15:27:21'),
#  ('a-Bq_yXFVk2PptoWpmry3w',
#   'skq5LzqCFvChew3yDY5AmA',
#   "This place makes my belly happy. Add it to your list for authentic and flavorful Thai dishes that don't shy away from bolder spice levels. In my experience...",
#   5,
#   '2020-12-28 22:03:26'),
#  ('a-Bq_yXFVk2PptoWpmry3w',
#   '5FYhEHsPK6gZHeiC9DkUdA',
#   'Came to Astoria on a random whim and then decided to check out Pye Boat Noodle due to its overwhelmingly positive reviews, and it was so worth it. I loved...',
#   5,
#   '2020-11-23 18:46:08'),
#  ('5pzc2GdvdmqiLRSdjHnnKw',
#   '7GUSPGxM2ZMfUkPshrqYgA',
#   'The place was nicely decorated and the tables were all sectioned with plastic sheets for patron safety.  \n\nWe did takeout and ordered red curry, curry puff,...',
#   5,
#   '2020-12-30 05:29:51'),
#  ('5pzc2GdvdmqiLRSdjHnnKw',
#   'skZsLBra8UNdz5XAB3_uew',
#   'Came here to dine in for lunch (next week NYC is reverting back to takeout/outdoor dining).  There was temperature check and every table had a divider....',
#   5,
#   '2020-12-12 00:18:51'),
#  ('5pzc2GdvdmqiLRSdjHnnKw',
#   'qp2-A_qxOkpdsZN7egF2MQ',
#   "Best Crabby Poo!\n\nOne of the best Khai Jeaw Poo - Crab Omelette I've ever had.  The omelette itself is fluffy, light, and rolled up just like a famous...",
#   5,
#   '2020-09-22 21:19:26'),
#  ('oNN202L_XcNM-tuDHlgkfg',
#   'ur27etyZaSGtA4qR99Zn-g',
#   "Takeout doesn't take long and food is always on point! I always get the thai sausage fried rice and thai icetea. Perfect lunch or dinner meal.",
#   5,
#   '2021-02-10 10:45:38'),
#  ('oNN202L_XcNM-tuDHlgkfg',
#   'aJONEQBbsgq4g8hdKICfVQ',
#   'I order here almost every week / every other week and they never fail to satisfy! They must recognize my number because when I call they already know my...',
#   5,
#   '2020-09-13 13:15:35'),
#  ('oNN202L_XcNM-tuDHlgkfg',
#   'yvbptjzAd8JLdvo8QFFeMQ',
#   'I ordered takeout crispy pork over rice...well packed and hot too. Thank you for being there in this difficult times.....',
#   5,
#   '2020-11-11 09:23:19'),
#  ('1svF14BUYt_Wc0XA3nMxdw',
#   'ZemrPEYlwFcespHMaLaK_A',
#   "This is a nice take out Thai place I ventured today. When it comes to Thai food, the essence is in sauce or the base. And that's the main reason driving my...",
#   5,
#   '2021-01-31 15:58:58'),
#  ('1svF14BUYt_Wc0XA3nMxdw',
#   'E7EWJ7H49zW9uf9dZKrprQ',
#   'Ordered dinner for pick up for the first time and we were so pleasantly surprised! Not only was the pick up process seamless and contact less, my order was...',
#   5,
#   '2020-04-15 16:43:31'),
#  ('1svF14BUYt_Wc0XA3nMxdw',
#   'UvGq5WCmSI_dE2NK1Ai5Rg',
#   "We've tried their lunch specials twice now.  Both have been excellent.  Really tasty and very reasonably priced.  \n\nThe previous Thai restaurant at the same...",
#   5,
#   '2020-03-23 20:08:09'),
#  ('PPQSf_1JWkbjFHi1S0nSNA',
#   'O9yL3y-CtidLd_olvwdStQ',
#   "Lamoon is bomb every single time. Their food is not commonly found in Thai restaurants so it's a must try. Also it's a smaller family owned place so their...",
#   5,
#   '2020-09-09 18:04:52'),
#  ('PPQSf_1JWkbjFHi1S0nSNA',
#   'QRhRuOg8qS4_sx25JGkuLQ',
#   'Very decent Thai priced extremely low for how good the food is. A must try in this area. They have a great space and their takeout is good too!',
#   5,
#   '2020-10-23 00:01:35'),
#  ('PPQSf_1JWkbjFHi1S0nSNA',
#   'pXD1leSKnIcjxI0foGi2nQ',
#   'Without a doubt one of the best Thai restaurants in Elmhurst. It is unique in their creative dishes and the flavors are so fragrant once the food hits your...',
#   5,
#   '2020-08-23 11:27:54'),
#  ('tVB11pOiDhPWlt_o6ylMNg',
#   'ENpZtfYbTpr-5fq0fyQadQ',
#   "Everything you've read about their Tom Kha soup is legit. It is delicious! The only caveat is sometimes they change up the vegetables, so once I got...",
#   5,
#   '2021-01-14 10:49:47'),
#  ('tVB11pOiDhPWlt_o6ylMNg',
#   '3PZc_8E5VdIWtBlJsrOg9g',
#   "Enthaice is one of our favorite Thai restaurants in the neighborhood. We've been inside a few times and with the pandemic, we order every few weeks. Fun...",
#   5,
#   '2020-12-09 20:50:23'),
#  ('tVB11pOiDhPWlt_o6ylMNg',
#   'm5701KTLVmKMWQhMk6VnTA',
#   "Please note: My first experience with them is during the coronavirus so (a) I only did takeout (b) I'm extremely biased for businesses that are serving...",
#   5,
#   '2020-04-08 19:24:31'),
#  ('Ve_iFpnhL8zN789ZL2jnxQ',
#   'f0ATdrZ_5ArYzCqjBLrkDg',
#   'This is our "go to" neighborhood Thai spot.  Delivery is always quick.  Food is always great and consistant.  The portions are good.  The Basil fried rice...',
#   5,
#   '2020-09-07 15:54:29'),
#  ('Ve_iFpnhL8zN789ZL2jnxQ',
#   '6z-FxlqDhFj6ewSoXo8Rog',
#   'This Thai spot is a local gem. We just moved to the area and had been avoiding thai food because our takeout thai food experience were hit or miss, mostly...',
#   5,
#   '2020-07-22 06:13:54'),
#  ('Ve_iFpnhL8zN789ZL2jnxQ',
#   'yymp-hyaIz-zis-ZZMYptA',
#   'Fairly friendly and reliable Thai in the neighborhood. Actually the only Thai in the confines of Rego Park. Delivery is fast and friendly too.  Should out...',
#   4,
#   '2021-01-02 17:50:12'),
#  ('inftQdKaEEiqQ323AlomXg',
#   'f1CPBedDZzqPyApc1c_5Pw',
#   "Whoa, whoa, whoa, whoa. I haven't written a review for Dek Sen yet?! Get outta here!\n\nDek Sen is one of my top Thai restaurants in NYC. Period. I love this...",
#   5,
#   '2021-01-11 15:52:44'),
#  ('inftQdKaEEiqQ323AlomXg',
#   'CgwoBy5F8SxTw3gEquXv_Q',
#   'Ordered delivery a couple food, noodle and papaya salad. The food is fresh and still hot when arrived to my house. The delivery is on time. All food i...',
#   5,
#   '2021-02-07 22:38:19'),
#  ('inftQdKaEEiqQ323AlomXg',
#   'g0aAQEgi1AldvgmhTJRHnQ',
#   "AMAZING AND A MUST if you're in Elmhurt!\n\nFood 5/5\nLove all of it. My noodles were spicy and packed with flavour. The desserts were the bomb! The thai iced...",
#   5,
#   '2021-01-11 17:42:55'),
#  ('a23bfZBVjIhV32Em4hKHAA',
#   'fR_5_5oJzmy6AijwmbB-SQ',
#   "I picked up takeout this weekend, and was glad to see that pickup is through a walk-up window, so you don't have to go inside. Great for COVID safety, and...",
#   5,
#   '2021-01-24 19:02:53'),
#  ('a23bfZBVjIhV32Em4hKHAA',
#   'cDKXVbWDI-GX1Y7KLOe5Bw',
#   'I started ordering from The Buffs in Spring 2020 and have enjoyed their consistently good food and friendly service. So happy to have them in the hood! Got...',
#   5,
#   '2020-12-30 16:43:44'),
#  ('a23bfZBVjIhV32Em4hKHAA',
#   'hjZed0sRkrQjcvWKTGTFyQ',
#   "Quick and tasty! My go to spot. The pad Ew is my favorite. Nice prices. I always pickup because it's quick and I love hot food",
#   5,
#   '2021-01-01 15:57:00'),
#  ('CpY77cDN1KS5EdiXMmWovw',
#   'LB-vDrxlZg5A2ki-M94Hgw',
#   'Limited indoor seating w sanitation protocols and social distancing practices.\n\nStart off by saying the staff is EXTREMELY POLITE and ATTENTIVE. No frequent...',
#   4,
#   '2020-12-09 10:50:56'),
#  ('CpY77cDN1KS5EdiXMmWovw',
#   'aGGCPjH0rQpnf7iH6R_SCA',
#   'Great spot for Thai food and outdoor dining during COVID if you live nearby. The curry is good but not the greatest. Chicken could be better. Thai tea is...',
#   4,
#   '2020-08-04 11:21:08'),
#  ('CpY77cDN1KS5EdiXMmWovw',
#   'Mr5GcIhCiTKA9yM1IQk9Pg',
#   'An absolutely phenomenal Thai restaurant in the heart of Astoria/LIC. Beautiful ambience inside sets an elegant tone in a quiet, romantic setting. Also...',
#   5,
#   '2020-05-22 12:29:39'),
#  ('PyaeHq_UAu6nazGiy0XAnw',
#   'RPBU_MB1oA_OeGLKxuAwuQ',
#   "I've been here 2-3 times before (before Covid) and just got take out this past weekend. I've always liked the pho broth here because it tastes really...",
#   5,
#   '2020-11-24 20:04:21'),
#  ('PyaeHq_UAu6nazGiy0XAnw',
#   'bOByutiN5Ju8wvIGQR6_6A',
#   'Been here twice now and they now have a cute outdoor seating area. The curbside dining area is built well with a nice tent over the whole thing to block out...',
#   4,
#   '2020-11-01 07:23:32'),
#  ('PyaeHq_UAu6nazGiy0XAnw',
#   'usJTsSY0w5duOJaEzp7lJA',
#   "Cute little vietnamese/thai fusion gem in Whitestone! Came here on a Sunday, they don't take any rsvp but it was fairly packed with some empty tables at...",
#   4,
#   '2020-11-02 09:49:59'),
#  ('yCJHIM-PWl54K53ACOpoNg',
#   'F48QgpQ1mIYebGN7YL-z8Q',
#   "Spicy is NO BS here! Unique and delicious Northeastern Thai food is the true experience here, if you're looking for typical Thai dishes like Pad Thai - not...",
#   5,
#   '2021-02-08 17:59:14'),
#  ('yCJHIM-PWl54K53ACOpoNg',
#   'HT0RsyQQzsrDMhLFi_Ynng',
#   "This soup was so flavorful, noodle were soft, pork was so tender. It's call Khao Piak Sen. I ordered for delivery they're pay attention with the package,...",
#   5,
#   '2020-07-06 16:06:31'),
#  ('yCJHIM-PWl54K53ACOpoNg',
#   'hPDXj6pB-xs3HuvJBChTiA',
#   '**Delivery Review**\n\nOne of the many Thai restaurants within radius in the neighborhood. Fairly quick delivery window of 25 minutes and a wide array of...',
#   4,
#   '2021-02-09 08:35:08'),
#  ('m2_ZNFos5ugAwe8ft8eaEw',
#   'jDZXLRosH_w3nSf-7mFI2A',
#   'Been wanting to try this fine establishment for very long time now and since my friend lives close, so we ordered Set 3 for take out, which is perfect for 3...',
#   5,
#   '2020-11-22 15:32:40'),
#  ('m2_ZNFos5ugAwe8ft8eaEw',
#   'HogaNCsoKomVtAv0SppS5g',
#   "PRO TIP - CASH ONLY!!\n\nYou literally cannot get better Hainese Chicken in NYC other than this place! It's the only thing they sell and there's a reason why...",
#   5,
#   '2020-08-26 12:25:44'),
#  ('m2_ZNFos5ugAwe8ft8eaEw',
#   'SHTYj5Avh7f9jCEqo0THlA',
#   "Hands down the best Hainanese chicken over rice I've had. \n\nI've had this place bookmarked for a while now and I finally had the chance to try it out. I...",
#   5,
#   '2020-06-28 12:40:58'),
#  ('kXuubLd6s3GidpqU3psPdw',
#   'W_CdVh_zFZdLHsUoSLuBNw',
#   'Really gonna miss ordering from this place twice a week, no shame. Consistently really flavorful, large portions for 10-13$. The people are super nice too!...',
#   5,
#   '2020-12-26 13:44:25'),
#  ('kXuubLd6s3GidpqU3psPdw',
#   'AaFwyAfg5pc7eFBrSJiu-g',
#   "Hole in the wall? Talk about literally. Raw shrimp salad. 10 stars. Very authentic & the food is just the best I've ever had. Last time I ordered it was...",
#   5,
#   '2020-11-21 18:40:22'),
#  ('kXuubLd6s3GidpqU3psPdw',
#   '5ZWC6fSnlm0ESDydfv4JMQ',
#   "Elmhurst is really the spot to go for you're craving Southeast Asian or East Asian cuisines. I've came here multiple times pre-Covid and it's a small...",
#   5,
#   '2020-10-30 13:20:39'),
#  ('hA5QUlrSjpxMZ90Kof0bgA',
#   'lXlHP1teDHsX20QXMyYBVw',
#   "I LOVE THIS SPOT! \n\nKhao Kang has been a reliable place to get food for lunch or dinner for me. This spot is like Chinese rice box places but it's with Thai...",
#   5,
#   '2020-11-24 16:34:03'),
#  ('hA5QUlrSjpxMZ90Kof0bgA',
#   'Tao8ebqBVO0mMmGt2lSDdw',
#   'This is another place that I bookmarked a really long time ago but  never went...until now!  Wow, what have I been missing?!?!  This is such a gem.  I will...',
#   4,
#   '2021-01-14 14:16:36'),
#  ('hA5QUlrSjpxMZ90Kof0bgA',
#   'GCjo5Cf1TIH0RjI3vL-qGw',
#   'This spot is great, everything others have written about authenticity, service and price is spot on.\nI would like to make one small point that I hope they...',
#   4,
#   '2020-10-18 08:12:07'),
#  ('zRQNaDUoWTInc2tqndSJVA',
#   'fOR8Bbi_0hhAzJeeCvB0wA',
#   "The Thai food was pretty good. I decided to try this new delivery spot as I wasn't impressed with the other Thai restaurants (or more like Asian fusion...",
#   4,
#   '2020-07-09 20:23:56'),
#  ('zRQNaDUoWTInc2tqndSJVA',
#   'X1kylbWB7o4WkC6hdKfXJA',
#   'I have been to this place 2-3 times and I have never been disappointed. Even during COVID, they kept their lunch menu which is an amazing deal! $10 for an...',
#   5,
#   '2020-10-26 14:32:02'),
#  ('zRQNaDUoWTInc2tqndSJVA',
#   'y9ttwwJUqzHlc-KijL-BnQ',
#   'This place is open for takeout and pickup during the coronavirus quarantine! And they even offer their awesomely priced lunch special. The green curry was...',
#   5,
#   '2020-03-28 21:43:16'),
#  ('rehmlZmUNL2AthW-VTXJJQ',
#   'npD3KUZEB4T27LQS-ZOKgQ',
#   "I'd rate tasty Thai four and a half stars.\n\nWe ordered takeout through a delivery app. I ordered the tom yum soup with chicken. The broth was very flavorful...",
#   5,
#   '2021-02-06 17:43:24'),
#  ('rehmlZmUNL2AthW-VTXJJQ',
#   'IwvxtTWjbaZ9jevlMTBpWA',
#   'As a vegetarian this is my FAV thai place to order from. I have yet to go in person due to covid but everytime I am craving thai food I order delivery from...',
#   5,
#   '2020-09-06 15:19:19'),
#  ('rehmlZmUNL2AthW-VTXJJQ',
#   'ie0kpEcwq7QB9qq_6gdlQA',
#   "Best vegetarian mock duck I've ever tasted!!! The imitation duck salad is my go to. Highly recommend for veg and non-veg alike! Also the tum yum soup......",
#   5,
#   '2020-09-01 06:02:03'),
#  ('a5H9p1B6m6WPVjakPylvdA',
#   'SWfdFkY2Fs6nlWd6EVx3xg',
#   'I ordered delivery so many times. My first time to dine in does not disappoint me. Everything is done properly. Seafood is cooked just right. \n\nTheir...',
#   4,
#   '2020-09-02 17:25:16'),
#  ('a5H9p1B6m6WPVjakPylvdA',
#   '9AUjXR_e3Oof2nYqxT6fAQ',
#   "I've been coming to Spicy Shallot for quite some time. Previously, the food here was mediocre. However, we recently went for outdoor dining during the...",
#   4,
#   '2020-07-17 11:06:09'),
#  ('a5H9p1B6m6WPVjakPylvdA',
#   'gTD55Z1DuC6VwS9S1NRYKg',
#   'Always my go to Thai restaurant in my neighborhood even with all the other choices of Thai around. They have great lunch menu deal. Since COVID, they have...',
#   5,
#   '2020-11-04 11:45:14'),
#  ('toykv8K0yg8qtvZSXRQ5bg',
#   '57MJPP3pM3Yhtfll-PkHfQ',
#   "I love Pochana. It's affordable, the food's good, and the decor is so cute and cozy. It has plenty of seating for couples but can't really seat too many...",
#   5,
#   '2020-10-21 19:07:24'),
#  ('toykv8K0yg8qtvZSXRQ5bg',
#   'JJMFLXMC9m3CLf1KkZrJ2w',
#   "I ordered pickup via phone from Pochana for the first time recently and was pleased! It was a bit surprising that they didn't take any other information...",
#   5,
#   '2020-06-26 10:31:23'),
#  ('toykv8K0yg8qtvZSXRQ5bg',
#   'YMXXZEgUro4xBwZViDI6ug',
#   'Got this for take out during COVID. Everything was delicious! Especially the duck noodle soup - so good a must try!! The beef stew and the hen were great too!',
#   5,
#   '2020-06-21 16:21:30'),
#  ('OR9oqAJW-U5ZnqhwH12Nuw',
#   'MjPrXhDCb3AH4t1wLarScQ',
#   'Cutest shop ever! Ive been here before covid and its always packed! Its sad to see it at 33% capacity. \n\nThey have heated outdoor seating with plenty of...',
#   5,
#   '2020-11-19 17:30:22'),
#  ('OR9oqAJW-U5ZnqhwH12Nuw',
#   'i8Z4nx2peEvntMdpow1cVw',
#   'I literally order take out from this place every week since I live a couple blocks away. The value of the meal definitely unbeatable. Crispy pork  Kraprao...',
#   5,
#   '2020-10-22 12:39:23'),
#  ('OR9oqAJW-U5ZnqhwH12Nuw',
#   'x299XjQOc8JK57jSj4OCxg',
#   'Khao Nom is one of best Thai restaurants in the neighborhood. The interior decor is simple and lovely with vintage style adornment. We had a lunch with...',
#   5,
#   '2021-02-03 20:32:56'),
#  ('YMcDo3UccCPvIJrQ5Yt9Yw',
#   'q5OXL0P1PsHGuS0xzPUKjg',
#   'O.M.G. ......,So delicious and worth the price.\nCheck the GRUB-HUB MENU photo.\n\n     They are the best with ACCURACY to DETAIL for Asian cuisine delivery!!...',
#   5,
#   '2020-06-08 19:08:13'),
#  ('YMcDo3UccCPvIJrQ5Yt9Yw',
#   'iwsx9DPXNu1wkWEgEKlBNg',
#   'Very good food and nicely portion. One of my favorite places to order Thai food. Delivery is great and food very well packaged.',
#   5,
#   '2020-08-28 17:22:07'),
#  ('YMcDo3UccCPvIJrQ5Yt9Yw',
#   '81HuGUuiJ7Qc4Y0pQZMJRg',
#   "This spot is great. I've only ever ordered take out from here via Doordash. And they always follow my instructions with the orders far as no egg and brown...",
#   5,
#   '2020-10-08 16:15:21'),
#  ('8-dc942sz-prIeepAkHLJA',
#   'GoXFK9TQgvipnwoBFszm7A',
#   'This is the best Thai food in the area. There are closer and cheaper options, but I usually go for zenith because the food is just incredible.\nGet the...',
#   5,
#   '2020-12-11 20:50:37'),
#  ('8-dc942sz-prIeepAkHLJA',
#   'ZQZXF9kHS0LIuj9LdFVdeQ',
#   'One of the best Thai food restaurants. The food is the best and staff is very cordial. I already introduced this place to friends who have already ordered...',
#   5,
#   '2020-12-20 13:42:38'),
#  ('8-dc942sz-prIeepAkHLJA',
#   'jyj28tfvYi1JMNRnwVdbbA',
#   'Great food...fast service...highly recommend.\nDrunken noodles delish as well as wok eggplant.\nGood portions...pleasant staff and safe delivery',
#   5,
#   '2020-08-25 18:15:19'),
#  ('dnCRiUZWgu5ZI4Q-Z-az6Q',
#   'DQCVYtn4WGeqkOGZ9vJLug',
#   'This is our favorite restaurant to order from! We are so lucky that we live next to this place. My fiancé and I love to pick up our regular orders for...',
#   5,
#   '2020-04-24 17:35:26'),
#  ('dnCRiUZWgu5ZI4Q-Z-az6Q',
#   'p6icQ4RdHYmiRA92xquEnw',
#   "Probably the best Thai restaurant in the neighborhood.  Wish they were closer to me or I'd order from them more often (usually order from Vera Thai as it's...",
#   5,
#   '2021-01-15 13:03:42'),
#  ('dnCRiUZWgu5ZI4Q-Z-az6Q',
#   'lyat0zTeLXzdEThKEQKIoA',
#   'My favorite Thai restaurant in Queens. So yummy, great value, and clean! \nThanks guys!! You guys definitely makes these days much easier :)',
#   5,
#   '2021-01-21 12:00:44'),
#  ('ipxeCjihDqXTMkuPe-CQ4A',
#   'Fl3T676Uz86HAYrF5QdqPQ',
#   'The best Thai food in Queens. I love the pad puck, coconut rice, chive dumplings, pad Thai with tofu, FRENCH FRIES and an ice cold Singha. Service always...',
#   5,
#   '2020-05-13 17:58:23'),
#  ('ipxeCjihDqXTMkuPe-CQ4A',
#   'dbDTHwg0cyLeOLpptx2qFA',
#   'Really love this thai spot, came here with my parents bc my parents always want thai. But it was so good I had to bring my friends to try here too (this...',
#   5,
#   '2020-11-16 15:30:51'),
#  ('ipxeCjihDqXTMkuPe-CQ4A',
#   'jl2hi0H-yOEBIHYJLjpxHw',
#   'I had the red curry, Panang. I ask them to make it extra spicy. It was delicious! I am so happy there was leftovers for the next day. It was even better.',
#   5,
#   '2021-01-23 08:21:25'),
#  ('1wdJ1vJR_Z1vJebQGlZU3Q',
#   'SpfHB3ddhyA5mK9y5pRz_Q',
#   'Love getting their food and Thai iced teas! Usually order takeout but indoor dining is great as well! The serving portions are just right!',
#   5,
#   '2020-10-21 17:53:03'),
#  ('1wdJ1vJR_Z1vJebQGlZU3Q',
#   'Hsy0zshTg9smdgLXOzqyiQ',
#   "Best Thai food I've had in the local area. Ordered from here via DoorDash 2 nights in a row :) ad many times thereafter... everything is packaged well and...",
#   5,
#   '2020-10-31 17:31:45'),
#  ('1wdJ1vJR_Z1vJebQGlZU3Q',
#   '2jky2lfMo22eaa6ScddyGg',
#   'Work at Northwell for eight years and have been meaning to go. My nurses recommend it highly. I got takeout yesterday. It was really good. Also no stomach...',
#   5,
#   '2020-12-24 10:04:15'),
#  ('ET4xGd-SQ6gs9lce4xVpQg',
#   'VOzVkwjZXPt8r__Gcz8o7w',
#   "With all the madness happening in the world today it's such a good feeling when you can sit down and dig into some food that makes you forget all your...",
#   5,
#   '2020-11-30 05:34:23'),
#  ('ET4xGd-SQ6gs9lce4xVpQg',
#   'drpNhTqB-nj6JyhzqQ9_3w',
#   "My house was slightly out of their delivery zone so I decided to braze the cold and jump on my bike. They definitely don't skimp on portions as the to-go...",
#   5,
#   '2020-11-24 10:26:54'),
#  ('ET4xGd-SQ6gs9lce4xVpQg',
#   'uCztNrWwl-BOn2SNbhvi4A',
#   'In the midst of COVID, I had an awesome restaurant experience. \n\nThe seating was separated by plastic partitions. The staff all wore mask. Hand sanitizer...',
#   5,
#   '2021-01-06 02:59:16'),
#  ('Eyn7hQENF8R9DrBwBHO6lQ',
#   'pQdaEq3YC_moLfWXAGBi9g',
#   'Had this over the summer (so like 5 months ago?) for take out. The noodle portion was smaller than some other places but they were generous with the shrimp....',
#   5,
#   '2021-01-23 07:15:13'),
#  ('Eyn7hQENF8R9DrBwBHO6lQ',
#   '1yZKM_SlH_YOUZq3zhxOvQ',
#   "By far one of the best Thai food restaurants I've been to. I think what makes this place special is that grandma is throwing down in the kitchen. Her and...",
#   5,
#   '2020-12-31 16:03:02'),
#  ('Eyn7hQENF8R9DrBwBHO6lQ',
#   'oAjV286M8JT00Jd7BTvyvw',
#   "I wish I like this place but unfortunately they don't treat their customers nicely.  The woman answered the phone was cold and didn't seem to care about...",
#   1,
#   '2020-12-25 11:51:08'),
#  ('JX5QkNfMd-jP-Nz5iQ_QeA',
#   'r6rsh6MA1cJCCzsuU5StIA',
#   "My first time here was pre covid, inside it's a friendly and humble place. Ive been back many times recently for take out and it's great every time. I've...",
#   5,
#   '2020-08-06 20:06:44'),
#  ('JX5QkNfMd-jP-Nz5iQ_QeA',
#   't9OdBJlXU5QfygVKz0gFNQ',
#   "The food is delicious. Asked for my Pad Kee Mao to be extra spicy and it was! Chicken satay and accompanying sauces were probably the best I've had. Ordered...",
#   5,
#   '2020-09-27 11:43:25'),
#  ('JX5QkNfMd-jP-Nz5iQ_QeA',
#   'mqI2OwsanOF7RHF9rLhX3g',
#   "Best Thai food ever! Amazing customer service! Definitely coming here every day. Near the subway so it's very easy to locate as well.",
#   5,
#   '2021-02-09 17:09:34'),
#  ('nu239sXQUGjcGFhZ3AdJmQ',
#   'rO4HYCufW2MmzUWnor6nEA',
#   'Covid outdoor dining was a mixed review. Food was delish, but service was pretty dismal. They kept accommodating guests by bringing out more dining tables....',
#   4,
#   '2020-09-27 21:33:45'),
#  ('nu239sXQUGjcGFhZ3AdJmQ',
#   '9U6LD2tqIj3r7raHXo6hdg',
#   'Amazing service as always. The food never disappoints and food was ready for pick up in 15 minutes as per stated. \nKeep up the great service during the...',
#   5,
#   '2020-05-05 15:05:11'),
#  ('nu239sXQUGjcGFhZ3AdJmQ',
#   'zNndNln_vifFbWHjSxmEMA',
#   "My family had a take-out from here today. We liked the beef pad sea-eiw, baby back ribs, pineapple fried rice, and curry puffs. It could've been better....",
#   3,
#   '2020-12-01 20:43:29'),
#  ('2ZBEE_MJeRdLD1NLiNTnCQ',
#   '6k2uo5fUntAfMzUDObc9BA',
#   "Ordered delivery from here last night - Shrimp Green Curry and Pad Khee Mao with Pork, and everything was great! I'm often disappointed in Thai food, as so...",
#   5,
#   '2020-12-19 16:52:33'),
#  ('2ZBEE_MJeRdLD1NLiNTnCQ',
#   'YLFDCkLOWZr4DdOvVsOWVw',
#   "Ordered delivery from here last night - Shrimp Green Curry and Pad Khee Mao with Pork, and everything was great! I'm often disappointed in Thai food, as so...",
#   5,
#   '2020-11-23 09:08:38'),
#  ('2ZBEE_MJeRdLD1NLiNTnCQ',
#   'l5JyXiqjgrcbBy4ViQTQ2Q',
#   'Food: 4/5\nArrived here starving and we ended up ordering way too much food. We ordered a spicy papaya salad, an oxtail soup, a steamed mussel appetizer in...',
#   4,
#   '2020-07-01 20:21:30'),
#  ('khvnn7cpiYSpe80ue5YLvg',
#   'AGhuzYVhtOeJV2UljQXRDQ',
#   'Similar to a nearby thai place (Hero), this place was incredible. We ordered multiple appetizers, entrees and drinks - seated outside on the corner to watch...',
#   5,
#   '2020-10-31 18:17:01'),
#  ('khvnn7cpiYSpe80ue5YLvg',
#   'Flo1FnZ3lQOdenrQsqEqPQ',
#   'Opted to try this spot for takeout after a long day of driving around. The food came super quickly and was still piping hot--the khao soi had been separated...',
#   5,
#   '2020-12-11 17:52:14'),
#  ('khvnn7cpiYSpe80ue5YLvg',
#   'QdisrwhfrCcFuX8GAfyEkg',
#   'So happy to have found a thai restaurant open during this quarantine. I definitely needed my thai fix! My husband and I ordered a pad see ew chicken, pad...',
#   5,
#   '2020-04-19 19:36:57'),
#  ('qrydcGQpeDP_1oFvx3qOeg',
#   '6Uyd4IToAofC-KCUUXEpig',
#   "I used to travel extensively to Thailand in the 1990's.\n\nThe food there is absolutely nothing like the Thai food I was used to eating in the USA. I realized...",
#   5,
#   '2020-11-15 05:07:10'),
#  ('qrydcGQpeDP_1oFvx3qOeg',
#   'DAI0yWKAruaxQKbTaoJPrQ',
#   'I was there last night after had so many oyster with my friend . \n1. Fast service with big smile .\n2. Super clean and conscious about Covid19.\n3. 5 stars...',
#   5,
#   '2020-10-18 23:26:47'),
#  ('qrydcGQpeDP_1oFvx3qOeg',
#   'LIyuhWBeETKkqio4lqmuoQ',
#   "[pre-COVID dine-in review]\n\nShort version: loved it, you can't go wrong, but standouts for me the seafood suki and beef skewers. \n\nAbsolutely loved loved...",
#   5,
#   '2020-08-14 11:20:53'),
#  ('_ArDQIKj5qHgmwNnnIaIIg',
#   'zasyhUBCxctCPl57l9IqgQ',
#   'I Am Thai deliver from their own website for $2 fee www.iamthairestaurant.com\nWe ordered Vegan spicy noodles ( got them medium & they WERE SPICY!) & \nVegan...',
#   5,
#   '2021-01-07 14:44:51'),
#  ('_ArDQIKj5qHgmwNnnIaIIg',
#   'qXqKTsQw4E6dXtaR4x3sOg',
#   'Ordered pad see ew take out and it was delicious! Their website was quick and easy to use. A family member went to pick up the order and said the staff was...',
#   5,
#   '2021-01-22 20:21:28'),
#  ('_ArDQIKj5qHgmwNnnIaIIg',
#   'X59n2o72v2_KUs8rAQQGtg',
#   "This is THE best Thai restaurant in Sunnyside/Woodside! We have tried vegan and non-vegan dishes and we've loved them all - seriously, NOTHING is bad here!...",
#   5,
#   '2020-10-30 16:58:51'),
#  ('QWskQ2QpR8bmza2FRFziOQ',
#   'z1soNSe25e9M5XqDmzhF6Q',
#   "Big menu with lots of options.  All traditional Thai and Chinese dishes are available and as far as I've experienced, they stand up to any quality...",
#   4,
#   '2020-10-01 15:01:00'),
#  ('QWskQ2QpR8bmza2FRFziOQ',
#   'TX4-33AKDlApTv-NxIjywA',
#   'Best take out Chinese food in Forest Hills. The wonton soup was really tasty, boneless ribs were really tasty and the spicy chicken was just the right...',
#   5,
#   '2021-02-12 17:16:42'),
#  ('QWskQ2QpR8bmza2FRFziOQ',
#   '8JnXqpCAcKt9vT8AsgutTA',
#   'This is the only spot in the neighborhood where we order Chinese food from. Always quick delivery. Love their Sesame Chicken!',
#   5,
#   '2021-01-03 18:56:28'),
#  ('D-gd1Gb_Nmc2MN6G0KANMg',
#   'KGpKlILycKbow7ybmVOmmQ',
#   "I'm happy that they have outdoor dining during Covid-19 crisis! The food and service are fast and great. Love the dessert. Highly recommended!!",
#   5,
#   '2020-07-15 17:54:12'),
#  ('D-gd1Gb_Nmc2MN6G0KANMg',
#   'omLTF_3XuFY2ki6C80qtyg',
#   'Delicious appetizers, pad Thai, spicy noodles, and Thai iced tea. Food arrives hot, timely delivery. Great for ordering in Astoria! Extremely considerate...',
#   5,
#   '2020-05-12 11:00:55'),
#  ('D-gd1Gb_Nmc2MN6G0KANMg',
#   'vWpB-siCRdUjMDb4df1Bjg',
#   'BEST Thai food in Astoria hands down. Quick delivery and always hot. This place never misses',
#   5,
#   '2020-08-12 15:52:04'),
#  ('SkYcO8FaqYgoP-66g58OMw',
#   'zCfj_2bTFYSTjNxt8yK54g',
#   "I haven't been here in a very long time but they have been here a while which is usually a good sign. Of course they aren't open for dining in yet but they...",
#   4,
#   '2020-09-20 17:12:33'),
#  ('SkYcO8FaqYgoP-66g58OMw',
#   'hapGaH9eZ_2V9WSZ2FZGAg',
#   "We've been here several times over the past few years. Their dishes and service have been hit or miss but their curries have always been good. My husband's...",
#   3,
#   '2020-09-02 03:49:49'),
#  ('SkYcO8FaqYgoP-66g58OMw',
#   'MtqyEHWXcepg3JyV47PWPQ',
#   'Quick and safe pickup. I ordered a beef pad Thai. The flavor was more on the sweeter side but not bad in flavor. The beef however was a little too chewy...',
#   3,
#   '2020-10-25 07:29:27'),
#  ('B3_K2kUVbYOU0VaLcj_LTw',
#   '1CKI5RATDbfdtAMiGYLMHA',
#   "First things first, I LOVED the venue and I'm not talking about the indoor decor. I absolutely adored the little cabins the restaurant created to house us...",
#   5,
#   '2021-02-05 19:39:18'),
#  ('B3_K2kUVbYOU0VaLcj_LTw',
#   'vJbttqvzPsuRqjkaQ6M5nQ',
#   'I loved this place, honestly. Everything I ate was super flavorful, and exactly what I wanted to be in my stomach. I love Thai food and I wish I had...',
#   5,
#   '2021-01-25 14:53:07'),
#  ('B3_K2kUVbYOU0VaLcj_LTw',
#   'yp4OP3I8wALKaXXylrqReg',
#   'Finally have a chance to try this one! But no indoor dining. Definitely worth to try again after the pandemic. Food is so yummy and big portion! \nVery nice !',
#   5,
#   '2021-02-08 10:47:26'),
#  ('zENn0_yDJEdLoHyivXb2xw',
#   'rwflSCpOnP44eT0p7VZI0w',
#   'Decent food, fast delivery, and huge portions. \n\nFood: the food was not the best Thai food. I had the drunken noodles with tofu. The drunken noodles with...',
#   4,
#   '2021-01-14 16:24:24'),
#  ('zENn0_yDJEdLoHyivXb2xw',
#   'c7xpPQyZX42i5cP3SWdbrg',
#   'Stumbled upon this Thai restaurant by wandering Northern Blvd. on a Saturday night. Dimly lit yet inviting interior and a pleasant hostess who seated us...',
#   4,
#   '2020-12-15 09:06:36'),
#  ('zENn0_yDJEdLoHyivXb2xw',
#   'DunsArT0wDJ__YAgl_bTTA',
#   'This Thai restaurant is a small restaurant that packs a mighty punch, imo. During COVID, this is the first time I been to a restaurant and luckily they just...',
#   5,
#   '2021-02-14 19:29:55'),
#  ('bjf8vmAIrdPo1aHoaYPkBw',
#   'lwNdJOOgI53RV0q1VE3AKg',
#   "I really love this spot, it's our go to at work for Thai food. But ever since Covid happened they stopped doing lunch specials. You have to pay full price...",
#   4,
#   '2020-10-29 08:15:53'),
#  ('bjf8vmAIrdPo1aHoaYPkBw',
#   '4pPN2awAu8VQZwP78Tlb4g',
#   'Stopped by on a Sunday evening, had a pleasant experience, the staff was very nice and attentive. Food was on time and delicious , overall a good experience...',
#   5,
#   '2020-10-11 18:35:51'),
#  ('bjf8vmAIrdPo1aHoaYPkBw',
#   'rNQQsPZGjKAbyQSyqTFvDg',
#   'Nice outdoor dining during COVID. Delicious pad see ew - super flavorful but not too heavy.  Great mango with sticky rice!',
#   5,
#   '2020-08-14 19:26:05'),
#  ('9WgsvzaiXNAmmQGD0uQxFQ',
#   'XYau75rutUUL73LsF2vaMg',
#   'I ordered - lunch special Pad see ew for only $9\n noodles were broad and saucy. Perfect balance of soy and sweet and tofu was crispy. \nCame with 2 veggie...',
#   5,
#   '2020-12-06 11:39:38'),
#  ('9WgsvzaiXNAmmQGD0uQxFQ',
#   'BBRGdFcDv3ahbgYsfW_Sjg',
#   'This is the best Thai food I have had. Dishes are flavorful and really well priced. They also have a few delicious cocktails. Obviously take out is only...',
#   5,
#   '2021-01-23 09:01:55'),
#  ('9WgsvzaiXNAmmQGD0uQxFQ',
#   'mhM7ECSaJVzmURJMEDRf2w',
#   'Really solid Thai food!! Portions are big and the food was ready for pick up within ten minutes from placing my order.\n\nThe key lime tea was very aromatic...',
#   5,
#   '2020-06-17 15:45:01'),
#  ('shHhP5lfZwrAYFL3K04_lg',
#   'SXuKrnV9nB8C7BsOC10fBw',
#   'Ordered this place for delivery because they had a great lunch special where you got an appetizer, entrée, and side/drink/desert for $13. Delivery was very...',
#   4,
#   '2020-12-30 09:25:26'),
#  ('shHhP5lfZwrAYFL3K04_lg',
#   '9icSM24X6dRJZJqMxb7WOQ',
#   'Tried take out for the first time from here. The menu was very convenient with labeling for gluten free items, which is not common! We got the healthy...',
#   5,
#   '2020-09-20 17:41:44'),
#  ('shHhP5lfZwrAYFL3K04_lg',
#   'Us7nW-lk6jxi3Ie-rjOYRw',
#   'I enjoy the food here and have dined here for years. They are good about accommodating to specific requests. Their spring rolls are so delicious as are...',
#   4,
#   '2020-10-12 13:27:39'),
#  ('RSZITLOyKCsvCKLJNiE3Hg',
#   'dgU5-8J6p790ZHwU7wpieA',
#   "This is such a great spot for Thai food in the neighborhood. However since December 2020 and now January 2021 I'm beginning to suspect that they might be...",
#   5,
#   '2021-01-08 14:22:57'),
#  ('RSZITLOyKCsvCKLJNiE3Hg',
#   'yCoj7uLhAYhPmTc4KUtcTA',
#   'Ordered food thru grubhub last night and given the fact that I have lived in Bangkok as well as Hongkong for a while I am no stranger to thai food and...',
#   1,
#   '2020-04-16 11:04:48'),
#  ('RSZITLOyKCsvCKLJNiE3Hg',
#   'gFlFbudhveYAZloW4-HIKw',
#   "Seeing as this is the only Thai place within walking distance from my apt, I'll have to live with what they got. Most of the time I'll order their lunch...",
#   3,
#   '2020-03-16 22:27:45'),
#  ('1BJo1JcwYHUuk-UfJLEwUQ',
#   'BgJy-HvGhq451f3V5dUreA',
#   'Very very very good thai food on queens blvd. Super friendly servers and very attentive. Definitely stop by and give it a try',
#   5,
#   '2021-01-01 18:51:09'),
#  ('1BJo1JcwYHUuk-UfJLEwUQ',
#   'gpe7O-2cETuWcu_3808M6g',
#   "I went for a quick lunch with my friends and the food was tasty. Just make sure that you ask for not spicy on some dishes if you really don't like spicy...",
#   4,
#   '2021-02-11 19:26:24'),
#  ('1BJo1JcwYHUuk-UfJLEwUQ',
#   'VQTNs4FMDJ6i8pH4DVwa8Q',
#   'We are living in the neighborhood.  We came here multiple timese but no one served us better than Muay. She is kind, friendly and has a good knowledge of...',
#   5,
#   '2021-01-16 18:57:55'),
#  ('mpD_kUFo8POQDLoLgRSfCg',
#   'M1W5a_VlB5Crlg6_Q2R0XQ',
#   "This is my favorite thai place hands down, been going here for years. Food is great and inexpensive. I've never had any issues with delivery, it's always...",
#   5,
#   '2020-11-12 17:29:23'),
#  ('mpD_kUFo8POQDLoLgRSfCg',
#   '1rrA1lTyh_Z-QaXjE0RQgA',
#   'I love Sage. They have the best lunch specials in east Williamsburg and are still delivering during the pandemic. Their orders always arrive quicker than...',
#   5,
#   '2020-05-18 10:53:24'),
#  ('mpD_kUFo8POQDLoLgRSfCg',
#   'IgvDZgIHJ8Nek_ysVLxVLg',
#   'Great lunch specials, im getting into thai because of them! the portions are quite large for me but for the average person. they have a shrimp app thats...',
#   5,
#   '2020-10-21 19:36:49'),
#  ('7rTl_d-dqlK5dGG31ogSBg',
#   'E2KO5bOw1WIWnRjlQBqVyA',
#   'We ordered delivery from Nanking through a delivery service app. I ordered the Nanking chili chicken. It was breaded chicken with onions and peppers in a...',
#   4,
#   '2020-11-22 12:14:53'),
#  ('7rTl_d-dqlK5dGG31ogSBg',
#   '1S6S5tl8FB3Xi162PAWZ0Q',
#   'One of my favorite spots. I love their curried shrimp however the shrimp used to be large and succulent now they are tiny and hard as stone. It seems the...',
#   3,
#   '2020-11-04 19:28:51'),
#  ('7rTl_d-dqlK5dGG31ogSBg',
#   'nGUxR9enmL4wToH0DkrDwg',
#   'The food was terrible and the place could use sprucing .',
#   1,
#   '2020-12-20 03:29:35'),
#  ('HzJP6ICu_Naf5R0swzd-dg',
#   'sxguFn5hRVWvwKvo6uGSTw',
#   "I'm surprised I never wrote about this place since I frequent it quite a bit. This is probably the first halal Thai restaurant I've come across, so I very...",
#   4,
#   '2020-09-02 03:42:55'),
#  ('HzJP6ICu_Naf5R0swzd-dg',
#   'yrMin0FYjigjnCW0heIPdw',
#   'Absolutely delicious!!! I got the chicken teryaki with white rice and steamed veggies and it did not disappoint! The lemonade tasted refreshing and not to...',
#   5,
#   '2020-09-20 17:04:56'),
#  ('HzJP6ICu_Naf5R0swzd-dg',
#   'aPk4en4DUi65wy0zPx64ZQ',
#   'The food is great and so is the environment! Very tasteful and filling. The only down side to this restaurant now is that they changed their policy to cash...',
#   4,
#   '2020-07-22 17:32:27'),
#  ('yzbIUIeDuSH58WgK32J7Fw',
#   'owsbAuiWIMUPYbjbJX3Vsg',
#   'Pad See Eew was absolutely delicious, friendly staff and easy pick up! Highly recommend',
#   5,
#   '2020-10-19 10:29:37'),
#  ('yzbIUIeDuSH58WgK32J7Fw',
#   'fjX4d5-9-305wILUD6eQIg',
#   'Oh, do good! Just try it. I liked it when it was Red Basil & still do today. Pad Thai, basic but one of the best around for simple takeout. Other entrees...',
#   4,
#   '2020-09-06 18:33:24'),
#  ('yzbIUIeDuSH58WgK32J7Fw',
#   'DHLd10BR3qUDuJ-DLPz5ZQ',
#   'Been here multiple times and every time it just hits the spot and never fails to make me happy dance. Through the good and bad times it has always come...',
#   5,
#   '2020-05-05 11:57:34'),
#  ('WFx1VcopQGjW7jbERZUUbA',
#   'VY3Rm3eaiTlrUMi9n2kQEg',
#   'Tommy Thai is always my go-to place for delivery but our order of chicken pad thai and tofu red curry yesterday was perfect. Food always comes warm and on...',
#   5,
#   '2020-12-19 12:29:05'),
#  ('WFx1VcopQGjW7jbERZUUbA',
#   'V6HoZczMmWSUyGwnOcyToQ',
#   'Ordered take out from here for the first time. Delivery was fast. Food was hot. Only complaint was there were no bean sprouts in the pad Thai. Other than...',
#   4,
#   '2020-04-12 08:24:37'),
#  ('WFx1VcopQGjW7jbERZUUbA',
#   's2yflAoL6yaO9TEkFwkUNw',
#   'Fast delivery and very yummy food. Last night I ordered Thai chicken wings and pad see eiw and it was absolutely delicious and worth the $. Def recommend...',
#   5,
#   '2020-05-06 13:39:52'),
#  ('SOrQnn_dsHIFpmW5HTCFCw',
#   'Su99j_nqXr0K2keKsmxHHA',
#   'I think the food is good and to standards of other good thai restaurants and the portion sizes are good. I was impressed with the amount of protein they...',
#   4,
#   '2021-02-06 16:59:36'),
#  ('SOrQnn_dsHIFpmW5HTCFCw',
#   'YXMVrzM2TBalrHa5YxU0Iw',
#   'I ordered a pad thai with chicken for pick up for dinner. It was around 10 dollars which was decent. Its conveniently located near my house. The staff was...',
#   4,
#   '2020-09-09 21:47:46'),
#  ('SOrQnn_dsHIFpmW5HTCFCw',
#   '2Gk_c4pJvkLSzLYyKfavoQ',
#   'I lived in rural Thailand for three years, and the food at Ocha Thai cuisine is like what I used to eat in my small town in Thailand.  All of the things I...',
#   5,
#   '2020-05-22 16:39:57'),
#  ('XgiG7K7ubHsj2JJ-c2sXnw',
#   'PsvCfZhr0vtSuTHiXinWVg',
#   "GREAT OUTDOOR SETUP FOR DINING DURING COVID!! Ya'll this is the same people that was behind opening Uncle Boon's Michelin Star Thai restaurant! And if ya'll...",
#   5,
#   '2021-02-05 17:04:32'),
#  ('XgiG7K7ubHsj2JJ-c2sXnw',
#   'H_VfMLScTvFxea2vTQ8Z0g',
#   "My favorite Thai-inspired restaurant!\n\nEverything from cocktails to main dishes are fantastic. They change their menu every few months or so. I'm not...",
#   5,
#   '2021-02-05 14:55:27'),
#  ('XgiG7K7ubHsj2JJ-c2sXnw',
#   'bYGg7aKlcv8EgLBAzlr1nQ',
#   'I went to Thai Diner for brunch recently and had a lovely meal! I was the biggest advocate for Uncle Boons (so sad they closed, damn COVID!) and was...',
#   5,
#   '2021-01-16 12:03:30'),
#  ('4M-nT45SdA119-lcJg9c9A',
#   '9pHFmv3MWASQVD2qcaDB2g',
#   'Ordered delivery from here the other day and really enjoyed the food. I got a basic pad Thai which was fresh and very generously portioned. My boyfriend had...',
#   5,
#   '2020-09-05 12:43:17'),
#  ('4M-nT45SdA119-lcJg9c9A',
#   '4N2SOMXTa7IjDZXS4d_0qA',
#   "I love taste of thai food from this restaurant. Tom saab chicken feet is so spicy and that 's really good ingredient i can smell lots of herbs inside. Also...",
#   5,
#   '2021-01-26 23:23:03'),
#  ('4M-nT45SdA119-lcJg9c9A',
#   'nBA68wOknsL5vUsxNXCGyQ',
#   'Cancelled my seamless order and lied saying "restaurant closed 5:59PM" all because I placed a first time order with their $5 off first time discount....',
#   1,
#   '2021-01-29 15:02:34'),
#  ('utg1E8cea7vY5VuDyoOthA',
#   'flB4wcRBUOQTdVYiIF6E-w',
#   'My go to spot. Love them! Always good food and nice service. I normally get takeout but when I picked up once, they were extremely friendly too. Fav is the...',
#   5,
#   '2020-05-24 15:08:57'),
#  ('utg1E8cea7vY5VuDyoOthA',
#   '0KrGB6m5nphhIn0CuUN3PQ',
#   'The food was excellent, the Thai iced tea was so good too. The waitress who attended us was super kind and made sure everything was okay. \nMy favorite thing...',
#   5,
#   '2020-10-01 02:54:46'),
#  ('utg1E8cea7vY5VuDyoOthA',
#   'u4A5fW_Ep3eB0Wvkj8N35w',
#   'On a Friday (?) about a month ago, two friends and I came upon this restaurant. For fun, we had walked 6.5 miles with 20 lb backpacks and we wanted to reach...',
#   4,
#   '2020-08-08 15:47:45'),
#  ('f7jZvRH-h76F4emzvKytaQ',
#   'DkLvzu93uNfbPta5STPkCw',
#   'This is purely based on delivery - and it is AMAZING (so I can only imagine how good it is dining in). We have tried just about everything on the menu and...',
#   5,
#   '2021-01-11 19:36:43'),
#  ('f7jZvRH-h76F4emzvKytaQ',
#   'StBMVns4LK0bcGEnq3pujQ',
#   'Great Thai food. Nice people. They go the extra step before and now, during COVID. \nAlthough we moved about 40 mins away, we still come back to this local...',
#   5,
#   '2021-01-23 04:59:08'),
#  ('f7jZvRH-h76F4emzvKytaQ',
#   '4zOTQTWB12py6tWpD9LTWw',
#   'Located right near Gantry Plaza State Park, this Thai restaurant hit the spot after a long day of walking and exploring. They took all reasonable COVID...',
#   4,
#   '2020-11-21 20:52:33'),
#  ('O1fUmxt3kbV-rnyjBtzAfw',
#   'SGoiIE9Z06tWOKufmkedMg',
#   'COVID report: THEP currently has individual heated wooden cabins with sliding doors. I visited on a freezing day and it was a little chilly in our cabin,...',
#   5,
#   '2021-01-17 15:01:13'),
#  ('O1fUmxt3kbV-rnyjBtzAfw',
#   'jOdub8WTpzmeTYOk8vzs_g',
#   "I literally cannot get enough of this place. I am putting it out there its the best Thai in NYC (I'm open to debating but there is none.)\nThey are very...",
#   5,
#   '2021-01-03 03:19:19'),
#  ('O1fUmxt3kbV-rnyjBtzAfw',
#   'Z1B4b9h732455VwyU4gw6Q',
#   'Deeeelicious! Everytime. We got the calamari, basil fried rice, pad se ew, crispy duck in penang curry. Covid safe.',
#   5,
#   '2021-02-14 14:40:03'),
#  ('liZmIO0FqZwslLJfLDkfgw',
#   'AOeeh2Vbw-S6ae3WRytNhw',
#   "Covid: Contract tracing & temperature check upon arrival. Staff wears masks. There's a front outdoor dining area, indoor dining and the cutest backyard...",
#   5,
#   '2020-11-25 17:42:53'),
#  ('liZmIO0FqZwslLJfLDkfgw',
#   'm40P029HzByec4721AWtmw',
#   'Wayla is such a vibe!!!\n\nI set my timer to go off at midnight in order to snag a reservation at peak hours. So happy I did!\n\nMy friend and I dined on a...',
#   5,
#   '2020-09-08 05:46:26'),
#  ('liZmIO0FqZwslLJfLDkfgw',
#   '1eRKB3rgbrDllg4l0V7eqg',
#   "I've been wanting to eat at Wayla since before the pandemic & finally got to do so with a good friend late in the summer. Boy, Wayla did not...",
#   5,
#   '2020-11-22 18:56:36'),
#  ('n20BmzZ-KGd0RCKcPGRv1A',
#   'svP9-npAsyYhnDdm_bKziQ',
#   "When your Thai craving is hitting, this is definitely the perfect spot! Their menu is really expansive and everything I've had is amazing. The basil fried...",
#   5,
#   '2020-11-30 08:58:18'),
#  ('n20BmzZ-KGd0RCKcPGRv1A',
#   'oRnWzy2NlS_1hhwAdjRLzw',
#   "Great food, service, and covid precaution efforts. \n\nNo rsvp required, wasn't busy, seated immediately ... I'll definitely come for more yummy Thai food.",
#   5,
#   '2021-01-29 07:55:55'),
#  ('n20BmzZ-KGd0RCKcPGRv1A',
#   'JaPe2Schh2zf83IaMvl_dA',
#   'Delicious authentic Thai food! Order directly on their website if you want super fast delivery and even discounts. I had the drunken noodle with tofu, crab...',
#   5,
#   '2020-12-28 16:13:16'),
#  ('SZQqAil4kuXhNCLR7_6khg',
#   'azB-W15_WT_hHEWqejB5Dw',
#   'Now this restaurant just open , They serve delivery and pick up \nif you guy wanna try Thai authentic food , I definitely recommend this place it is...',
#   5,
#   '2020-05-18 17:40:02'),
#  ('SZQqAil4kuXhNCLR7_6khg',
#   'iisHGkNvK2cOTr67d2MsXA',
#   'The best thai food in my opinion in NYC Very authentic, the spice they used for the food, the taste of it almost exactly like the one when your in Thailand....',
#   5,
#   '2020-09-15 22:42:44'),
#  ('SZQqAil4kuXhNCLR7_6khg',
#   '2lJ-aHabaGuoh7r3-24CLg',
# ...
#   5,
#   '2021-01-30 21:16:07'),
#  ('3n6i8TwGEIL9KnCCHUyiqA',
#   'spswCj-muoz8zTPNhDq49w',
#   'Sai is such a hidden gem in Rego Park. The sushi is high quality and great value. The location is close to Queens Center Mall.\n\nThe sushi and sashimi was so...',
#   5,
#   '2020-12-30 08:12:00'),
#  ('3n6i8TwGEIL9KnCCHUyiqA',
#   'Q4ajZG7vOP-nbkJ_oWljrA',
#   'Wow, I am impressed!!! Honestly, I was a little hesitant about ordering from here because I never really had amazing sushi in Queens and the concept of good...',
#   5,
#   '2020-12-05 16:20:01'),
#  ('qtRPV9YANKcXU3OzcUUokw',
#   'APpJnT2Gnyuq5vhvf1Y2lA',
#   "One of my favorite places for takeout.  The food is ALWAYS good and delivery is usually on time.  My only complaint is the portions aren't big enough.",
#   5,
#   '2020-10-08 18:19:12'),
#  ('qtRPV9YANKcXU3OzcUUokw',
#   'aS7EtQyU0rDjRGef8xijTA',
#   'River Thai is still my favorite thai spot in the area for many dishes. I have noticed the chef who cooks during lunch hours is different than the dinner (at...',
#   5,
#   '2020-03-18 07:00:58'),
#  ('qtRPV9YANKcXU3OzcUUokw',
#   'mWDcz6FErLI4MWvFEirZwg',
#   'Ordered take out from here during a quarantine night--got wings, green curry with chicken, and cashew chicken dish. The green curry was so savory!! It was...',
#   4,
#   '2020-04-23 14:29:04'),
#  ('jjJc_CrkB2HodEinB6cWww',
#   'pWWqEQb86iGs7gYoML3thw',
#   'my friends and i were all craving different food when we were trying to decide what to eat, and i recommended that we try out this place. i can definitely...',
#   5,
#   '2021-02-06 09:37:55'),
#  ('jjJc_CrkB2HodEinB6cWww',
#   'CWFwiYEkzHvb2fuDFTAupA',
#   'I was in NYC on Christmas Day and we were searching for Thai food around Chinatown area. Most of the restaurants were closed (as expected because it is...',
#   5,
#   '2020-12-27 15:57:44'),
#  ('jjJc_CrkB2HodEinB6cWww',
#   'yrCJUsjsXzIwNBALVCz3EA',
#   "Came back yesterday after 3 years!!! Sorry I waited so long, when I said I would return sooner! But even though it's been 3 years, the moment I had a bite...",
#   5,
#   '2020-11-10 08:38:19'),
#  ('VoAuIReq_cPUrFwxbWqG_Q',
#   'KELkFyHVLYp5caGsnomAzA',
#   'NYC indoor dining is back!! \n\nThis restaurant has a cozy feel to it inside. I love the decor and ambiance. \n\nWe were seated right away and felt completely...',
#   5,
#   '2021-02-12 17:15:42'),
#  ('VoAuIReq_cPUrFwxbWqG_Q',
#   'oRcnooceJP1mOPOVGwmxGg',
#   'The best Thai restaurant outside of Thailand. \n\nI have probably ate in and ordered food over 200 times in the last 3 years. The food is incomparable. Always...',
#   5,
#   '2021-01-12 05:42:39'),
#  ('VoAuIReq_cPUrFwxbWqG_Q',
#   'OMzJ_byor_cYum8FJQUsRg',
#   "My favorite Thai restaurant around me! Delivery is quick and the food is very yummy! I've ordered the Pad Se Ew, Pad Thai, another noodle dish that I cannot...",
#   5,
#   '2021-01-19 08:48:46'),
#  ('tk_hI5v8KufzFaIP57_57g',
#   'QFckjm5l2LARQaptJCrybQ',
#   'Been my go to takeout place for a sec, always consistently good with great portions. Not sure what these other reviews have had, as every order has always...',
#   5,
#   '2020-12-21 18:05:58'),
#  ('tk_hI5v8KufzFaIP57_57g',
#   '3TDYXJoFL52LglNbLlYxZA',
#   'Extremely quick delivery! Highly recommend the crispy duck rolls ($6 for 3) as they were pretty generously filled with juicy duck and they were perfectly...',
#   4,
#   '2021-02-08 12:39:40'),
#  ('tk_hI5v8KufzFaIP57_57g',
#   'eDMnjbv1Xqv0jWmTJBdGjw',
#   'This place is getting me through COVID. A delicious Thai restaurant, that is always willing to indulge me when I want a pad thai SUPER spicy! Great service,...',
#   5,
#   '2021-01-12 07:17:44'),
#  ('feY7PgoRjCp2qReaIitRkQ',
#   'WNrd3pyWSchjl1wr6z0XrA',
#   "One of my favorite Thai restaurants ever, and not just because it's conveniently in my neighborhood. Delicious, authentic Thai food and great service. It's...",
#   5,
#   '2020-06-18 06:24:42'),
#  ('feY7PgoRjCp2qReaIitRkQ',
#   'pA8i2-mG9l_6WDOYrlndhw',
#   'My girlfriend hates me because all I ever want to get is Boran. Everything is great. But their food is much better in the restaurant than as take out. For...',
#   5,
#   '2020-06-27 16:16:14'),
#  ('feY7PgoRjCp2qReaIitRkQ',
#   'eIePDunnVg_9hC2i_GP1EQ',
#   "YESSSSSSSS. YES. yep. Uh huh! The best I've had in NYC. Will be ordering again. Spice level was right and delivery friendly.",
#   5,
#   '2020-04-24 17:30:58'),
#  ('NN3mOWF5e_pnR1ArqM2bHQ',
#   'nM67OAUfSYZMmQGG3FZ6wA',
#   "I've gotten take out and delivery a number of times from here. My favorite dish is the lunch pad see iew which is like drunken noodles with beef. I love...",
#   4,
#   '2020-11-19 06:48:04'),
#  ('NN3mOWF5e_pnR1ArqM2bHQ',
#   'xH-0mSSPQDi-HKIiWMEpcg',
#   'Good food. Eh on service. \n\nGot the calamari appetizer to start, which was good but not what you would expect (see photo). My fiancé got the crab fried...',
#   4,
#   '2020-10-28 18:51:37'),
#  ('NN3mOWF5e_pnR1ArqM2bHQ',
#   'd9oX9nK-GDbJ0iPcQetkbQ',
#   'I would have loved to try this place before the pandemic since the inside looks beautiful! We sat at a table close to the entrance, and to be honest, I...',
#   5,
#   '2020-10-05 19:14:46'),
#  ('eGIY_25KFspf8KefDQMj-Q',
#   'G5MG0bFMMgayzWDIzCHExA',
#   'Consistent.  Reliable.  Comforting.  Delicious. \nWith restaurants tanking left and right throughout Manhattan, I hold onto hope that my favorite...',
#   4,
#   '2020-12-20 13:41:57'),
#  ('eGIY_25KFspf8KefDQMj-Q',
#   'GTzHB1IrCuICyt0TfsbGmA',
#   'I\'ve been here twice now and this place is incredible. Good portions, authentic flavor, diverse menu. The "Bangkok street foods **new menu**" is...',
#   5,
#   '2021-01-15 15:48:40'),
#  ('eGIY_25KFspf8KefDQMj-Q',
#   'nrpY0YydJeGGb-haNLRapw',
#   'Thai duck noodle soup was so delicious - with rice noodles, greens and very generous amount of tamarind marinated non fatty but moist duck. So impressed and...',
#   5,
#   '2020-12-02 12:40:25'),
#  ('kiKUF11kNgEnM__P11nrig',
#   'eTYW67TyFwBn-umIGlDzPA',
#   "Amazing food and so affordable price in the middle of the pandemic. It's quite a drive from home but I would travel all the way just to get some good food!",
#   5,
#   '2021-02-05 16:24:06'),
#  ('kiKUF11kNgEnM__P11nrig',
#   'qBAC8pVMdlnXN7Sp2uq5OA',
#   "I don't know what that other review was talking about when it comes to the prices. There was a sign that clearly said all food is $10 dollars when I went....",
#   5,
#   '2020-06-05 10:22:34'),
#  ('kiKUF11kNgEnM__P11nrig',
#   'rigBe4hkH1aVZBXL5ZMDYg',
#   "I did not know spots like this existed in this area. Place was cozy. It's always deep, rich and pure in flavor. Also, the service is very nice. I really...",
#   5,
#   '2020-10-25 13:45:10'),
#  ('coQAQmIKG9dBPA6-RHqJag',
#   'OgtvIiaPvHhbqk_ZqmvxpA',
#   "My favorite Thai food restaurant in the city - and they're open during Covid-19! \n\nI've been ordering take out from here all month. \n\nThe food is always,...",
#   5,
#   '2020-04-12 11:49:28'),
#  ('coQAQmIKG9dBPA6-RHqJag',
#   '5-DRlVOD1KvKiVgEnjW3LA',
#   'Charms is normally a lovely Thai restaurant on 8th Ave in Chelsea with great food, a bar, good service, and a wonderful ambience. My husband and I are...',
#   5,
#   '2020-06-02 23:39:36'),
#  ('coQAQmIKG9dBPA6-RHqJag',
#   'TvvFE5H_83SvZ9-XJR8fOw',
#   "Thank you CHARM'S restaurant for open during COVID19. You save my life and you're the best. The food is so good and clean.",
#   5,
#   '2020-04-04 13:22:24'),
#  ('L2ZW-MdvRJ3gM2RIq8STbA',
#   'qrnrtOyJpwNwEx77t2bs4g',
#   'AMAZING. I came here yesterday with my mom for a quick meal and we ended up falling in love with this place!\n\nThey are taking good measures during these...',
#   5,
#   '2020-10-26 11:03:50'),
#  ('L2ZW-MdvRJ3gM2RIq8STbA',
#   'eGiB_zjMS7VGgtKdAUI26A',
#   "Tried Thai72 for the first time with a delivery.  Everything tasted really good - tried the sweet and sour chicken, crepe dumplings, and pad sew ew.  I'd...",
#   4,
#   '2020-05-30 11:18:46'),
#  ('L2ZW-MdvRJ3gM2RIq8STbA',
#   'Xdn4N63E34Bo4RAsLmrDcw',
#   'Excellent Thai food with quick delivery. This is our go to dinner when in town. Everything has been flavorful and artfully made. I love the avocado mango...',
#   5,
#   '2021-01-04 14:22:28'),
#  ('CDa0GJZDMPcjvhbx7RbG5Q',
#   'Pj3v8wJ2Au02A1q8cobPxg',
#   'Solid neighborhood spot for good takeout/delivery. We tried the shrimp dumpling appetizer and it was pretty tasty, 5 come in an order. Their pad kee mao is...',
#   4,
#   '2021-01-17 12:13:48'),
#  ('CDa0GJZDMPcjvhbx7RbG5Q',
#   'nRSaLfoRXLtKd2_-ruL1JQ',
#   "I'm so glad Senn is still open and available. Hopefully they'll slowly bring back their original menu, pre-pandemic. \n\nPros: food is good and feels homey...",
#   4,
#   '2021-02-05 09:16:29'),
#  ('CDa0GJZDMPcjvhbx7RbG5Q',
#   'dw7jsP2NQlbLRFlF8uHcfw',
#   'My son and I loved this after going to the Natural History museum. He said the pad see ew was particularly good. Great lunch set - fairly priced. The spring...',
#   5,
#   '2020-12-26 13:48:58'),
#  ('EzyjRrhRpt_NR7wIwqm_Rg',
#   'EdUqfRTwh7uAxvt8Tn4CHg',
#   'I love this place! My go-to takeout! I am a huge fan of the Pad Thai (chicken). Always so fresh--never a let down.',
#   5,
#   '2020-05-17 07:55:56'),
#  ('EzyjRrhRpt_NR7wIwqm_Rg',
#   'Y1jFyGbI7txKSu9imoKIXg',
#   "This is my favorite thai food in Astoria. I always get delivery from here, and the panang curry's so insanely good that it makes it really difficult to try...",
#   5,
#   '2020-03-19 09:53:00'),
#  ('EzyjRrhRpt_NR7wIwqm_Rg',
#   'xhYxtxmBeq2ti2EE9z-htw',
#   'Best pad thai in astoria. Most places make their pad thai way too sweet like a dessert with way too much sauce but this place does it just right. They get...',
#   5,
#   '2020-06-18 06:16:02'),
#  ('wGFSTTB6b4MHJJUzBnVJeg',
#   '8ykkiVYMAhIl7A3vW6WCGQ',
#   'There is heated and partitioned seating! Win :) \n\nI have been here preCovid and would highly recommend the pad see ew with fried tofu & veggies, with the...',
#   5,
#   '2021-01-10 16:26:35'),
#  ('wGFSTTB6b4MHJJUzBnVJeg',
#   '_SmvTuTIJEX7xWOBcwtohw',
#   'We just finished our delivery first order from Top Thai on Carmine St.  Mango Red Curry with Beef, Pad Thai with Shrimp and Papaya Salad. This is the best...',
#   5,
#   '2021-02-13 17:11:48'),
#  ('wGFSTTB6b4MHJJUzBnVJeg',
#   'CTwT4LbuegW4-Y-XtQkgwg',
#   'We came here for happy hour drinks and food and were very happy with our decision!\n\nThe lychee mojito was delicious as was the red and white sangrias. I was...',
#   5,
#   '2020-08-29 09:40:14'),
#  ('gBoqjD5MTJuGx65QjAhJGg',
#   '995M3OOmosblgvXueRsN6g',
#   'When I went there, they were takeout only, so I opted to eat by the park benches by the restaurant.  Not ideal, but at least I got to enjoy the food and...',
#   5,
#   '2020-07-17 22:44:05'),
#  ('gBoqjD5MTJuGx65QjAhJGg',
#   'DqkC1jGlAUX2sfa0_ffw3A',
#   'First time getting Thai food from this Pelham establishment. Typically would go to a place in New Ro or Mamaroneck. Bangkok City will be my go to place for...',
#   5,
#   '2020-12-27 05:31:57'),
#  ('gBoqjD5MTJuGx65QjAhJGg',
#   'HlQueE1jTyeqPDJl0NdSSw',
#   'When I left Manhattan for Westchester I was (and still am) sorely disappointed at the food scene. However I am SO pleased I have discovered this very tasty...',
#   5,
#   '2020-08-03 14:46:15'),
#  ('Il1K0hzGEiJgLLBCZCfA1A',
#   'P5ImY2iylUamkhPQMM6PeQ',
#   "What a cool little shop!\nI spotted this shop the other night, but didn't have time to go inside .\nI've had my eyes on these coconut roll cookies for the...",
#   5,
#   '2019-08-24 14:15:35'),
#  ('Il1K0hzGEiJgLLBCZCfA1A',
#   'gw2CwNwzfxV4uuZlJyXmmw',
#   'I love this store! I was in search for Holy Basil or Thai basil because I wanted to make Pad Ka Prow at home. I went to other Thai stores in Woodside and...',
#   5,
#   '2020-06-08 08:34:20'),
#  ('Il1K0hzGEiJgLLBCZCfA1A',
#   'UuCOobisJjeeYO0okSFzfw',
#   'I should be clear that I am not reviewing the products or quality of food that you can purchase here - this store clearly stocks authentic Thai products and...',
#   2,
#   '2020-07-14 19:53:38'),
#  ('qnD3XDvYIrFh_FppNH90cA',
#   'o0D5DAwFDs9F62L47nIZeg',
#   'I got take out from this place during the pandemic and I thought tbt food tasted good and the portions were great I got the green curry, pad see ew, and the...',
#   4,
#   '2020-08-31 02:24:39'),
#  ('qnD3XDvYIrFh_FppNH90cA',
#   'mPahU0kKtMMrelGp8AyLBQ',
#   'Great food and fast take out. Fried calamari, chicken pad Thai, pad see ew w chicken and shrimp, and spring rolls were all delicious. Would definitely go...',
#   5,
#   '2020-08-25 18:59:58'),
#  ('qnD3XDvYIrFh_FppNH90cA',
#   'Z5g1CG6bkFZrOG2-yWtWnQ',
#   'Just OK. There are better Thai places in the neighbourhood.\n\nThe good -\nReasonably priced and good portions\nFlavourful  Kraw Prow and Drunken Noodle\nReminds...',
#   3,
#   '2020-11-09 12:37:10'),
#  ('9v4l7pz4J709z0mkqUpQbw',
#   'GL3mn7-qEx27tanzWyPMZQ',
#   'Great for takeout/delivery!! Friendly staff and delivered my order SO fast! Plus YUM!',
#   5,
#   '2021-02-02 16:17:47'),
#  ('9v4l7pz4J709z0mkqUpQbw',
#   'p1UU9NE5HHVSmEPSqF8U9w',
#   'One of my favorite Thai spots. Very pleasant staff, fast delivery and delicious food.',
#   5,
#   '2020-12-07 23:05:08'),
#  ('9v4l7pz4J709z0mkqUpQbw',
#   'CxTt_qShmH8tohNCd0OSTg',
#   'Excellent service during Covid! Chicken over Thai Fried Rice was GREAT! Customer Service was welcoming.',
#   5,
#   '2020-08-27 14:29:17'),
#  ('TUoya6mwmxr0Zpr8oZSXlg',
#   'fWr_3St2n8WdG-WY9_calQ',
#   'Love this place! Food is always great as well as the services.They take great care in packing the food for pick up. Even puncturing holes in the container...',
#   5,
#   '2020-09-24 12:24:12'),
#  ('TUoya6mwmxr0Zpr8oZSXlg',
#   'Q95iFZ6mCtUaA3X5oafTIg',
#   'Ordered delivery from here at least twice so far. Lunch special comes with side and a small salad, paired that with a soup and a drink all for less than 20...',
#   5,
#   '2020-05-02 15:18:30'),
#  ('TUoya6mwmxr0Zpr8oZSXlg',
#   '0K7xHBJCkqVpn-Zgu0rk6g',
#   'The food at Thip Osha is seriously delicious! The dishes are fresh and flavorful. The curries are incredibly tasty. Also- the banana sticky rice is AMAZING!...',
#   5,
#   '2020-11-02 18:10:34'),
#  ('BlBBmx4sLmoRW0tORiMDHQ',
#   'vuTxDwfO_bRqaRwETYXlLA',
#   'Today was my first time trying some food from this particular restaurant. The out side of the restaurant looks really cool.the doors are the old Camelot...',
#   4,
#   '2021-01-15 23:08:54'),
#  ('BlBBmx4sLmoRW0tORiMDHQ',
#   'Ow-9RJpyEtEflZpV0ILcRQ',
#   'I mainly order from Hado Sushi via Uber Eats. The delivery is always excellent the Alligator and Tuna 141 rolls are extremely tasty and well-packaged. Their...',
#   5,
#   '2020-10-05 16:47:27'),
#  ('BlBBmx4sLmoRW0tORiMDHQ',
#   'TFwxnjT0SDDDQ1Evcm4WiA',
#   'I ordered on seamless and am commenting on the service specifically as I have not yet eaten the food. They were timely and followed delivery instructions...',
#   5,
#   '2020-07-02 18:26:23'),
#  ('maRGHspk6zuaNn1pk9qgZw',
#   'H8PJOtQE7kgeu2dSXtn6YQ',
#   'Super fast delivery for an 8:30pm Friday night order. \nPad Thai, Thai Fried Rice, and veggie dumplings. Good portions for the money, and everything was...',
#   5,
#   '2020-12-18 20:44:09'),
#  ('maRGHspk6zuaNn1pk9qgZw',
#   'gG4MdZvUZxxotrG0SIg4_Q',
#   "Chicken Satay with it's peanut sauce, Fried Chicken Wings, Peanut Sauce (Nutty) Beef, and  Drunken Noodles were all amazing! We had it for delivery and it's...",
#   5,
#   '2020-04-23 16:05:43'),
#  ('maRGHspk6zuaNn1pk9qgZw',
#   'O509MmGR2iZnuMbUuNWr_A',
#   'Good food, reliable delivery service, all in all a solid Thai spot to have nearby . Thank you guys for staying open and continuing to serve the community...',
#   5,
#   '2020-05-15 11:28:50'),
#  ('4nwVzRCfWFGe6_Taqee4Cg',
#   'pVDiRCwCQNxt_i7rybL6Mw',
#   'Our go to neighborhood Thai spot for dine in or takeout. I always get the roti canai and pad see yuu. They have an extensive vegan menu with the best mock...',
#   5,
#   '2021-01-12 17:51:08'),
#  ('4nwVzRCfWFGe6_Taqee4Cg',
#   'oosuiEWyxUJcfp7C_OQoUg',
#   '[Pre-covid review] A welcome oasis in the neighborhood. Very small charming resto with two rows of dark wood tables accented with colorful Thai pillows....',
#   5,
#   '2020-08-13 20:20:39'),
#  ('4nwVzRCfWFGe6_Taqee4Cg',
#   'cQUx6dsSd82OSw65GmwWIA',
#   'I ordered the drunken noodles with beef on a whim for delivery, and then ordered it again the next night. It was that good. Then I ordered it a week later....',
#   5,
#   '2021-01-12 16:22:50')]

# %% [markdown]
# - Write a function that takes a business id and makes a call to the API for reivews

# %% [markdown]
# - Write a function to parse out the relevant information from the reviews

# %%
def parse_results_review(list_of_data):
    review_list = []
    for l in yelp_call_rev(url_params):
        for review in l:
            for t in review:
#             print (t)
                try:
                    review_tuple = (l[1],
                            t['id'],
                            t['text'],
                            t['rating'],
                            t['time_created'])   
    # add each individual business tuple to our data container
                    review_list.append(review_tuple)
                except:
                    break
    # return the container with all of the parsed results
    return review_list

# %% [markdown]
# - Write a function to save the parse data into a csv file containing all of the reviews.

# %%
def df_save_review(csv_file_path, parsed_results):
    # your code to open the csv file, concat the current data, and save the data. 
    business_df = pd.DataFrame(parsed_results, columns = ['Business ID','ID', 'Review', 'Rating', 'Date'])
    business_df.to_csv(csv_file_path, mode = 'a')
    new_df = pd.read_csv(csv_file_path, delimiter = ",")
    return new_df

# %% [markdown]
# - Combine the functions above into a single script

# %%
# create a variable  to keep track of which result you are in. 
num = 0

#set up a while loop to go through and grab the result 
while num < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = num
    #make your API call with the new offset number
    yelpcall = yelp_call_rev(url_params)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results_review(yelpcall)

    # use your function to insert your parsed results into the db
    df_save_review('review.csv', parsed_results)    

    #increment the counter by 50 to move on to the next results
    num += 50

# %%
reviewsdf=pd.read_csv('review.csv')

# %%
r_df= reviewsdf[:294]

# %% [markdown]
# ___

# %% [markdown]
# ## Part 4 -  Using python and pandas, write code to answer the questions below.
#
#
# - Which are the 5 most reviewed businesses in your dataset?
# - What is the highest rating recieved in your data set and how many businesses have that rating?
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What percentage of your businesseshave a price label of one dollar sign? Two dollar signs? Three dollar signs? No dollar signs?
# - Return the text of the reviews for the most reviewed business.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the business with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the business with the least reviews.

# %%
df=pd.concat([thaidf,mexdf])

# %%
df=df.set_index('Name')

# %%
#had duplicate indicies so dropped that column
df=df.drop(df.columns[0], axis=1)

# %%
#had headers in place of data so removed those rows
df=df[df['Rating']!='Rating']

# %%
#review count was object type so converted to int to sort
df['Review Count']=df['Review Count'].astype(int)

# %%
#TOP 5 REVIEWS
top_5_reviews=df.sort_values('Review Count',ascending=False)[0:5]

# %%
df['Rating']=df['Rating'].astype(float)

# %%
#HIGHEST RATED/ 5 businesses have 5.0 rating
highest_rated=df.sort_values('Rating',ascending=False)[0:10]

# %%
#RATINGS GREATER THAN OR EQUAL TO 4.5
high_ratings_perc=(len(df[df['Rating']>=4.5])/len(df))*100

# %%
#RATINGS LOWER THAN 3.0
low_ratings_perc=(len(df[df['Rating']<3])/len(df))*100
low_ratings_perc
# Out:
# 1.2414649286157666

# %%
df['Price']=df['Price'].astype(str)

# %%
#VALUE COUNTS FOR PRICE DOLLAR SIGNS
df.groupby('Price').count()['Id']
# Out:
# Price
# $        322
# $$      1270
# $$$       17
# $$$$       2
# Name: Id, dtype: int64

# %%
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
ax.bar(df['Rating'],df['Review Count'])
# Out:
# <BarContainer object of 1611 artists>

# %%
thaidf=thaidf[thaidf['Rating']!='Rating']
thaidf['Rating']=thaidf['Rating'].astype(float)
mexdf=mexdf[mexdf['Rating']!='Rating']
mexdf['Rating']=mexdf['Rating'].astype(float)

# %%
thaidf
fig,ax=plt.subplots()
ax.hist(thaidf['Rating'],edgecolor='black',bins=5)
ax.set_title('Thai Restaurant Ratings')
ax.set_xlabel('Ratings')
ax.set_ylabel('Frequency')
ax.set_xlim(1.0,5.0)
# Out:
# (1.0, 5.0)

# %%
fig,ax=plt.subplots()
ax.hist(mexdf['Rating'],edgecolor='black',bins=3)
ax.set_title('Mexican Restaurant Ratings')
ax.set_xlabel('Ratings')
ax.set_ylabel('Frequency')
ax.set_xlim(1.0,5.0)
# Out:
# (1.0, 5.0)

# %%
fig,ax=plt.subplots()
ax.scatter(df['Price'].map(len),df['Rating'])

# %%
df['Transactions']=df['Transactions'].astype(str)

# %%
def conversion(string):
    string=string.split(',')
    return string
df['Transactions']=df['Transactions'].map(conversion)

# %%
# fig,ax=plt.subplot()
# plt.hist(df['Transactions'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1611 entries, Sup Thai Kitchen to Viva Viva Taqueria
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            1611 non-null   object
#  1   Location      1610 non-null   object
#  2   Rating        1611 non-null   float64
#  3   Price         1611 non-null   object
#  4   Zipcode       1611 non-null   object
#  5   Transactions  1611 non-null   object
#  6   Review Count  1611 non-null   int64
#  7   Categories    1611 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 153.3+ KB

# %%
r_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   294 non-null    float64
#  1   Business ID  294 non-null    object
#  2   ID           294 non-null    object
#  3   Review       294 non-null    object
#  4   Rating       294 non-null    object
#  5   Date         294 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 13.9+ KB

# %%
#RETURN TEXT OF REVIEW FOR MOST REVIEWED
most_reviews=df[df['Review Count']==df['Review Count'].max()]

x=r_df['Review'][(r_df['Business ID'].isin(most_reviews['Id']))].to_string().split('\n')
len(x[0])+len(x[1])+len(x[2])
# Out:
# 168

# %%
#Find the highest rated business and return text of the most recent review
most_rated_reviews=df[df['Rating']==df['Rating'].max()]

review_rating= most_rated_reviews[most_rated_reviews['Review Count']==most_rated_reviews['Review Count'].max()]

review_rating

r_df[r_df['Business ID']=='2UxAkvKkkWNwqZi9H0OzWw']

# z=r_df['Review'][(r_df['Business ID'].isin(review_rating['Id']))]
# z
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Business ID, ID, Review, Rating, Date]
# Index: []

# %%
#Find the lowest rated business and return text of the most recent review

least_rated_reviews=df[df['Rating']==df['Rating'].min()]

review_low_rating= least_rated_reviews[least_rated_reviews['Review Count']==least_rated_reviews['Review Count'].min()]

review_low_rating

d=r_df['Review'][(r_df['Business ID'].isin(review_low_rating['Id']))].to_string().split('\n')

d
# Out:
# ['Series([], )']

# %% [markdown]
# ___

# %% [markdown]
# # Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    db_insert(parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 20
