# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
import sys
print(sys.path)
# Out:
# ['/Users/ryanlewis/Documents/Flatiron_020121/nyc-dc-ds-020121/Phase_1/ds-apis_json-main', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python38.zip', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python3.8', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python3.8/lib-dynload', '', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/extensions', '/Users/ryanlewis/.ipython']

# %%
# set theurl and endpoint we want to hit
url = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'YYinute8YoprX7XHYr6zhg'
api_key = "S3cROVIGs17gTiCO6iy8-2ycbL999zhz84ANxStc2mYNESu0cKfM4qdarKNZ69t-2bnTPSR_RRTTCTKmpQidQYhD1mpVN1zvyo0EGTVthI7SVumcOA3IZrRgj5omYHYx"

# %%
from  keys  import  client_id, api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-a43eced8b34d> in <module>
# ----> 1 from  keys  import  client_id, api_key
#
# ModuleNotFoundError: No module named 'keys'

# %%
print(api_key)

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'Thai'

#where do you want to perform this search
location = 'Queens'

# what is your other parameter you want to search against
categories = 'restaurants'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50,
    
            }

# %%
url_params
# Out:
# {'term': 'Thai',
#  'location': 'Queens',
#  'categories': 'restaurants',
#  'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
url
# Out:
# 'https://api.yelp.com/v3/businesses/search'

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "uazg6WhYVOw3jhWCG_MDBg", "alias": "sup-thai-kitchen-fresh-meadows", "name": "Sup Thai Kitchen", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg", "review_count": 373, "categories": [{"alias": "thai", "title": "Thai"}, {"alias": "seafood", "title": "Seafood"}, {"alias": "noodles", "title": "Noodles"}], "rating": 4.5, "coordinates": {"latitude": 40.7266838, "longitude": -73.7894371}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "178-19 Union Tpke", "address2": null, "address3": "", "city": "Fresh Meadows", "zip_code": "11366", "country": "US", "state": "NY", "display_address": ["178-19 Union Tpke", "Fresh Meadows, NY 11366"]}, "phone": "+17184874449", "display_phone": "(718) 487-4449", "distance": 5378.159709707153}, {"id": "cegA4jf16vEt7NCQ7cpu2w", "alias": "kind-fresh-meadows", "name": "Kin\'d", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg", "review_count": 767, "categories": [{"alias": "thai", "title": "Thai"}], "rating": 4.5, "coordinates": {"latitude": 40.73031, "longitude": -73.77814}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "192-03 Union Tpke", "address2": "", "address3": null, "city": "Fresh Meadows", "zip_code": "11366", "country": "US", "state": "NY", "display_address": ["192-03 Union Tpke", "Fresh Meadows, NY 11366"]}, "phone": "+17184680888", "display_phone": "(718) 468-0888", "distance": 6273.193942408963}, {"id": "1E7lCNaRAM1Da0vkt5rcvw", "alias": "thai-mission-maspeth", "name": "Thai Mission", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/OTi0qCJS2HAyviRUwg-Qtw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/thai-mission-maspeth?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg", "review_count": 29, "categories": [{"alias": "thai", "title": "Thai"}], "rating": 5.0, "coordinates": {"latitude": 40.72779, "longitude": -73.89279}, "transactions": ["pickup", "delivery"], "location": {"address1": "70-11 Grand Ave", "address2": null, "address3": "", "city": "Maspeth", "zip_code": "11378", "country": "US", "state": "NY", "display_address": ["70-11 Grand Ave", "Maspeth, NY 11378"]}, "phone": "+19293280328", "display_phone": "(929) 328-0328", "distance": 3390.6012918832753}, {"id": "0L03onqNwxWLrbb_FCK79A", "alias": "sripraphai-thai-restaurant-woodside", "name": "SriPraPhai Thai Restaurant", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg", "review_count": 2380, "categories": [{"alias": "thai", "title": "Thai"}], "rating": 4.0, "coordinates": {"latitude": 40.7464987, "longitude": -73.8992328}, "transactions": [], "price": "$$", "location": {"address1": "64-13 39th Ave", "address2": "", "address3": "", "city": "Woodside", "zip_code": "11377", "country": "US", "state": "NY", "display_address": ["64-13 39th Ave", "Woodside, NY 11377"]}, "phone": "+17188999599", "display_phone": "(718) 899-9599", "distance": 4250.747809627073}, {"id": "gr3wUszE1972q0GBkmwEXQ", "alias": "bangkok-cuisine-forest-hills", "name": "Bangkok Cuisine", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/8vTa_qflOZVu30D0k0HSTg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/bangkok-cuisine-forest-hil ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'uazg6WhYVOw3jhWCG_MDBg',
#    'alias': 'sup-thai-kitchen-fresh-meadows',
#    'name': 'Sup Thai Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 373,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '178-19 Union Tpke',
#     'address2': None,
#     'address3': '',
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184874449',
#    'display_phone': '(718) 487-4449',
#    'distance': 5378.159709707153},
#   {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#    'alias': 'kind-fresh-meadows',
#    'name': "Kin'd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 767,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '192-03 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184680888',
#    'display_phone': '(718) 468-0888',
#    'distance': 6273.193942408963},
#   {'id': '1E7lCNaRAM1Da0vkt5rcvw',
#    'alias': 'thai-mission-maspeth',
#    'name': 'Thai Mission',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OTi0qCJS2HAyviRUwg-Qtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-mission-maspeth?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 29,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72779, 'longitude': -73.89279},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '70-11 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70-11 Grand Ave', 'Maspeth, NY 11378']},
#    'phone': '+19293280328',
#    'display_phone': '(929) 328-0328',
#    'distance': 3390.6012918832753},
#   {'id': '0L03onqNwxWLrbb_FCK79A',
#    'alias': 'sripraphai-thai-restaurant-woodside',
#    'name': 'SriPraPhai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2380,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '64-13 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17188999599',
#    'display_phone': '(718) 899-9599',
#    'distance': 4250.747809627073},
#   {'id': 'gr3wUszE1972q0GBkmwEXQ',
#    'alias': 'bangkok-cuisine-forest-hills',
#    'name': 'Bangkok Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8vTa_qflOZVu30D0k0HSTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-cuisine-forest-hills?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 421,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720954, 'longitude': -73.845238},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '10718 70th Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10718 70th Rd', 'Forest Hills, NY 11375']},
#    'phone': '+17182614005',
#    'display_phone': '(718) 261-4005',
#    'distance': 1329.980593467087},
#   {'id': '1ubEg-rrSE8IWXl6lJzIGw',
#    'alias': 'nur-thai-rego-park',
#    'name': 'Nur Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wKL4Mnmig42Youp-9eYUIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nur-thai-rego-park?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 561,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7235516378586,
#     'longitude': -73.868817789544},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63-32 Woodhaven Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-32 Woodhaven Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17182556141',
#    'display_phone': '(718) 255-6141',
#    'distance': 1608.1819342053043},
#   {'id': '3GMHPnrkFAcqffw3T7JSdQ',
#    'alias': 'kitchen-79-jackson-heights',
#    'name': 'Kitchen 79',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ip9F8-pOstZmt7_8T_46Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-79-jackson-heights?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 629,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747551, 'longitude': -73.8868866},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37-70 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-70 79th St', 'Jackson Heights, NY 11372']},
#    'phone': '+17188036227',
#    'display_phone': '(718) 803-6227',
#    'distance': 3388.369692606335},
#   {'id': 'fRO4Fwe5uRAajMcTwLbVkA',
#    'alias': 'ayada-thai-elmhurst-2',
#    'name': 'Ayada Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qybFSiSVmsTTXx5fmX3BNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ayada-thai-elmhurst-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1222,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433662414551,
#     'longitude': -73.8876037597656},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7708 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7708 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184240844',
#    'display_phone': '(718) 424-0844',
#    'distance': 3222.317210809843},
#   {'id': '-YazuZbXAM_NOny8LpLQpQ',
#    'alias': 'bkny-thai-restaurant-bayside',
#    'name': 'BKNY Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glVWdfDHW-eu4KhXWP3QMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkny-thai-restaurant-bayside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7530184239866,
#     'longitude': -73.780074009384},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '47-11 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-11 Francis Lewis Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182811900',
#    'display_phone': '(718) 281-1900',
#    'distance': 6582.441577772174},
#   {'id': 'OVAV0k2O1kqeuRFyt95qzg',
#    'alias': 'ma-kin-middle-village-3',
#    'name': 'Ma Kin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HKS9ClA3DITKpnzWjhFm6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ma-kin-middle-village-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 92,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7130368, 'longitude': -73.8775219},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7419 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Middle Village',
#     'zip_code': '11379',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7419 Metropolitan Ave', 'Middle Village, NY 11379']},
#    'phone': '+13475071234',
#    'display_phone': '(347) 507-1234',
#    'distance': 2915.288989938397},
#   {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#    'alias': 'pye-boat-noodle-astoria',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 837,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17186852329',
#    'display_phone': '(718) 685-2329',
#    'distance': 6625.086426070104},
#   {'id': 'oNN202L_XcNM-tuDHlgkfg',
#    'alias': 'boon-chu-thai-place-elmhurst',
#    'name': 'Boon Chu Thai Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ffVw7NKAcTDUIPfd5tUwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boon-chu-thai-place-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 313,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740638, 'longitude': -73.879645},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '83-18 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83-18 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17188986836',
#    'display_phone': '(718) 898-6836',
#    'distance': 2477.7303260455205},
#   {'id': 'STx4mlpKJVrjd6eZu4yDIw',
#    'alias': 'heng-thai-long-island-city',
#    'name': 'Heng Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNglrhhC7IGOBrdkTu-h-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heng-thai-long-island-city?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 10,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74491469312005,
#     'longitude': -73.94774386999885},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '23-06 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23-06 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17187060999',
#    'display_phone': '(718) 706-0999',
#    'distance': 8134.151172667756},
#   {'id': '5pzc2GdvdmqiLRSdjHnnKw',
#    'alias': 'bangkok-avenue-little-neck-2',
#    'name': 'Bangkok Avenue',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-6MNVU7V930qB3PvdLHKAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-avenue-little-neck-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77135, 'longitude': -73.73529},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '253-21 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Little Neck',
#     'zip_code': '11362',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253-21 Northern Blvd', 'Little Neck, NY 11362']},
#    'phone': '+19143033388',
#    'display_phone': '(914) 303-3388',
#    'distance': 10849.613791106447},
#   {'id': 'jMb34zhfkqoW866F10hf1Q',
#    'alias': 'grace-thai-restaurant-elmhurst',
#    'name': 'Grace Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JtXzAAG2jsoperWNGOANSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-thai-restaurant-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 52,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.736905, 'longitude': -73.865734},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '5617 Junction Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5617 Junction Blvd', 'Elmhurst, NY 11373']},
#    'phone': '+19294633693',
#    'display_phone': '(929) 463-3693',
#    'distance': 1241.9783887099397},
#   {'id': '1svF14BUYt_Wc0XA3nMxdw',
#    'alias': 'cha-lom-thai-flushing',
#    'name': 'Cha Lom Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LUcuIr0hXhAy8DMUMbClFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cha-lom-thai-flushing?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 59,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7663429058334,
#     'longitude': -73.7893586550144},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-47 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-47 Francis Lewis Blvd', 'Flushing, NY 11358']},
#    'phone': '+17182696821',
#    'display_phone': '(718) 269-6821',
#    'distance': 6606.083966623151},
#   {'id': 'PPQSf_1JWkbjFHi1S0nSNA',
#    'alias': 'lamoon-elmhurst',
#    'name': 'Lamoon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YNrzpdKbmrGLFOtPUwFW6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamoon-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 268,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742890245749, 'longitude': -73.883034010715},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8140 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8140 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19177451168',
#    'display_phone': '(917) 745-1168',
#    'distance': 2843.1620995374224},
#   {'id': 'Ve_iFpnhL8zN789ZL2jnxQ',
#    'alias': 'uthai-rego-park',
#    'name': 'UThai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EyX6yAydMLYFXZc7dY7PRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uthai-rego-park?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 219,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7282415, 'longitude': -73.8639467},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '63-55 Wetherole St',
#     'address2': None,
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-55 Wetherole St', 'Rego Park, NY 11374']},
#    'phone': '+17188971575',
#    'display_phone': '(718) 897-1575',
#    'distance': 1001.8808045720075},
#   {'id': 'tVB11pOiDhPWlt_o6ylMNg',
#    'alias': 'enthaice-thai-kitchen-astoria',
#    'name': 'Enthaice Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/poiYY93PvnCGFXQAEvO-Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enthaice-thai-kitchen-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 695,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7630889337809,
#     'longitude': -73.9213237166405},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-20 31st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-20 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17189321111',
#    'display_phone': '(718) 932-1111',
#    'distance': 6755.95967403878},
#   {'id': 'inftQdKaEEiqQ323AlomXg',
#    'alias': 'dek-sen-elmhurst-2',
#    'name': 'Dek Sen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VV_1YWKJXD_BEvAfQ2-wGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dek-sen-elmhurst-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 278,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.741714, 'longitude': -73.878689},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8608 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8608 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17182055181',
#    'display_phone': '(718) 205-5181',
#    'distance': 2452.1963359930987},
#   {'id': 'a23bfZBVjIhV32Em4hKHAA',
#    'alias': 'the-buffs-long-island-city-4',
#    'name': 'The Buffs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lQID-gz3kJ6Gw-Yr8rLVKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buffs-long-island-city-4?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 106,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7556342, 'longitude': -73.9417121},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1313 40th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1313 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183612362',
#    'display_phone': '(718) 361-2362',
#    'distance': 7918.772733558018},
#   {'id': 'CpY77cDN1KS5EdiXMmWovw',
#    'alias': 'house-of-thai-long-island-city-4',
#    'name': 'House of Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uZJDECEq7QBfrSIfyrPsRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-thai-long-island-city-4?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 301,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7535257695712,
#     'longitude': -73.9377629319284},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2501 40th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2501 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+19295220247',
#    'display_phone': '(929) 522-0247',
#    'distance': 7562.962070152043},
#   {'id': 'PyaeHq_UAu6nazGiy0XAnw',
#    'alias': 'ginger-and-lemongrass-whitestone',
#    'name': 'Ginger and Lemongrass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rc7pZR40ZmAVzeenf48eZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-lemongrass-whitestone?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 801,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7892691, 'longitude': -73.813717},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1253 150th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1253 150th St', 'Whitestone, NY 11357']},
#    'phone': '+13477324720',
#    'display_phone': '(347) 732-4720',
#    'distance': 7222.985916370918},
#   {'id': 'yCJHIM-PWl54K53ACOpoNg',
#    'alias': 'hug-esan-elmhurst',
#    'name': 'Hug Esan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6solnO-f4-uAP7irlf1MZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hug-esan-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 169,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7436465, 'longitude': -73.8873753},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '77-16 Woodside Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77-16 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+19293280392',
#    'display_phone': '(929) 328-0392',
#    'distance': 3209.1609507515063},
#   {'id': 'm2_ZNFos5ugAwe8ft8eaEw',
#    'alias': 'eim-khao-mun-kai-elmhurst-elmhurst',
#    'name': 'Eim Khao Mun Kai Elmhurst',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JqeuGqrZxCPGVowAEs8XFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eim-khao-mun-kai-elmhurst-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 457,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'hainan', 'title': 'Hainan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7429414097644,
#     'longitude': -73.8832733356575},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '81-32 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-32 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17184247156',
#    'display_phone': '(718) 424-7156',
#    'distance': 2863.74521041377},
#   {'id': 'kXuubLd6s3GidpqU3psPdw',
#    'alias': 'chao-thai-elmhurst-3',
#    'name': 'Chao Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sq1y11AFR9zp81X0aH9vKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chao-thai-elmhurst-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 379,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414656, 'longitude': -73.8801273},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8503 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8503 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184244999',
#    'display_phone': '(718) 424-4999',
#    'distance': 2568.855535856452},
#   {'id': 'hA5QUlrSjpxMZ90Kof0bgA',
#    'alias': 'khao-kang-elmhurst',
#    'name': 'Khao Kang',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vfRK27R36XLI4wHpZr6bHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-kang-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 244,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743269, 'longitude': -73.888039},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '7620 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7620 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17188061807',
#    'display_phone': '(718) 806-1807',
#    'distance': 3242.7336966969283},
#   {'id': 'a5H9p1B6m6WPVjakPylvdA',
#    'alias': 'spicy-shallot-elmhurst',
#    'name': 'Spicy Shallot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OzUSMfiNLzDNthJuYxni0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spicy-shallot-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 633,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7437053273707,
#     'longitude': -73.8878916857991},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7701 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7701 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17186725266',
#    'display_phone': '(718) 672-5266',
#    'distance': 3251.3867012082496},
#   {'id': 'rehmlZmUNL2AthW-VTXJJQ',
#    'alias': 'tasty-thai-ridgewood',
#    'name': 'Tasty Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NX0ocs11fl3Dj1kTmpBrRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-thai-ridgewood?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69984, 'longitude': -73.89958},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '72-04 Forest Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72-04 Forest Ave', 'Ridgewood, NY 11385']},
#    'phone': '+19179090937',
#    'display_phone': '(917) 909-0937',
#    'distance': 5281.3840549926945},
#   {'id': 'zRQNaDUoWTInc2tqndSJVA',
#    'alias': 'thai-101-bayside',
#    'name': 'Thai 101',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dvejY_8barqkhtUQt35Hkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-101-bayside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 306,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76488, 'longitude': -73.77133},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '39-15 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-15 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17186318600',
#    'display_phone': '(718) 631-8600',
#    'distance': 7803.89291133938},
#   {'id': 'YMcDo3UccCPvIJrQ5Yt9Yw',
#    'alias': 'chám-thai-cuisine-ridgewood',
#    'name': 'Chám Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_INscq_GSjWwiY03XfcQbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ch%C3%A1m-thai-cuisine-ridgewood?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 48,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7025939, 'longitude': -73.901464},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '881 Woodward Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['881 Woodward Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17188944404',
#    'display_phone': '(718) 894-4404',
#    'distance': 5205.517479140647},
#   {'id': 'wEawMdWT7UtZjEmmMTBiGA',
#    'alias': 'saranrom-thai-elmhurst-2',
#    'name': 'Saranrom Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kfH2mX_qFCnGegh9CUY_rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saranrom-thai-elmhurst-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 32,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7431528, 'longitude': -73.8836694},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '8110 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8110 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19178326672',
#    'display_phone': '(917) 832-6672',
#    'distance': 2905.2906392679156},
#   {'id': 'OR9oqAJW-U5ZnqhwH12Nuw',
#    'alias': 'khao-nom-elmhurst',
#    'name': 'Khao Nom',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fiPmRRzFIz4WRhuyAyGXXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-nom-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 116,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432731562959,
#     'longitude': -73.8879961885031},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '42-06 77th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 77th St', 'Elmhurst, NY 11373']},
#    'phone': '+19292080108',
#    'display_phone': '(929) 208-0108',
#    'distance': 3250.841753204315},
#   {'id': 'toykv8K0yg8qtvZSXRQ5bg',
#    'alias': 'pochana-thai-kitchen-astoria-2',
#    'name': 'Pochana Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5hfYhHZOsD9SRICjUaFpYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pochana-thai-kitchen-astoria-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 193,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765733, 'longitude': -73.91932},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-16 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-16 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17189569559',
#    'display_phone': '(718) 956-9559',
#    'distance': 6773.2440684776475},
#   {'id': 'dnCRiUZWgu5ZI4Q-Z-az6Q',
#    'alias': 'thai-diva-cuisine-woodside-3',
#    'name': 'Thai Diva Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FAxltkvgVnPp87i9Uq90Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-diva-cuisine-woodside-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 140,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414512, 'longitude': -73.9190131},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45-53 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-53 46th St', 'Woodside, NY 11377']},
#    'phone': '+19292080282',
#    'display_phone': '(929) 208-0282',
#    'distance': 5684.506606279269},
#   {'id': 'ipxeCjihDqXTMkuPe-CQ4A',
#    'alias': 'arunee-thai-jackson-heights',
#    'name': 'Arunee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yBzXFJre13F2BtJNRiWAlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arunee-thai-jackson-heights?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7494503, 'longitude': -73.8873621},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '78-23 37th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78-23 37th Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+17182055559',
#    'display_phone': '(718) 205-5559',
#    'distance': 3529.3232402943213},
#   {'id': '8-dc942sz-prIeepAkHLJA',
#    'alias': 'zenith-thai-restaurant-ridgewood',
#    'name': 'Zenith Thai Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P5WjD6_4bZyV6AVgkeceaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zenith-thai-restaurant-ridgewood?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 113,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7023726, 'longitude': -73.8952926},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7002 Fresh Pond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7002 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '+17184978899',
#    'display_phone': '(718) 497-8899',
#    'distance': 4825.743443483346},
#   {'id': 'Eyn7hQENF8R9DrBwBHO6lQ',
#    'alias': 'pata-cafe-elmhurst',
#    'name': 'Pata Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XaAZQtUInh_RNGATh7ImpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pata-cafe-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 73,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7326341, 'longitude': -73.8769762},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5614 Van Horn St',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5614 Van Horn St', 'Elmhurst, NY 11373']},
#    'phone': '+13474697142',
#    'display_phone': '(347) 469-7142',
#    'distance': 2013.709004982964},
#   {'id': 'f7jZvRH-h76F4emzvKytaQ',
#    'alias': 'tuk-tuk-long-island-city',
#    'name': 'Tuk Tuk',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r_ALzLJ-56hQq6Wvk9jwFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuk-tuk-long-island-city?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 697,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743232, 'longitude': -73.954254},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4906 Vernon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4906 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17184725598',
#    'display_phone': '(718) 472-5598',
#    'distance': 8642.2312908624},
#   {'id': 'JX5QkNfMd-jP-Nz5iQ_QeA',
#    'alias': 'thai-nara-halal-restaurant-woodside',
#    'name': 'Thai Nara Halal Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EN6EwzOYv9NjoNdxjNhexw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-nara-halal-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 50,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75011, 'longitude': -73.89848},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '64-02 35th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-02 35th Ave', 'Woodside, NY 11377']},
#    'phone': '+17186068842',
#    'display_phone': '(718) 606-8842',
#    'distance': 4368.173178694347},
#   {'id': '2ZBEE_MJeRdLD1NLiNTnCQ',
#    'alias': 'thailands-center-point-woodside-2',
#    'name': "Thailand's Center Point",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o99eLojQrJOaEe1keKZEug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thailands-center-point-woodside-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 196,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746738, 'longitude': -73.900162},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63-19 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-19 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17186516888',
#    'display_phone': '(718) 651-6888',
#    'distance': 4333.1887147697735},
#   {'id': 'ET4xGd-SQ6gs9lce4xVpQg',
#    'alias': 'tum-thai-cuisine-rockville-centre',
#    'name': 'Tum Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0keHJi1yLq97gnDyCeM7UQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tum-thai-cuisine-rockville-centre?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 641,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65591, 'longitude': -73.64574},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '274 Merrick Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockville Centre',
#     'zip_code': '11570',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Merrick Rd', 'Rockville Centre, NY 11570']},
#    'phone': '+15165435078',
#    'display_phone': '(516) 543-5078',
#    'distance': 19384.513491944435},
#   {'id': 'nu239sXQUGjcGFhZ3AdJmQ',
#    'alias': 'erawan-thai-cuisine-bayside',
#    'name': 'Erawan Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x_vmcrpshZxNmtw9sKHzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/erawan-thai-cuisine-bayside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 346,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.761821, 'longitude': -73.769775},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4231 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4231 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17184282112',
#    'display_phone': '(718) 428-2112',
#    'distance': 7766.294526950914},
#   {'id': '2pJ782hnKTK0MWbc0H7EDw',
#    'alias': 'ditmars-thai-astoria',
#    'name': 'Ditmars Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P4ei6AZRi77oR6HcHLJMbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ditmars-thai-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 12,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77473, 'longitude': -73.90825},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '35-13 Ditmars Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17182694549',
#    'display_phone': '(718) 269-4549',
#    'distance': 6703.073797984971},
#   {'id': 'QWskQ2QpR8bmza2FRFziOQ',
#    'alias': 'asian-fortune-restaurant-forest-hills',
#    'name': 'Asian Fortune Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Av0ZXxYsKSXnZ8z182gh0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asian-fortune-restaurant-forest-hills?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 114,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7244621, 'longitude': -73.8493213},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '103-35 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103-35 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188306313',
#    'display_phone': '(718) 830-6313',
#    'distance': 851.8262088216507},
#   {'id': 'khvnn7cpiYSpe80ue5YLvg',
#    'alias': 'ddee-thai-astoria',
#    'name': 'Ddee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mVpYungatdQ1AFuujOjTdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ddee-thai-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 37,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.762909, 'longitude': -73.91325},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '42-06 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17186261222',
#    'display_phone': '(718) 626-1222',
#    'distance': 6173.635697332506},
#   {'id': 'MxMWPaC30sRkPKit_Omz2A',
#    'alias': 'khun-noo-thai-noodle-house-woodside',
#    'name': 'Khun Noo Thai Noodle House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85O4rR5ovWEeOa7sy1El2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khun-noo-thai-noodle-house-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 51,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74568, 'longitude': -73.91261},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '51-20 Skillman Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51-20 Skillman Ave', 'Woodside, NY 11377']},
#    'phone': '+17184268162',
#    'display_phone': '(718) 426-8162',
#    'distance': 5278.326423160265},
#   {'id': 'YIgBb6jb_KV0-nbYZ1oPig',
#    'alias': 'barn-na-thai-ridgewood',
#    'name': 'BARN NA THAI',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GAI2zkiVLyalqT0cX3K3vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-na-thai-ridgewood?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 16,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71012, 'longitude': -73.89958},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '6402 Fresh Pond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'RIDGEWOOD',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6402 Fresh Pond Rd', 'RIDGEWOOD, NY 11385']},
#    'phone': '+19293878065',
#    'display_phone': '(929) 387-8065',
#    'distance': 4594.843164144977},
#   {'id': 'W1L0UB1MvlhvkKTF43emSA',
#    'alias': 'jaew-hon-new-york-jackson-heights',
#    'name': 'Jaew Hon New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YfpU631zW4qs6WHrNyOZRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jaew-hon-new-york-jackson-heights?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 184,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7464487, 'longitude': -73.8938216},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '71-30 Roosevelt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71-30 Roosevelt Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+13479353085',
#    'display_phone': '(347) 935-3085',
#    'distance': 3833.3497253617165},
#   {'id': '_ArDQIKj5qHgmwNnnIaIIg',
#    'alias': 'i-am-thai-restaurant-woodside-2',
#    'name': 'I Am Thai Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-mXZpeTrwlFj6N788VriQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-am-thai-restaurant-woodside-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 286,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7445421133747,
#     'longitude': -73.9154577255249},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '49-08 43rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49-08 43rd Ave', 'Woodside, NY 11377']},
#    'phone': '+17184577700',
#    'display_phone': '(718) 457-7700',
#    'distance': 5472.0493295521055}],
#  'total': 2600,
#  'region': {'center': {'longitude': -73.85284423828125,
#    'latitude': 40.73146603137887}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'uazg6WhYVOw3jhWCG_MDBg',
#    'alias': 'sup-thai-kitchen-fresh-meadows',
#    'name': 'Sup Thai Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 373,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '178-19 Union Tpke',
#     'address2': None,
#     'address3': '',
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184874449',
#    'display_phone': '(718) 487-4449',
#    'distance': 5378.159709707153},
#   {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#    'alias': 'kind-fresh-meadows',
#    'name': "Kin'd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 767,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '192-03 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184680888',
#    'display_phone': '(718) 468-0888',
#    'distance': 6273.193942408963},
#   {'id': '1E7lCNaRAM1Da0vkt5rcvw',
#    'alias': 'thai-mission-maspeth',
#    'name': 'Thai Mission',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OTi0qCJS2HAyviRUwg-Qtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-mission-maspeth?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 29,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72779, 'longitude': -73.89279},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '70-11 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70-11 Grand Ave', 'Maspeth, NY 11378']},
#    'phone': '+19293280328',
#    'display_phone': '(929) 328-0328',
#    'distance': 3390.6012918832753},
#   {'id': '0L03onqNwxWLrbb_FCK79A',
#    'alias': 'sripraphai-thai-restaurant-woodside',
#    'name': 'SriPraPhai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2380,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '64-13 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17188999599',
#    'display_phone': '(718) 899-9599',
#    'distance': 4250.747809627073},
#   {'id': 'gr3wUszE1972q0GBkmwEXQ',
#    'alias': 'bangkok-cuisine-forest-hills',
#    'name': 'Bangkok Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8vTa_qflOZVu30D0k0HSTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-cuisine-forest-hills?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 421,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720954, 'longitude': -73.845238},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '10718 70th Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10718 70th Rd', 'Forest Hills, NY 11375']},
#    'phone': '+17182614005',
#    'display_phone': '(718) 261-4005',
#    'distance': 1329.980593467087},
#   {'id': '1ubEg-rrSE8IWXl6lJzIGw',
#    'alias': 'nur-thai-rego-park',
#    'name': 'Nur Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wKL4Mnmig42Youp-9eYUIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nur-thai-rego-park?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 561,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7235516378586,
#     'longitude': -73.868817789544},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63-32 Woodhaven Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-32 Woodhaven Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17182556141',
#    'display_phone': '(718) 255-6141',
#    'distance': 1608.1819342053043},
#   {'id': '3GMHPnrkFAcqffw3T7JSdQ',
#    'alias': 'kitchen-79-jackson-heights',
#    'name': 'Kitchen 79',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ip9F8-pOstZmt7_8T_46Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-79-jackson-heights?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 629,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747551, 'longitude': -73.8868866},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37-70 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-70 79th St', 'Jackson Heights, NY 11372']},
#    'phone': '+17188036227',
#    'display_phone': '(718) 803-6227',
#    'distance': 3388.369692606335},
#   {'id': 'fRO4Fwe5uRAajMcTwLbVkA',
#    'alias': 'ayada-thai-elmhurst-2',
#    'name': 'Ayada Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qybFSiSVmsTTXx5fmX3BNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ayada-thai-elmhurst-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1222,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433662414551,
#     'longitude': -73.8876037597656},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7708 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7708 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184240844',
#    'display_phone': '(718) 424-0844',
#    'distance': 3222.317210809843},
#   {'id': '-YazuZbXAM_NOny8LpLQpQ',
#    'alias': 'bkny-thai-restaurant-bayside',
#    'name': 'BKNY Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glVWdfDHW-eu4KhXWP3QMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkny-thai-restaurant-bayside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7530184239866,
#     'longitude': -73.780074009384},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '47-11 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-11 Francis Lewis Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182811900',
#    'display_phone': '(718) 281-1900',
#    'distance': 6582.441577772174},
#   {'id': 'OVAV0k2O1kqeuRFyt95qzg',
#    'alias': 'ma-kin-middle-village-3',
#    'name': 'Ma Kin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HKS9ClA3DITKpnzWjhFm6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ma-kin-middle-village-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 92,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7130368, 'longitude': -73.8775219},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7419 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Middle Village',
#     'zip_code': '11379',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7419 Metropolitan Ave', 'Middle Village, NY 11379']},
#    'phone': '+13475071234',
#    'display_phone': '(347) 507-1234',
#    'distance': 2915.288989938397},
#   {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#    'alias': 'pye-boat-noodle-astoria',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 837,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17186852329',
#    'display_phone': '(718) 685-2329',
#    'distance': 6625.086426070104},
#   {'id': 'oNN202L_XcNM-tuDHlgkfg',
#    'alias': 'boon-chu-thai-place-elmhurst',
#    'name': 'Boon Chu Thai Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ffVw7NKAcTDUIPfd5tUwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boon-chu-thai-place-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 313,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740638, 'longitude': -73.879645},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '83-18 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83-18 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17188986836',
#    'display_phone': '(718) 898-6836',
#    'distance': 2477.7303260455205},
#   {'id': 'STx4mlpKJVrjd6eZu4yDIw',
#    'alias': 'heng-thai-long-island-city',
#    'name': 'Heng Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNglrhhC7IGOBrdkTu-h-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heng-thai-long-island-city?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 10,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74491469312005,
#     'longitude': -73.94774386999885},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '23-06 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23-06 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17187060999',
#    'display_phone': '(718) 706-0999',
#    'distance': 8134.151172667756},
#   {'id': '5pzc2GdvdmqiLRSdjHnnKw',
#    'alias': 'bangkok-avenue-little-neck-2',
#    'name': 'Bangkok Avenue',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-6MNVU7V930qB3PvdLHKAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-avenue-little-neck-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77135, 'longitude': -73.73529},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '253-21 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Little Neck',
#     'zip_code': '11362',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253-21 Northern Blvd', 'Little Neck, NY 11362']},
#    'phone': '+19143033388',
#    'display_phone': '(914) 303-3388',
#    'distance': 10849.613791106447},
#   {'id': 'jMb34zhfkqoW866F10hf1Q',
#    'alias': 'grace-thai-restaurant-elmhurst',
#    'name': 'Grace Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JtXzAAG2jsoperWNGOANSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-thai-restaurant-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 52,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.736905, 'longitude': -73.865734},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '5617 Junction Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5617 Junction Blvd', 'Elmhurst, NY 11373']},
#    'phone': '+19294633693',
#    'display_phone': '(929) 463-3693',
#    'distance': 1241.9783887099397},
#   {'id': '1svF14BUYt_Wc0XA3nMxdw',
#    'alias': 'cha-lom-thai-flushing',
#    'name': 'Cha Lom Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LUcuIr0hXhAy8DMUMbClFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cha-lom-thai-flushing?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 59,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7663429058334,
#     'longitude': -73.7893586550144},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-47 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-47 Francis Lewis Blvd', 'Flushing, NY 11358']},
#    'phone': '+17182696821',
#    'display_phone': '(718) 269-6821',
#    'distance': 6606.083966623151},
#   {'id': 'PPQSf_1JWkbjFHi1S0nSNA',
#    'alias': 'lamoon-elmhurst',
#    'name': 'Lamoon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YNrzpdKbmrGLFOtPUwFW6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamoon-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 268,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742890245749, 'longitude': -73.883034010715},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8140 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8140 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19177451168',
#    'display_phone': '(917) 745-1168',
#    'distance': 2843.1620995374224},
#   {'id': 'Ve_iFpnhL8zN789ZL2jnxQ',
#    'alias': 'uthai-rego-park',
#    'name': 'UThai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EyX6yAydMLYFXZc7dY7PRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uthai-rego-park?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 219,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7282415, 'longitude': -73.8639467},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '63-55 Wetherole St',
#     'address2': None,
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-55 Wetherole St', 'Rego Park, NY 11374']},
#    'phone': '+17188971575',
#    'display_phone': '(718) 897-1575',
#    'distance': 1001.8808045720075},
#   {'id': 'tVB11pOiDhPWlt_o6ylMNg',
#    'alias': 'enthaice-thai-kitchen-astoria',
#    'name': 'Enthaice Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/poiYY93PvnCGFXQAEvO-Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enthaice-thai-kitchen-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 695,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7630889337809,
#     'longitude': -73.9213237166405},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-20 31st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-20 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17189321111',
#    'display_phone': '(718) 932-1111',
#    'distance': 6755.95967403878},
#   {'id': 'inftQdKaEEiqQ323AlomXg',
#    'alias': 'dek-sen-elmhurst-2',
#    'name': 'Dek Sen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VV_1YWKJXD_BEvAfQ2-wGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dek-sen-elmhurst-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 278,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.741714, 'longitude': -73.878689},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8608 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8608 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17182055181',
#    'display_phone': '(718) 205-5181',
#    'distance': 2452.1963359930987},
#   {'id': 'a23bfZBVjIhV32Em4hKHAA',
#    'alias': 'the-buffs-long-island-city-4',
#    'name': 'The Buffs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lQID-gz3kJ6Gw-Yr8rLVKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buffs-long-island-city-4?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 106,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7556342, 'longitude': -73.9417121},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1313 40th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1313 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183612362',
#    'display_phone': '(718) 361-2362',
#    'distance': 7918.772733558018},
#   {'id': 'CpY77cDN1KS5EdiXMmWovw',
#    'alias': 'house-of-thai-long-island-city-4',
#    'name': 'House of Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uZJDECEq7QBfrSIfyrPsRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-thai-long-island-city-4?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 301,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7535257695712,
#     'longitude': -73.9377629319284},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2501 40th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2501 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+19295220247',
#    'display_phone': '(929) 522-0247',
#    'distance': 7562.962070152043},
#   {'id': 'PyaeHq_UAu6nazGiy0XAnw',
#    'alias': 'ginger-and-lemongrass-whitestone',
#    'name': 'Ginger and Lemongrass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rc7pZR40ZmAVzeenf48eZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-lemongrass-whitestone?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 801,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7892691, 'longitude': -73.813717},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1253 150th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1253 150th St', 'Whitestone, NY 11357']},
#    'phone': '+13477324720',
#    'display_phone': '(347) 732-4720',
#    'distance': 7222.985916370918},
#   {'id': 'yCJHIM-PWl54K53ACOpoNg',
#    'alias': 'hug-esan-elmhurst',
#    'name': 'Hug Esan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6solnO-f4-uAP7irlf1MZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hug-esan-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 169,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7436465, 'longitude': -73.8873753},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '77-16 Woodside Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77-16 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+19293280392',
#    'display_phone': '(929) 328-0392',
#    'distance': 3209.1609507515063},
#   {'id': 'm2_ZNFos5ugAwe8ft8eaEw',
#    'alias': 'eim-khao-mun-kai-elmhurst-elmhurst',
#    'name': 'Eim Khao Mun Kai Elmhurst',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JqeuGqrZxCPGVowAEs8XFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eim-khao-mun-kai-elmhurst-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 457,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'hainan', 'title': 'Hainan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7429414097644,
#     'longitude': -73.8832733356575},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '81-32 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-32 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17184247156',
#    'display_phone': '(718) 424-7156',
#    'distance': 2863.74521041377},
#   {'id': 'kXuubLd6s3GidpqU3psPdw',
#    'alias': 'chao-thai-elmhurst-3',
#    'name': 'Chao Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sq1y11AFR9zp81X0aH9vKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chao-thai-elmhurst-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 379,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414656, 'longitude': -73.8801273},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8503 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8503 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184244999',
#    'display_phone': '(718) 424-4999',
#    'distance': 2568.855535856452},
#   {'id': 'hA5QUlrSjpxMZ90Kof0bgA',
#    'alias': 'khao-kang-elmhurst',
#    'name': 'Khao Kang',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vfRK27R36XLI4wHpZr6bHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-kang-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 244,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743269, 'longitude': -73.888039},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '7620 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7620 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17188061807',
#    'display_phone': '(718) 806-1807',
#    'distance': 3242.7336966969283},
#   {'id': 'a5H9p1B6m6WPVjakPylvdA',
#    'alias': 'spicy-shallot-elmhurst',
#    'name': 'Spicy Shallot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OzUSMfiNLzDNthJuYxni0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spicy-shallot-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 633,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7437053273707,
#     'longitude': -73.8878916857991},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7701 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7701 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17186725266',
#    'display_phone': '(718) 672-5266',
#    'distance': 3251.3867012082496},
#   {'id': 'rehmlZmUNL2AthW-VTXJJQ',
#    'alias': 'tasty-thai-ridgewood',
#    'name': 'Tasty Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NX0ocs11fl3Dj1kTmpBrRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-thai-ridgewood?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69984, 'longitude': -73.89958},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '72-04 Forest Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72-04 Forest Ave', 'Ridgewood, NY 11385']},
#    'phone': '+19179090937',
#    'display_phone': '(917) 909-0937',
#    'distance': 5281.3840549926945},
#   {'id': 'zRQNaDUoWTInc2tqndSJVA',
#    'alias': 'thai-101-bayside',
#    'name': 'Thai 101',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dvejY_8barqkhtUQt35Hkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-101-bayside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 306,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76488, 'longitude': -73.77133},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '39-15 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-15 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17186318600',
#    'display_phone': '(718) 631-8600',
#    'distance': 7803.89291133938},
#   {'id': 'YMcDo3UccCPvIJrQ5Yt9Yw',
#    'alias': 'chám-thai-cuisine-ridgewood',
#    'name': 'Chám Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_INscq_GSjWwiY03XfcQbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ch%C3%A1m-thai-cuisine-ridgewood?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 48,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7025939, 'longitude': -73.901464},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '881 Woodward Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['881 Woodward Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17188944404',
#    'display_phone': '(718) 894-4404',
#    'distance': 5205.517479140647},
#   {'id': 'wEawMdWT7UtZjEmmMTBiGA',
#    'alias': 'saranrom-thai-elmhurst-2',
#    'name': 'Saranrom Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kfH2mX_qFCnGegh9CUY_rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saranrom-thai-elmhurst-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 32,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7431528, 'longitude': -73.8836694},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '8110 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8110 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19178326672',
#    'display_phone': '(917) 832-6672',
#    'distance': 2905.2906392679156},
#   {'id': 'OR9oqAJW-U5ZnqhwH12Nuw',
#    'alias': 'khao-nom-elmhurst',
#    'name': 'Khao Nom',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fiPmRRzFIz4WRhuyAyGXXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-nom-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 116,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432731562959,
#     'longitude': -73.8879961885031},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '42-06 77th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 77th St', 'Elmhurst, NY 11373']},
#    'phone': '+19292080108',
#    'display_phone': '(929) 208-0108',
#    'distance': 3250.841753204315},
#   {'id': 'toykv8K0yg8qtvZSXRQ5bg',
#    'alias': 'pochana-thai-kitchen-astoria-2',
#    'name': 'Pochana Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5hfYhHZOsD9SRICjUaFpYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pochana-thai-kitchen-astoria-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 193,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765733, 'longitude': -73.91932},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-16 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-16 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17189569559',
#    'display_phone': '(718) 956-9559',
#    'distance': 6773.2440684776475},
#   {'id': 'dnCRiUZWgu5ZI4Q-Z-az6Q',
#    'alias': 'thai-diva-cuisine-woodside-3',
#    'name': 'Thai Diva Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FAxltkvgVnPp87i9Uq90Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-diva-cuisine-woodside-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 140,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414512, 'longitude': -73.9190131},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45-53 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-53 46th St', 'Woodside, NY 11377']},
#    'phone': '+19292080282',
#    'display_phone': '(929) 208-0282',
#    'distance': 5684.506606279269},
#   {'id': 'ipxeCjihDqXTMkuPe-CQ4A',
#    'alias': 'arunee-thai-jackson-heights',
#    'name': 'Arunee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yBzXFJre13F2BtJNRiWAlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arunee-thai-jackson-heights?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7494503, 'longitude': -73.8873621},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '78-23 37th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78-23 37th Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+17182055559',
#    'display_phone': '(718) 205-5559',
#    'distance': 3529.3232402943213},
#   {'id': '8-dc942sz-prIeepAkHLJA',
#    'alias': 'zenith-thai-restaurant-ridgewood',
#    'name': 'Zenith Thai Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P5WjD6_4bZyV6AVgkeceaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zenith-thai-restaurant-ridgewood?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 113,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7023726, 'longitude': -73.8952926},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7002 Fresh Pond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7002 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '+17184978899',
#    'display_phone': '(718) 497-8899',
#    'distance': 4825.743443483346},
#   {'id': 'Eyn7hQENF8R9DrBwBHO6lQ',
#    'alias': 'pata-cafe-elmhurst',
#    'name': 'Pata Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XaAZQtUInh_RNGATh7ImpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pata-cafe-elmhurst?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 73,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7326341, 'longitude': -73.8769762},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5614 Van Horn St',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5614 Van Horn St', 'Elmhurst, NY 11373']},
#    'phone': '+13474697142',
#    'display_phone': '(347) 469-7142',
#    'distance': 2013.709004982964},
#   {'id': 'f7jZvRH-h76F4emzvKytaQ',
#    'alias': 'tuk-tuk-long-island-city',
#    'name': 'Tuk Tuk',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r_ALzLJ-56hQq6Wvk9jwFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuk-tuk-long-island-city?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 697,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743232, 'longitude': -73.954254},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4906 Vernon Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4906 Vernon Blvd', 'Long Island City, NY 11101']},
#    'phone': '+17184725598',
#    'display_phone': '(718) 472-5598',
#    'distance': 8642.2312908624},
#   {'id': 'JX5QkNfMd-jP-Nz5iQ_QeA',
#    'alias': 'thai-nara-halal-restaurant-woodside',
#    'name': 'Thai Nara Halal Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EN6EwzOYv9NjoNdxjNhexw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-nara-halal-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 50,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75011, 'longitude': -73.89848},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '64-02 35th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-02 35th Ave', 'Woodside, NY 11377']},
#    'phone': '+17186068842',
#    'display_phone': '(718) 606-8842',
#    'distance': 4368.173178694347},
#   {'id': '2ZBEE_MJeRdLD1NLiNTnCQ',
#    'alias': 'thailands-center-point-woodside-2',
#    'name': "Thailand's Center Point",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o99eLojQrJOaEe1keKZEug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thailands-center-point-woodside-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 196,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746738, 'longitude': -73.900162},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63-19 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-19 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17186516888',
#    'display_phone': '(718) 651-6888',
#    'distance': 4333.1887147697735},
#   {'id': 'ET4xGd-SQ6gs9lce4xVpQg',
#    'alias': 'tum-thai-cuisine-rockville-centre',
#    'name': 'Tum Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0keHJi1yLq97gnDyCeM7UQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tum-thai-cuisine-rockville-centre?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 641,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65591, 'longitude': -73.64574},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '274 Merrick Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockville Centre',
#     'zip_code': '11570',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Merrick Rd', 'Rockville Centre, NY 11570']},
#    'phone': '+15165435078',
#    'display_phone': '(516) 543-5078',
#    'distance': 19384.513491944435},
#   {'id': 'nu239sXQUGjcGFhZ3AdJmQ',
#    'alias': 'erawan-thai-cuisine-bayside',
#    'name': 'Erawan Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x_vmcrpshZxNmtw9sKHzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/erawan-thai-cuisine-bayside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 346,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.761821, 'longitude': -73.769775},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4231 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4231 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17184282112',
#    'display_phone': '(718) 428-2112',
#    'distance': 7766.294526950914},
#   {'id': '2pJ782hnKTK0MWbc0H7EDw',
#    'alias': 'ditmars-thai-astoria',
#    'name': 'Ditmars Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P4ei6AZRi77oR6HcHLJMbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ditmars-thai-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 12,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77473, 'longitude': -73.90825},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '35-13 Ditmars Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17182694549',
#    'display_phone': '(718) 269-4549',
#    'distance': 6703.073797984971},
#   {'id': 'QWskQ2QpR8bmza2FRFziOQ',
#    'alias': 'asian-fortune-restaurant-forest-hills',
#    'name': 'Asian Fortune Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Av0ZXxYsKSXnZ8z182gh0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asian-fortune-restaurant-forest-hills?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 114,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7244621, 'longitude': -73.8493213},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '103-35 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103-35 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188306313',
#    'display_phone': '(718) 830-6313',
#    'distance': 851.8262088216507},
#   {'id': 'khvnn7cpiYSpe80ue5YLvg',
#    'alias': 'ddee-thai-astoria',
#    'name': 'Ddee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mVpYungatdQ1AFuujOjTdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ddee-thai-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 37,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.762909, 'longitude': -73.91325},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '42-06 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17186261222',
#    'display_phone': '(718) 626-1222',
#    'distance': 6173.635697332506},
#   {'id': 'MxMWPaC30sRkPKit_Omz2A',
#    'alias': 'khun-noo-thai-noodle-house-woodside',
#    'name': 'Khun Noo Thai Noodle House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85O4rR5ovWEeOa7sy1El2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khun-noo-thai-noodle-house-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 51,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74568, 'longitude': -73.91261},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '51-20 Skillman Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51-20 Skillman Ave', 'Woodside, NY 11377']},
#    'phone': '+17184268162',
#    'display_phone': '(718) 426-8162',
#    'distance': 5278.326423160265},
#   {'id': 'YIgBb6jb_KV0-nbYZ1oPig',
#    'alias': 'barn-na-thai-ridgewood',
#    'name': 'BARN NA THAI',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GAI2zkiVLyalqT0cX3K3vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-na-thai-ridgewood?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 16,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71012, 'longitude': -73.89958},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '6402 Fresh Pond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'RIDGEWOOD',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6402 Fresh Pond Rd', 'RIDGEWOOD, NY 11385']},
#    'phone': '+19293878065',
#    'display_phone': '(929) 387-8065',
#    'distance': 4594.843164144977},
#   {'id': 'W1L0UB1MvlhvkKTF43emSA',
#    'alias': 'jaew-hon-new-york-jackson-heights',
#    'name': 'Jaew Hon New York',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YfpU631zW4qs6WHrNyOZRA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jaew-hon-new-york-jackson-heights?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 184,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7464487, 'longitude': -73.8938216},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '71-30 Roosevelt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71-30 Roosevelt Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+13479353085',
#    'display_phone': '(347) 935-3085',
#    'distance': 3833.3497253617165},
#   {'id': '_ArDQIKj5qHgmwNnnIaIIg',
#    'alias': 'i-am-thai-restaurant-woodside-2',
#    'name': 'I Am Thai Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-mXZpeTrwlFj6N788VriQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/i-am-thai-restaurant-woodside-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 286,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7445421133747,
#     'longitude': -73.9154577255249},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '49-08 43rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['49-08 43rd Ave', 'Woodside, NY 11377']},
#    'phone': '+17184577700',
#    'display_phone': '(718) 457-7700',
#    'distance': 5472.0493295521055}],
#  'total': 2600,
#  'region': {'center': {'longitude': -73.85284423828125,
#    'latitude': 40.73146603137887}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = response.json()

# %% [markdown]
# What are the keys in this dictionary and the datatypes of their values.

# %%
# your code here
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
data['businesses'][0]
# Out:
# {'id': 'uazg6WhYVOw3jhWCG_MDBg',
#  'alias': 'sup-thai-kitchen-fresh-meadows',
#  'name': 'Sup Thai Kitchen',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#  'review_count': 373,
#  'categories': [{'alias': 'thai', 'title': 'Thai'},
#   {'alias': 'seafood', 'title': 'Seafood'},
#   {'alias': 'noodles', 'title': 'Noodles'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '178-19 Union Tpke',
#   'address2': None,
#   'address3': '',
#   'city': 'Fresh Meadows',
#   'zip_code': '11366',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#  'phone': '+17184874449',
#  'display_phone': '(718) 487-4449',
#  'distance': 5378.159709707153}

# %% [markdown]
# How many results did our query return?

# %%
data['total']
# Out:
# 2600

# %% [markdown]
# How many businesses were returned from the API call?

# %%
len(data['businesses'])
# Out:
# 50

# %%
def yelp_call(url_params):
    
    response = requests.get(url, headers=headers, params=url_params)
    return response.json()['businesses']

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][0]

# %%
business
# Out:
# {'id': 'uazg6WhYVOw3jhWCG_MDBg',
#  'alias': 'sup-thai-kitchen-fresh-meadows',
#  'name': 'Sup Thai Kitchen',
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#  'review_count': 373,
#  'categories': [{'alias': 'thai', 'title': 'Thai'},
#   {'alias': 'seafood', 'title': 'Seafood'},
#   {'alias': 'noodles', 'title': 'Noodles'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '178-19 Union Tpke',
#   'address2': None,
#   'address3': '',
#   'city': 'Fresh Meadows',
#   'zip_code': '11366',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#  'phone': '+17184874449',
#  'display_phone': '(718) 487-4449',
#  'distance': 5378.159709707153}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_tuple = (business['name'], business['location']['address1'], business['rating'],business['price'],business['location']['zip_code'], business['transactions'],business['review_count'],business['categories'])

# %%
biz_tuple
# Out:
# ('Sup Thai Kitchen',
#  '178-19 Union Tpke',
#  4.5,
#  '$$',
#  '11366',
#  ['pickup', 'delivery'],
#  373,
#  [{'alias': 'thai', 'title': 'Thai'},
#   {'alias': 'seafood', 'title': 'Seafood'},
#   {'alias': 'noodles', 'title': 'Noodles'}])

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data, biz_tuple):
    # create a container to hold our parsed data
    biz_list = []
    # loop through our business and 
    for business in list_of_data:
    # parse each individual business into a tuple
        try:
            biz_tuple = (business['name'],
                     business['location']['address1'],
                     business['rating'],
                     business['price'],
                     business['location']['zip_code'],
                     business['transactions'],
                     business['review_count'],
                     business['categories'])   
    # add each individual business tuple to our data container
            biz_list.append(biz_tuple)
        except:
            continue
    # return the container with all of the parsed results
    return biz_list

# %%
parsed_results = parse_data(data['businesses'], biz_tuple)

# %%
parsed_results
# Out:
# [('Sup Thai Kitchen',
#   '178-19 Union Tpke',
#   4.5,
#   '$$',
#   '11366',
#   ['pickup', 'delivery'],
#   373,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'noodles', 'title': 'Noodles'}]),
#  ("Kin'd",
#   '192-03 Union Tpke',
#   4.5,
#   '$$',
#   '11366',
#   ['pickup', 'delivery'],
#   767,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('SriPraPhai Thai Restaurant',
#   '64-13 39th Ave',
#   4.0,
#   '$$',
#   '11377',
#   [],
#   2380,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Bangkok Cuisine',
#   '10718 70th Rd',
#   4.0,
#   '$$',
#   '11375',
#   ['pickup', 'delivery'],
#   421,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Nur Thai',
#   '63-32 Woodhaven Blvd',
#   4.0,
#   '$$',
#   '11374',
#   ['pickup', 'delivery'],
#   561,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Kitchen 79',
#   '37-70 79th St',
#   4.5,
#   '$$',
#   '11372',
#   ['pickup', 'delivery'],
#   629,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Ayada Thai',
#   '7708 Woodside Ave',
#   4.0,
#   '$$',
#   '11373',
#   ['pickup', 'delivery'],
#   1222,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]),
#  ('BKNY Thai Restaurant',
#   '47-11 Francis Lewis Blvd',
#   4.0,
#   '$$',
#   '11361',
#   ['delivery'],
#   1317,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'salad', 'title': 'Salad'}]),
#  ('Pye Boat Noodle',
#   '35-13 Broadway',
#   4.5,
#   '$$',
#   '11106',
#   ['delivery'],
#   837,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'}]),
#  ('Boon Chu Thai Place',
#   '83-18 Broadway',
#   4.0,
#   '$',
#   '11373',
#   ['pickup', 'delivery'],
#   313,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Bangkok Avenue',
#   '253-21 Northern Blvd',
#   5.0,
#   '$$',
#   '11362',
#   ['pickup', 'delivery'],
#   86,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'}]),
#  ('Cha Lom Thai',
#   '33-47 Francis Lewis Blvd',
#   4.5,
#   '$$',
#   '11358',
#   ['pickup', 'delivery'],
#   59,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Lamoon',
#   '8140 Broadway',
#   4.5,
#   '$$',
#   '11373',
#   ['pickup', 'delivery'],
#   268,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('UThai',
#   '63-55 Wetherole St',
#   4.0,
#   '$',
#   '11374',
#   ['pickup', 'delivery'],
#   219,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'noodles', 'title': 'Noodles'}]),
#  ('Enthaice Thai Kitchen',
#   '33-20 31st Ave',
#   4.0,
#   '$$',
#   '11106',
#   ['pickup', 'delivery'],
#   695,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}]),
#  ('Dek Sen',
#   '8608 Whitney Ave',
#   4.0,
#   '$$',
#   '11373',
#   ['pickup', 'delivery'],
#   278,
#   [{'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'}]),
#  ('The Buffs',
#   '1313 40th Ave',
#   4.5,
#   '$$',
#   '11101',
#   ['pickup', 'delivery'],
#   106,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'ramen', 'title': 'Ramen'}]),
#  ('House of Thai',
#   '2501 40th Ave',
#   4.0,
#   '$$',
#   '11101',
#   ['pickup', 'delivery'],
#   301,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Ginger and Lemongrass',
#   '1253 150th St',
#   4.0,
#   '$$',
#   '11357',
#   ['pickup', 'delivery'],
#   801,
#   [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'thai', 'title': 'Thai'}]),
#  ('Hug Esan',
#   '77-16 Woodside Ave',
#   4.5,
#   '$$',
#   '11373',
#   ['pickup', 'delivery'],
#   169,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Eim Khao Mun Kai Elmhurst',
#   '81-32 Broadway',
#   4.5,
#   '$',
#   '11373',
#   [],
#   457,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'hainan', 'title': 'Hainan'}]),
#  ('Chao Thai',
#   '8503 Whitney Ave',
#   4.0,
#   '$$',
#   '11373',
#   ['pickup', 'delivery'],
#   379,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Khao Kang',
#   '7620 Woodside Ave',
#   4.0,
#   '$',
#   '11373',
#   ['pickup', 'delivery'],
#   244,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Spicy Shallot',
#   '7701 Woodside Ave',
#   4.0,
#   '$$',
#   '11373',
#   ['pickup', 'delivery'],
#   633,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'bars', 'title': 'Bars'}]),
#  ('Tasty Thai',
#   '72-04 Forest Ave',
#   4.0,
#   '$',
#   '11385',
#   ['pickup', 'delivery'],
#   86,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Thai 101',
#   '39-15 Bell Blvd',
#   3.5,
#   '$$',
#   '11361',
#   ['pickup', 'delivery'],
#   306,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Chám Thai Cuisine',
#   '881 Woodward Ave',
#   3.5,
#   '$$',
#   '11385',
#   ['pickup', 'delivery'],
#   48,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Khao Nom',
#   '42-06 77th St',
#   4.5,
#   '$$',
#   '11373',
#   ['pickup', 'delivery'],
#   116,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}]),
#  ('Pochana Thai Kitchen',
#   '33-16 30th Ave',
#   4.0,
#   '$$',
#   '11103',
#   ['pickup', 'delivery'],
#   193,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Thai Diva Cuisine',
#   '45-53 46th St',
#   4.0,
#   '$$',
#   '11377',
#   ['pickup', 'delivery'],
#   140,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'soup', 'title': 'Soup'}]),
#  ('Arunee Thai',
#   '78-23 37th Ave',
#   4.0,
#   '$$',
#   '11372',
#   ['pickup', 'delivery'],
#   317,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Zenith Thai Restaurant',
#   '7002 Fresh Pond Rd',
#   4.0,
#   '$$',
#   '11385',
#   ['pickup', 'delivery'],
#   113,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Pata Cafe',
#   '5614 Van Horn St',
#   4.5,
#   '$$',
#   '11373',
#   ['pickup', 'delivery'],
#   73,
#   [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'thai', 'title': 'Thai'}]),
#  ('Tuk Tuk',
#   '4906 Vernon Blvd',
#   4.0,
#   '$$',
#   '11101',
#   ['delivery'],
#   697,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Thai Nara Halal Restaurant',
#   '64-02 35th Ave',
#   4.5,
#   '$$',
#   '11377',
#   ['pickup', 'delivery'],
#   50,
#   [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'halal', 'title': 'Halal'}]),
#  ("Thailand's Center Point",
#   '63-19 39th Ave',
#   4.0,
#   '$$',
#   '11377',
#   ['pickup', 'delivery'],
#   196,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'seafood', 'title': 'Seafood'}]),
#  ('Tum Thai Cuisine',
#   '274 Merrick Rd',
#   4.5,
#   '$$',
#   '11570',
#   ['delivery'],
#   641,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Erawan Thai Cuisine',
#   '4231 Bell Blvd',
#   3.5,
#   '$$',
#   '11361',
#   ['pickup', 'delivery'],
#   346,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Asian Fortune Restaurant',
#   '103-35 Queens Blvd',
#   4.0,
#   '$$',
#   '11375',
#   ['pickup', 'delivery'],
#   114,
#   [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'thai', 'title': 'Thai'}]),
#  ('Ddee Thai',
#   '42-06 30th Ave',
#   4.5,
#   '$$',
#   '11103',
#   ['pickup', 'delivery'],
#   37,
#   [{'alias': 'thai', 'title': 'Thai'}]),
#  ('Jaew Hon New York',
#   '71-30 Roosevelt Ave',
#   4.5,
#   '$$',
#   '11372',
#   ['pickup', 'delivery'],
#   184,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'hotpot', 'title': 'Hot Pot'}]),
#  ('I Am Thai Restaurant',
#   '49-08 43rd Ave',
#   4.0,
#   '$$',
#   '11377',
#   [],
#   286,
#   [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'vegan', 'title': 'Vegan'}])]

# %% [markdown]
# Take the parsed results and put them in a Dataframe.

# %%
import pandas as pd

# %%
business_df = pd.DataFrame(parsed_results, columns =['Name', 'Location', 'Rating', 'Price', 'Zipcode', 'Transactions', 'Review Count', 'Categories'])

# %%
business_df.to_csv('business_csv')

# %%
new_df = pd.read_csv('/Users/ryanlewis/Documents/Flatiron_020121/nyc-dc-ds-020121/Phase_1/ds-apis_json-main/business_csv', delimiter = ",")

# %%
new_df
# Out:
#     Unnamed: 0                        Name                  Location  Rating  \
# 0            0            Sup Thai Kitchen         178-19 Union Tpke     4.5
# 1            1                       Kin'd         192-03 Union Tpke     4.5
# 2            2  SriPraPhai Thai Restaurant            64-13 39th Ave     4.0
# 3            3             Bangkok Cuisine             10718 70th Rd     4.0
# 4            4                    Nur Thai      63-32 Woodhaven Blvd     4.0
# 5            5                  Kitchen 79             37-70 79th St     4.5
# 6            6                  Ayada Thai         7708 Woodside Ave     4.0
# 7            7        BKNY Thai Restaurant  47-11 Francis Lewis Blvd     4.0
# 8            8             Pye Boat Noodle            35-13 Broadway     4.5
# 9            9         Boon Chu Thai Place            83-18 Broadway     4.0
# 10          10              Bangkok Avenue      253-21 Northern Blvd     5.0
# 11          11                Cha Lom Thai  33-47 Francis Lewis Blvd     4.5
# 12          12                      Lamoon             8140 Broadway     4.5
# 13          13                       UThai        63-55 Wetherole St     4.0
# 14          14       Enthaice Thai Kitchen            33-20 31st Ave     4.0
# 15          15                     Dek Sen          8608 Whitney Ave     4.0
# 16          16                   The Buffs             1313 40th Ave     4.5
# 17          17               House of Thai             2501 40th Ave     4.0
# 18          18       Ginger and Lemongrass             1253 150th St     4.0
# 19          19                    Hug Esan        77-16 Woodside Ave     4.5
# 20          20   Eim Khao Mun Kai Elmhurst            81-32 Broadway     4.5
# 21          21                   Chao Thai          8503 Whitney Ave     4.0
# 22          22                   Khao Kang         7620 Woodside Ave     4.0
# 23          23               Spicy Shallot         7701 Woodside Ave     4.0
# 24          24                  Tasty Thai          72-04 Forest Ave     4.0
# 25          25                    Thai 101           39-15 Bell Blvd     3.5
# 26          26           Chám Thai Cuisine          881 Woodward Ave     3.5
# 27          27                    Khao Nom             42-06 77th St     4.5
# 28          28        Pochana Thai Kitchen            33-16 30th Ave     4.0
# 29          29           Thai Diva Cuisine             45-53 46th St     4.0
# 30          30                 Arunee Thai            78-23 37th Ave     4.0
# 31          31      Zenith Thai Restaurant        7002 Fresh Pond Rd     4.0
# 32          32                   Pata Cafe          5614 Van Horn St     4.5
# 33          33                     Tuk Tuk          4906 Vernon Blvd     4.0
# 34          34  Thai Nara Halal Restaurant            64-02 35th Ave     4.5
# 35          35     Thailand's Center Point            63-19 39th Ave     4.0
# 36          36            Tum Thai Cuisine            274 Merrick Rd     4.5
# 37          37         Erawan Thai Cuisine            4231 Bell Blvd     3.5
# 38          38    Asian Fortune Restaurant        103-35 Queens Blvd     4.0
# 39          39                   Ddee Thai            42-06 30th Ave     4.5
# 40          40           Jaew Hon New York       71-30 Roosevelt Ave     4.5
# 41          41        I Am Thai Restaurant            49-08 43rd Ave     4.0
#
#    Price  Zipcode            Transactions  Review Count  \
# 0     $$    11366  ['pickup', 'delivery']           373
# 1     $$    11366  ['pickup', 'delivery']           767
# 2     $$    11377                      []          2380
# 3     $$    11375  ['pickup', 'delivery']           421
# 4     $$    11374  ['pickup', 'delivery']           561
# 5     $$    11372  ['pickup', 'delivery']           629
# 6     $$    11373  ['pickup', 'delivery']          1222
# 7     $$    11361            ['delivery']          1317
# 8     $$    11106            ['delivery']           837
# 9      $    11373  ['pickup', 'delivery']           313
# 10    $$    11362  ['pickup', 'delivery']            86
# 11    $$    11358  ['pickup', 'delivery']            59
# 12    $$    11373  ['pickup', 'delivery']           268
# 13     $    11374  ['pickup', 'delivery']           219
# 14    $$    11106  ['pickup', 'delivery']           695
# 15    $$    11373  ['pickup', 'delivery']           278
# 16    $$    11101  ['pickup', 'delivery']           106
# 17    $$    11101  ['pickup', 'delivery']           301
# 18    $$    11357  ['pickup', 'delivery']           801
# 19    $$    11373  ['pickup', 'delivery']           169
# 20     $    11373                      []           457
# 21    $$    11373  ['pickup', 'delivery']           379
# 22     $    11373  ['pickup', 'delivery']           244
# 23    $$    11373  ['pickup', 'delivery']           633
# 24     $    11385  ['pickup', 'delivery']            86
# 25    $$    11361  ['pickup', 'delivery']           306
# 26    $$    11385  ['pickup', 'delivery']            48
# 27    $$    11373  ['pickup', 'delivery']           116
# 28    $$    11103  ['pickup', 'delivery']           193
# 29    $$    11377  ['pickup', 'delivery']           140
# 30    $$    11372  ['pickup', 'delivery']           317
# 31    $$    11385  ['pickup', 'delivery']           113
# 32    $$    11373  ['pickup', 'delivery']            73
# 33    $$    11101            ['delivery']           697
# 34    $$    11377  ['pickup', 'delivery']            50
# 35    $$    11377  ['pickup', 'delivery']           196
# 36    $$    11570            ['delivery']           641
# 37    $$    11361  ['pickup', 'delivery']           346
# 38    $$    11375  ['pickup', 'delivery']           114
# 39    $$    11103  ['pickup', 'delivery']            37
# 40    $$    11372  ['pickup', 'delivery']           184
# 41    $$    11377                      []           286
#
#                                            Categories
# 0   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 1                [{'alias': 'thai', 'title': 'Thai'}]
# 2                [{'alias': 'thai', 'title': 'Thai'}]
# 3                [{'alias': 'thai', 'title': 'Thai'}]
# 4                [{'alias': 'thai', 'title': 'Thai'}]
# 5                [{'alias': 'thai', 'title': 'Thai'}]
# 6   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 7   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 8   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 9                [{'alias': 'thai', 'title': 'Thai'}]
# 10  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 11               [{'alias': 'thai', 'title': 'Thai'}]
# 12               [{'alias': 'thai', 'title': 'Thai'}]
# 13  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 14  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 15  [{'alias': 'desserts', 'title': 'Desserts'}, {...
# 16  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 17               [{'alias': 'thai', 'title': 'Thai'}]
# 18  [{'alias': 'vietnamese', 'title': 'Vietnamese'...
# 19               [{'alias': 'thai', 'title': 'Thai'}]
# 20  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 21               [{'alias': 'thai', 'title': 'Thai'}]
# 22               [{'alias': 'thai', 'title': 'Thai'}]
# 23  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 24               [{'alias': 'thai', 'title': 'Thai'}]
# 25               [{'alias': 'thai', 'title': 'Thai'}]
# 26               [{'alias': 'thai', 'title': 'Thai'}]
# 27  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 28               [{'alias': 'thai', 'title': 'Thai'}]
# 29  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 30               [{'alias': 'thai', 'title': 'Thai'}]
# 31               [{'alias': 'thai', 'title': 'Thai'}]
# 32  [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...
# 33               [{'alias': 'thai', 'title': 'Thai'}]
# 34  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 35  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 36               [{'alias': 'thai', 'title': 'Thai'}]
# 37               [{'alias': 'thai', 'title': 'Thai'}]
# 38  [{'alias': 'asianfusion', 'title': 'Asian Fusi...
# 39               [{'alias': 'thai', 'title': 'Thai'}]
# 40  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# 41  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...

# %%
new_df = new_df.drop('Unnamed: 0', axis=1)

# %%
new_df = new_df.set_index('Name')

# %%
new_df
# Out:
#                                             Location  Rating Price  Zipcode  \
# Name
# Sup Thai Kitchen                   178-19 Union Tpke     4.5    $$    11366
# Kin'd                              192-03 Union Tpke     4.5    $$    11366
# SriPraPhai Thai Restaurant            64-13 39th Ave     4.0    $$    11377
# Bangkok Cuisine                        10718 70th Rd     4.0    $$    11375
# Nur Thai                        63-32 Woodhaven Blvd     4.0    $$    11374
# Kitchen 79                             37-70 79th St     4.5    $$    11372
# Ayada Thai                         7708 Woodside Ave     4.0    $$    11373
# BKNY Thai Restaurant        47-11 Francis Lewis Blvd     4.0    $$    11361
# Pye Boat Noodle                       35-13 Broadway     4.5    $$    11106
# Boon Chu Thai Place                   83-18 Broadway     4.0     $    11373
# Bangkok Avenue                  253-21 Northern Blvd     5.0    $$    11362
# Cha Lom Thai                33-47 Francis Lewis Blvd     4.5    $$    11358
# Lamoon                                 8140 Broadway     4.5    $$    11373
# UThai                             63-55 Wetherole St     4.0     $    11374
# Enthaice Thai Kitchen                 33-20 31st Ave     4.0    $$    11106
# Dek Sen                             8608 Whitney Ave     4.0    $$    11373
# The Buffs                              1313 40th Ave     4.5    $$    11101
# House of Thai                          2501 40th Ave     4.0    $$    11101
# Ginger and Lemongrass                  1253 150th St     4.0    $$    11357
# Hug Esan                          77-16 Woodside Ave     4.5    $$    11373
# Eim Khao Mun Kai Elmhurst             81-32 Broadway     4.5     $    11373
# Chao Thai                           8503 Whitney Ave     4.0    $$    11373
# Khao Kang                          7620 Woodside Ave     4.0     $    11373
# Spicy Shallot                      7701 Woodside Ave     4.0    $$    11373
# Tasty Thai                          72-04 Forest Ave     4.0     $    11385
# Thai 101                             39-15 Bell Blvd     3.5    $$    11361
# Chám Thai Cuisine                   881 Woodward Ave     3.5    $$    11385
# Khao Nom                               42-06 77th St     4.5    $$    11373
# Pochana Thai Kitchen                  33-16 30th Ave     4.0    $$    11103
# Thai Diva Cuisine                      45-53 46th St     4.0    $$    11377
# Arunee Thai                           78-23 37th Ave     4.0    $$    11372
# Zenith Thai Restaurant            7002 Fresh Pond Rd     4.0    $$    11385
# Pata Cafe                           5614 Van Horn St     4.5    $$    11373
# Tuk Tuk                             4906 Vernon Blvd     4.0    $$    11101
# Thai Nara Halal Restaurant            64-02 35th Ave     4.5    $$    11377
# Thailand's Center Point               63-19 39th Ave     4.0    $$    11377
# Tum Thai Cuisine                      274 Merrick Rd     4.5    $$    11570
# Erawan Thai Cuisine                   4231 Bell Blvd     3.5    $$    11361
# Asian Fortune Restaurant          103-35 Queens Blvd     4.0    $$    11375
# Ddee Thai                             42-06 30th Ave     4.5    $$    11103
# Jaew Hon New York                71-30 Roosevelt Ave     4.5    $$    11372
# I Am Thai Restaurant                  49-08 43rd Ave     4.0    $$    11377
#
#                                       Transactions  Review Count  \
# Name
# Sup Thai Kitchen            ['pickup', 'delivery']           373
# Kin'd                       ['pickup', 'delivery']           767
# SriPraPhai Thai Restaurant                      []          2380
# Bangkok Cuisine             ['pickup', 'delivery']           421
# Nur Thai                    ['pickup', 'delivery']           561
# Kitchen 79                  ['pickup', 'delivery']           629
# Ayada Thai                  ['pickup', 'delivery']          1222
# BKNY Thai Restaurant                  ['delivery']          1317
# Pye Boat Noodle                       ['delivery']           837
# Boon Chu Thai Place         ['pickup', 'delivery']           313
# Bangkok Avenue              ['pickup', 'delivery']            86
# Cha Lom Thai                ['pickup', 'delivery']            59
# Lamoon                      ['pickup', 'delivery']           268
# UThai                       ['pickup', 'delivery']           219
# Enthaice Thai Kitchen       ['pickup', 'delivery']           695
# Dek Sen                     ['pickup', 'delivery']           278
# The Buffs                   ['pickup', 'delivery']           106
# House of Thai               ['pickup', 'delivery']           301
# Ginger and Lemongrass       ['pickup', 'delivery']           801
# Hug Esan                    ['pickup', 'delivery']           169
# Eim Khao Mun Kai Elmhurst                       []           457
# Chao Thai                   ['pickup', 'delivery']           379
# Khao Kang                   ['pickup', 'delivery']           244
# Spicy Shallot               ['pickup', 'delivery']           633
# Tasty Thai                  ['pickup', 'delivery']            86
# Thai 101                    ['pickup', 'delivery']           306
# Chám Thai Cuisine           ['pickup', 'delivery']            48
# Khao Nom                    ['pickup', 'delivery']           116
# Pochana Thai Kitchen        ['pickup', 'delivery']           193
# Thai Diva Cuisine           ['pickup', 'delivery']           140
# Arunee Thai                 ['pickup', 'delivery']           317
# Zenith Thai Restaurant      ['pickup', 'delivery']           113
# Pata Cafe                   ['pickup', 'delivery']            73
# Tuk Tuk                               ['delivery']           697
# Thai Nara Halal Restaurant  ['pickup', 'delivery']            50
# Thailand's Center Point     ['pickup', 'delivery']           196
# Tum Thai Cuisine                      ['delivery']           641
# Erawan Thai Cuisine         ['pickup', 'delivery']           346
# Asian Fortune Restaurant    ['pickup', 'delivery']           114
# Ddee Thai                   ['pickup', 'delivery']            37
# Jaew Hon New York           ['pickup', 'delivery']           184
# I Am Thai Restaurant                            []           286
#
#                                                                    Categories
# Name
# Sup Thai Kitchen            [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Kin'd                                    [{'alias': 'thai', 'title': 'Thai'}]
# SriPraPhai Thai Restaurant               [{'alias': 'thai', 'title': 'Thai'}]
# Bangkok Cuisine                          [{'alias': 'thai', 'title': 'Thai'}]
# Nur Thai                                 [{'alias': 'thai', 'title': 'Thai'}]
# Kitchen 79                               [{'alias': 'thai', 'title': 'Thai'}]
# Ayada Thai                  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# BKNY Thai Restaurant        [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Pye Boat Noodle             [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Boon Chu Thai Place                      [{'alias': 'thai', 'title': 'Thai'}]
# Bangkok Avenue              [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Cha Lom Thai                             [{'alias': 'thai', 'title': 'Thai'}]
# Lamoon                                   [{'alias': 'thai', 'title': 'Thai'}]
# UThai                       [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Enthaice Thai Kitchen       [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Dek Sen                     [{'alias': 'desserts', 'title': 'Desserts'}, {...
# The Buffs                   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# House of Thai                            [{'alias': 'thai', 'title': 'Thai'}]
# Ginger and Lemongrass       [{'alias': 'vietnamese', 'title': 'Vietnamese'...
# Hug Esan                                 [{'alias': 'thai', 'title': 'Thai'}]
# Eim Khao Mun Kai Elmhurst   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Chao Thai                                [{'alias': 'thai', 'title': 'Thai'}]
# Khao Kang                                [{'alias': 'thai', 'title': 'Thai'}]
# Spicy Shallot               [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Tasty Thai                               [{'alias': 'thai', 'title': 'Thai'}]
# Thai 101                                 [{'alias': 'thai', 'title': 'Thai'}]
# Chám Thai Cuisine                        [{'alias': 'thai', 'title': 'Thai'}]
# Khao Nom                    [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Pochana Thai Kitchen                     [{'alias': 'thai', 'title': 'Thai'}]
# Thai Diva Cuisine           [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Arunee Thai                              [{'alias': 'thai', 'title': 'Thai'}]
# Zenith Thai Restaurant                   [{'alias': 'thai', 'title': 'Thai'}]
# Pata Cafe                   [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...
# Tuk Tuk                                  [{'alias': 'thai', 'title': 'Thai'}]
# Thai Nara Halal Restaurant  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Thailand's Center Point     [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# Tum Thai Cuisine                         [{'alias': 'thai', 'title': 'Thai'}]
# Erawan Thai Cuisine                      [{'alias': 'thai', 'title': 'Thai'}]
# Asian Fortune Restaurant    [{'alias': 'asianfusion', 'title': 'Asian Fusi...
# Ddee Thai                                [{'alias': 'thai', 'title': 'Thai'}]
# Jaew Hon New York           [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
# I Am Thai Restaurant        [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
