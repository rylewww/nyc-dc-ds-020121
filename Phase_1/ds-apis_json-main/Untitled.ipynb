# %%
import requests
import json

# %%
import sys
print(sys.path)
# Out:
# ['/Users/ryanlewis/Documents/Flatiron_020121/nyc-dc-ds-020121/Phase_1/ds-apis_json-main', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python38.zip', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python3.8', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python3.8/lib-dynload', '', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages', '/Users/ryanlewis/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/extensions', '/Users/ryanlewis/.ipython']

# %%
url = 'https://api.yelp.com/v3/businesses/search'

# %%
api_key = "S3cROVIGs17gTiCO6iy8-2ycbL999zhz84ANxStc2mYNESu0cKfM4qdarKNZ69t-2bnTPSR_RRTTCTKmpQidQYhD1mpVN1zvyo0EGTVthI7SVumcOA3IZrRgj5omYHYx"

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %%
# what type of business do you want to search
term = 'Thai'

#where do you want to perform this search
location = 'NYC'

# what is your other parameter you want to search against
categories = 'restaurants'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50,
    
            }

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"businesses": [{"id": "9WgsvzaiXNAmmQGD0uQxFQ", "alias": "thai-holic-brooklyn", "name": "Thai Holic", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/iUqXan4GX7zWw8U7agjZBQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/thai-holic-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg", "review_count": 455, "categories": [{"alias": "thai", "title": "Thai"}, {"alias": "salad", "title": "Salad"}], "rating": 4.5, "coordinates": {"latitude": 40.693005, "longitude": -73.971286}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "372 Myrtle Ave", "address2": "", "address3": "", "city": "Brooklyn", "zip_code": "11205", "country": "US", "state": "NY", "display_address": ["372 Myrtle Ave", "Brooklyn, NY 11205"]}, "phone": "+17182229992", "display_phone": "(718) 222-9992", "distance": 2383.5456137420542}, {"id": "B3_K2kUVbYOU0VaLcj_LTw", "alias": "thai-villa-new-york-2", "name": "Thai Villa", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/oELHjgVFiisZdXpn91cd5A/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg", "review_count": 3544, "categories": [{"alias": "thai", "title": "Thai"}, {"alias": "asianfusion", "title": "Asian Fusion"}], "rating": 4.5, "coordinates": {"latitude": 40.73902, "longitude": -73.99065}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "5 E 19th St", "address2": "G Floor", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["5 E 19th St", "G Floor", "New York, NY 10003"]}, "phone": "+12128029999", "display_phone": "(212) 802-9999", "distance": 3744.570399827637}, {"id": "f_a1oO8-y2qorh_-K8xWHw", "alias": "thai-farm-kitchen-seaport-new-york", "name": "Thai Farm Kitchen Seaport", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/xRN_veYjK9TmF5B1rA7pQA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/thai-farm-kitchen-seaport-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg", "review_count": 67, "categories": [{"alias": "thai", "title": "Thai"}], "rating": 4.5, "coordinates": {"latitude": 40.70824, "longitude": -74.0017}, "transactions": ["delivery", "pickup", "restaurant_reservation"], "location": {"address1": "21 Peck Slip", "address2": "", "address3": null, "city": "New York", "zip_code": "10038", "country": "US", "state": "NY", "display_address": ["21 Peck Slip", "New York, NY 10038"]}, "phone": "+12123494433", "display_phone": "(212) 349-4433", "distance": 697.4169959225349}, {"id": "jjJc_CrkB2HodEinB6cWww", "alias": "lovemama-new-york", "name": "LoveMama", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/lovemama-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg", "review_count": 5189, "categories": [{"alias": "thai", "title": "Thai"}, {"alias": "malaysian", "title": "Malaysian"}, {"alias": "vietnamese", "title": "Vietnamese"}], "rating": 4.5, "coordinates": {"latitude": 40.730408722512074, "longitude": -73.98612673033213}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "174 2nd Ave", "address2": "", "address3": "", "city": "New York", "zip_code": "10003", "country": "US", "state": "NY", "display_address": ["174 2nd Ave", "New York, NY 10003"]}, "phone": "+12122545370", "display_phone": "(212) 254-5370", "distance": 2859.902795118878}, {"id": "-OixbLnFLCzQclxCSbUQ8w", "alias": "up-thai-new-york", "name": "Up Thai", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/i4TPZkTUWJn8aljC0UeU9Q/o.jpg", "is_cl ...

# %%
response.json()
# Out:
# {'businesses': [{'id': '9WgsvzaiXNAmmQGD0uQxFQ',
#    'alias': 'thai-holic-brooklyn',
#    'name': 'Thai Holic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iUqXan4GX7zWw8U7agjZBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-holic-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 455,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.693005, 'longitude': -73.971286},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '372 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['372 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17182229992',
#    'display_phone': '(718) 222-9992',
#    'distance': 2383.5456137420542},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'alias': 'thai-villa-new-york-2',
#    'name': 'Thai Villa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oELHjgVFiisZdXpn91cd5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 3544,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73902, 'longitude': -73.99065},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 E 19th St',
#     'address2': 'G Floor',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003']},
#    'phone': '+12128029999',
#    'display_phone': '(212) 802-9999',
#    'distance': 3744.570399827637},
#   {'id': 'f_a1oO8-y2qorh_-K8xWHw',
#    'alias': 'thai-farm-kitchen-seaport-new-york',
#    'name': 'Thai Farm Kitchen Seaport',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xRN_veYjK9TmF5B1rA7pQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-farm-kitchen-seaport-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 67,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70824, 'longitude': -74.0017},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'location': {'address1': '21 Peck Slip',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Peck Slip', 'New York, NY 10038']},
#    'phone': '+12123494433',
#    'display_phone': '(212) 349-4433',
#    'distance': 697.4169959225349},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 5189,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730408722512074,
#     'longitude': -73.98612673033213},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2859.902795118878},
#   {'id': '-OixbLnFLCzQclxCSbUQ8w',
#    'alias': 'up-thai-new-york',
#    'name': 'Up Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i4TPZkTUWJn8aljC0UeU9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/up-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2378,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7698275926665,
#     'longitude': -73.9576330868512},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1411 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1411 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12122561188',
#    'display_phone': '(212) 256-1188',
#    'distance': 7796.9126757590075},
#   {'id': 'wGFSTTB6b4MHJJUzBnVJeg',
#    'alias': 'top-thai-greenwich-new-york',
#    'name': 'Top Thai Greenwich',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4xK8iIj2rZrRvP9MMG7yOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-greenwich-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1536,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729771, 'longitude': -73.999392},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '235 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Sullivan St', 'New York, NY 10012']},
#    'phone': '+16467264418',
#    'display_phone': '(646) 726-4418',
#    'distance': 2739.489773141031},
#   {'id': 'feY7PgoRjCp2qReaIitRkQ',
#    'alias': 'boran-brooklyn-2',
#    'name': 'Boran',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DKm6I7QA_JNaEkwCUOgWyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boran-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 179,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6782327, 'longitude': -73.998062},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '462 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['462 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17184900207',
#    'display_phone': '(718) 490-0207',
#    'distance': 3042.489267250247},
#   {'id': '-XYp6w50XbZfS90YddS5ew',
#    'alias': 'soothr-new-york-2',
#    'name': 'Soothr',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Kg74WVsVfMB-2eG0I_QAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soothr-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 107,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.732318, 'longitude': -73.9873417},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '204 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 E 13th St', 'New York, NY 10003']},
#    'phone': '+12128449789',
#    'display_phone': '(212) 844-9789',
#    'distance': 3045.0417633367397},
#   {'id': 'qrydcGQpeDP_1oFvx3qOeg',
#    'alias': 'somtum-der-new-york',
#    'name': 'Somtum Der',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85AftnoxLOq0T0HKHPSdgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 753,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7252151982238,
#     'longitude': -73.9842741682317},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '85 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Ave A', 'New York, NY 10009']},
#    'phone': '+12122608570',
#    'display_phone': '(212) 260-8570',
#    'distance': 2354.956408341586},
#   {'id': 'MhceeLrM2_3mcKw5EGLY6A',
#    'alias': 'pure-thai-cookhouse-new-york',
#    'name': 'Pure Thai Cookhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QFYS-7MPGlOjUUy_2TkwLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-thai-cookhouse-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2566,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764291, 'longitude': -73.988159},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '766 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['766 9th Ave', 'New York, NY 10019']},
#    'phone': '+12125810999',
#    'display_phone': '(212) 581-0999',
#    'distance': 6563.765009094688},
#   {'id': 'l_gQf_4NgPMJcx2OkjsMfg',
#    'alias': 'noods-n-chill-brooklyn',
#    'name': 'Noods n’ Chill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aEbw8f72-M1la2L-ONR2pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noods-n-chill-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 76,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71194, 'longitude': -73.96121},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '170 S 3rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 S 3rd St', 'Brooklyn, NY 11211']},
#    'phone': '+17183887695',
#    'display_phone': '(718) 388-7695',
#    'distance': 2874.5347935406644},
#   {'id': 'XgiG7K7ubHsj2JJ-c2sXnw',
#    'alias': 'thai-diner-new-york',
#    'name': 'Thai Diner',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sABqmLTN1es_i4Ugu4DkpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-diner-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 110,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720714, 'longitude': -73.9956057},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '186 Mott St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Mott St', 'New York, NY 10012']},
#    'phone': '+16465594140',
#    'display_phone': '(646) 559-4140',
#    'distance': 1701.4484352726947},
#   {'id': 'O1fUmxt3kbV-rnyjBtzAfw',
#    'alias': 'thep-thai-restaurant-new-york-5',
#    'name': 'THEP Thai Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MKCdkV2v209he52ImIOSeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thep-thai-restaurant-new-york-5?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1337,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77078, 'longitude': -73.95727},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1439 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1439 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12128999995',
#    'display_phone': '(212) 899-9995',
#    'distance': 7904.787644740089},
#   {'id': 'liGIz8CzhyS1udx1aefjng',
#    'alias': 'williamsburg-thai-cuisine-brooklyn',
#    'name': 'Williamsburg Thai Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rb4WdnfScKrktF0O_ZWqqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/williamsburg-thai-cuisine-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 238,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71699, 'longitude': -73.9588799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '212 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19293377651',
#    'display_phone': '(929) 337-7651',
#    'distance': 3250.468442566167},
#   {'id': 'RrPIJvmje1qb9iaYd6jH0g',
#    'alias': 'pinto-restaurant-brooklyn-heights-2',
#    'name': 'Pinto Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QzRfSeXdqIx4y7Vbov9vHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinto-restaurant-brooklyn-heights-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 220,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6947735368336,
#     'longitude': -73.9943484261754},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '128 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn Heights',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Montague St', 'Brooklyn Heights, NY 11201']},
#    'phone': '+19293377732',
#    'display_phone': '(929) 337-7732',
#    'distance': 1186.6053037950712},
#   {'id': 'VoAuIReq_cPUrFwxbWqG_Q',
#    'alias': 'salathai-restaurant-new-york',
#    'name': 'SalaThai Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rY-GxvSeet0K4kPzB44gXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salathai-restaurant-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 399,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7801199, 'longitude': -73.98032},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '307 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 Amsterdam Ave', 'New York, NY 10023']},
#    'phone': '+12124333999',
#    'display_phone': '(212) 433-3999',
#    'distance': 8383.821131514791},
#   {'id': '0IFDnYf3bhqxJR6hVrG7Gw',
#    'alias': 'top-thai-55-carmine-new-york-2',
#    'name': 'Top Thai 55 - Carmine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-ZoEVVSfXiLLw8NLKSF9BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-55-carmine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 375,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729967, 'longitude': -74.004229},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '55 Carmine St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Carmine St', 'New York, NY 10014']},
#    'phone': '+16466092272',
#    'display_phone': '(646) 609-2272',
#    'distance': 2850.6467662416635},
#   {'id': '5ZjNZd3Yg0jOkJ9WRx1r6g',
#    'alias': 'kor-tor-mor-brooklyn',
#    'name': 'Kor Tor Mor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g8vp1MFooFU7-mUZbnjOAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kor-tor-mor-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 259,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6846634, 'longitude': -73.9918633},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '204 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17187975100',
#    'display_phone': '(718) 797-5100',
#    'distance': 2319.8537216888553},
#   {'id': '0L03onqNwxWLrbb_FCK79A',
#    'alias': 'sripraphai-thai-restaurant-woodside',
#    'name': 'SriPraPhai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2380,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '64-13 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17188999599',
#    'display_phone': '(718) 899-9599',
#    'distance': 9219.94935152076},
#   {'id': 'dqjko5ndMGayALuhwq3ghQ',
#    'alias': 'thailicious-new-york-3',
#    'name': 'Thailicious',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zu4TCkvWV-DdvvCR6Vxo6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thailicious-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 119,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71927, 'longitude': -73.98509},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '71 Clinton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Clinton St', 'New York, NY 10002']},
#    'phone': '+16468820343',
#    'display_phone': '(646) 882-0343',
#    'distance': 1715.2935292450331},
#   {'id': 'AkoNWXRhZWyJInoWI1AaZw',
#    'alias': 'pad-thai-kitchen-brooklyn',
#    'name': 'Pad Thai Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PXIRNktDhsZAxP0oppcYYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pad-thai-kitchen-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 40,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.620614, 'longitude': -73.989027},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '6218 18th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11204',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6218 18th Ave', 'Brooklyn, NY 11204']},
#    'phone': '+17184840156',
#    'display_phone': '(718) 484-0156',
#    'distance': 9442.140183514946},
#   {'id': 'WJS06XxRdc6DD1s4LWE9HA',
#    'alias': 'fish-cheeks-new-york',
#    'name': 'Fish Cheeks',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 718,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7258, 'longitude': -73.9927},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '55 Bond St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Bond St', 'New York, NY 10012']},
#    'phone': '+12126772223',
#    'display_phone': '(212) 677-2223',
#    'distance': 2258.7720584764224},
#   {'id': '0GftSP2dRwEzujkv2VKIgA',
#    'alias': 'wok-wok-southeast-asian-kitchen-new-york',
#    'name': 'Wok Wok Southeast Asian Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XOc7n_rq6kYGXySwasouRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wok-wok-southeast-asian-kitchen-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 993,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140555, 'longitude': -73.9988387116394},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '11 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Mott St', 'New York, NY 10013']},
#    'phone': '+19173883627',
#    'display_phone': '(917) 388-3627',
#    'distance': 1031.2690925773445},
#   {'id': 'p2sAfaFyfFj9nYPyqcmQdw',
#    'alias': 'thai-sidewalk-brooklyn-5',
#    'name': 'Thai Sidewalk',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8VY5opp0KuYAekshjrEl1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-sidewalk-brooklyn-5?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 39,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7024794, 'longitude': -73.9885649},
#    'transactions': [],
#    'location': {'address1': 'Adams St And Front St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Adams St And Front St', 'Brooklyn, NY 11201']},
#    'phone': '+16466418333',
#    'display_phone': '(646) 641-8333',
#    'distance': 583.9836845783237},
#   {'id': 'No1PU4NbOdoaG1lSikfeNg',
#    'alias': '7-elephants-new-york',
#    'name': '7 Elephants',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RylEgFXmusdxb6sLLrxvBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/7-elephants-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 10,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714099, 'longitude': -73.986987},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '221 East Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 East Broadway', 'New York, NY 10002']},
#    'phone': '+16467527940',
#    'display_phone': '(646) 752-7940',
#    'distance': 1142.856596202019},
#   {'id': 'xRvMOTMzDrMfyAWbYhkA8A',
#    'alias': 'terra-thai-new-york',
#    'name': 'Terra Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fQoIcwFwbbUOwx0VT-GS3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terra-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 29,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.724896, 'longitude': -73.983031},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '518 E 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['518 E 6th St', 'New York, NY 10009']},
#    'phone': '+16464787415',
#    'display_phone': '(646) 478-7415',
#    'distance': 2361.9100123091093},
#   {'id': 'mpD_kUFo8POQDLoLgRSfCg',
#    'alias': 'sage-brooklyn',
#    'name': 'SAGE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8_3u0uJLvInOMgqwuUN8YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sage-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 607,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7129736, 'longitude': -73.9442765},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '299-301 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['299-301 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17182186644',
#    'display_phone': '(718) 218-6644',
#    'distance': 4298.170607587344},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'alias': 'wayla-new-york',
#    'name': 'Wayla',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Se9IRHfGW8z9-292HJyKsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wayla-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 298,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7183, 'longitude': -73.9926038},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Forsyth St',
#     'address2': 'Basement',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Forsyth St', 'Basement', 'New York, NY 10002']},
#    'phone': '+12122062500',
#    'display_phone': '(212) 206-2500',
#    'distance': 1436.4990587768912},
#   {'id': 'UC3n_0vZ5zI1fvi7UzNZAg',
#    'alias': 'sabai-thai-restaurant-new-york-3',
#    'name': 'Sabai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n7zcZ-9Z_m1zWtQO50y9Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabai-thai-restaurant-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 290,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74422, 'longitude': -73.98365},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '432 Park Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['432 Park Ave S', 'New York, NY 10016']},
#    'phone': '+16464764521',
#    'display_phone': '(646) 476-4521',
#    'distance': 4412.21786588836},
#   {'id': 'StFf9fVnAlhwrUWan0C4Ww',
#    'alias': 'wanisa-home-kitchen-brooklyn',
#    'name': 'Wanisa Home Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/azd794dZJoROs5zyEizhrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wanisa-home-kitchen-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 145,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.687, 'longitude': -73.99042},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '142 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17185223027',
#    'display_phone': '(718) 522-3027',
#    'distance': 2074.755884968529},
#   {'id': '1sEr-BDi2LD6HH6K960pfQ',
#    'alias': 'ace-thai-kitchen-brooklyn-3',
#    'name': 'ACE Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DDDufVScz4Ae3wjz_i0e1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ace-thai-kitchen-brooklyn-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 101,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69315, 'longitude': -73.97328},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '330 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13479874100',
#    'display_phone': '(347) 987-4100',
#    'distance': 2240.064612841999},
#   {'id': 'hSiTqxKKgvQSI5x5VdMjoQ',
#    'alias': 'top-thai-brooklyn-brooklyn',
#    'name': 'Top Thai - Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XDqz5GxZC5X-msp2l4Cx3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-brooklyn-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 310,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.62325, 'longitude': -74.02838},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8510 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8510 4th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17183335811',
#    'display_phone': '(718) 333-5811',
#    'distance': 9578.460130007345},
#   {'id': 'I4FWrwXDC91lsfQLXYSeXA',
#    'alias': 'malii-new-york',
#    'name': 'Malii',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eHpMGVExY1ed_MMasrSJ_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malii-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 283,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.789432, 'longitude': -73.942962},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2028 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2028 2nd Ave', 'New York, NY 10029']},
#    'phone': '+12122892729',
#    'display_phone': '(212) 289-2729',
#    'distance': 10291.839523057411},
#   {'id': 'pSSajdYNKTyAGV8-fk7fWQ',
#    'alias': 'joya-brooklyn',
#    'name': 'Joya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X4HbR16EFVcywHtrW7BPqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joya-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1321,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.686672, 'longitude': -73.993544},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '215 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17182223484',
#    'display_phone': '(718) 222-3484',
#    'distance': 2087.041238313192},
#   {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#    'alias': 'pye-boat-noodle-astoria',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 837,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17186852329',
#    'display_phone': '(718) 685-2329',
#    'distance': 8656.427099874069},
#   {'id': 'tx-gxkns4uFyve7Eu5mYKA',
#    'alias': 'tana-thai-bronx',
#    'name': 'Tana Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FWqfkWekjDyGFV-xn4qcHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tana-thai-bronx?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 198,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8513635, 'longitude': -73.8439993},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1890 Eastchester Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10461',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1890 Eastchester Rd', 'Bronx, NY 10461']},
#    'phone': '+17186841900',
#    'display_phone': '(718) 684-1900',
#    'distance': 20591.422965460595},
#   {'id': 'IdHZfmpp8MmQ4_KZL2qXbg',
#    'alias': 'makiinny-new-york-3',
#    'name': 'MAKIINNY',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k49zoEEai5yB9_D_0tnaSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/makiinny-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 59,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72831, 'longitude': -73.98914},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '32 E7th St',
#     'address2': 'Front 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 E7th St', 'Front 2', 'New York, NY 10003']},
#    'phone': '+12126734610',
#    'display_phone': '(212) 673-4610',
#    'distance': 2566.784676576643},
#   {'id': 'p2zm0HnXZkI2yCAuYLb45g',
#    'alias': 'thai-market-new-york',
#    'name': 'Thai Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jPGJaYsRiU_se_UJzphxkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-market-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1014,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80132, 'longitude': -73.96529},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '960 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['960 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12122804575',
#    'display_phone': '(212) 280-4575',
#    'distance': 10940.010065176182},
#   {'id': 'RdGWCbcxA79G1ZMPVL3SGQ',
#    'alias': 'nora-thai-brooklyn-4',
#    'name': 'Nora Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pKgSo4nNsd0-FiRAvahoXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nora-thai-brooklyn-4?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 82,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71864, 'longitude': -73.95625},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '176 N 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 N 9th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183021499',
#    'display_phone': '(718) 302-1499',
#    'distance': 3511.550118914059},
#   {'id': 'SBy46BviyBKowPjbTjDsHQ',
#    'alias': 'lantern-brooklyn',
#    'name': 'Lantern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YwkmxTrk3iZOELiCLfwecA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lantern-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 466,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.69533, 'longitude': -73.99544},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '101 Montague St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+17182372594',
#    'display_phone': '(718) 237-2594',
#    'distance': 1132.8854453675879},
#   {'id': '83BXSwE0166sObnXLUE4bQ',
#    'alias': 'land-new-york',
#    'name': 'Land',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ptDV_QtdeLeSvBZs-tTqWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/land-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1060,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78497, 'longitude': -73.9772182},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '450 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12125018121',
#    'display_phone': '(212) 501-8121',
#    'distance': 8959.014790043642},
#   {'id': 'dVR5KHPMZoU9rQvxhY5Otw',
#    'alias': 'thai-terminal-new-york-2',
#    'name': 'Thai Terminal',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pYpcqmmsmWS_wX2qOUEzVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-terminal-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 570,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73039, 'longitude': -73.98381},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '349 E 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['349 E 12th St', 'New York, NY 10003']},
#    'phone': '+12126140155',
#    'display_phone': '(212) 614-0155',
#    'distance': 2909.1995849569603},
#   {'id': 'Nvhx093-K2xwHIZVnFstJw',
#    'alias': 'copper-throat-thai-cuisine-new-york',
#    'name': 'Copper Throat Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kU4KGhCSqEKP43D20XoZuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copper-throat-thai-cuisine-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 117,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71978, 'longitude': -73.98877},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '123 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19172617891',
#    'display_phone': '(917) 261-7891',
#    'distance': 1664.2227246686566},
#   {'id': 'NN3mOWF5e_pnR1ArqM2bHQ',
#    'alias': 'obao-new-york-3',
#    'name': 'OBAO',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CpVI2XJLrvg09Fm83bfPog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obao-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2637,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7606544, 'longitude': -73.991332},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '647 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['647 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122458880',
#    'display_phone': '(212) 245-8880',
#    'distance': 6144.081737145313},
#   {'id': 'TUoya6mwmxr0Zpr8oZSXlg',
#    'alias': 'thip-osha-brooklyn-2',
#    'name': 'Thip Osha',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AexQnAuV99JTkUsoe7edng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thip-osha-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 81,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712123, 'longitude': -73.941437},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '795 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['795 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183887787',
#    'display_phone': '(718) 388-7787',
#    'distance': 4514.165073687724},
#   {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#    'alias': 'kind-fresh-meadows',
#    'name': "Kin'd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 767,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '192-03 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184680888',
#    'display_phone': '(718) 468-0888',
#    'distance': 18401.011784437622},
#   {'id': 'UO4kyXfdQIlAhM-TRgM9cw',
#    'alias': 'look-by-plant-love-house-brooklyn-2',
#    'name': 'Look By Plant Love House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mvx6ONrNJHgVhnqHxsxo6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/look-by-plant-love-house-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 328,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.679893, 'longitude': -73.964447},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '622 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['622 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186220026',
#    'display_phone': '(718) 622-0026',
#    'distance': 3798.9064789978547},
#   {'id': 'jfnDwWBGK4JoWE5jbeKxSw',
#    'alias': 'chu-ros-thai-new-york',
#    'name': 'Chu-Ros Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qf6j86VG_Fq8xP8N37Ep0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chu-ros-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78922, 'longitude': -73.94873},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1590 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1590 Lexington Ave', 'New York, NY 10029']},
#    'phone': '+19172658432',
#    'display_phone': '(917) 265-8432',
#    'distance': 10082.249947035149},
#   {'id': 'rKeLuHDI3PQZsPSVCEMHtw',
#    'alias': 'wondee-siam-new-york-3',
#    'name': 'Wondee Siam',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8S7WgzeqeS0Y-Hy1yESx_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wondee-siam-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1027,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76495, 'longitude': -73.98747},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '792 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['792 9th Ave', 'New York, NY 10019']},
#    'phone': '+12124599057',
#    'display_phone': '(212) 459-9057',
#    'distance': 6639.674884696999},
#   {'id': '2AcDHuatOFXhqJDedZwGiA',
#    'alias': 'tung-thong-thai-restaurant-new-york',
#    'name': 'Tung Thong Thai Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hpS331DER9USvfRI2-WpSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tung-thong-thai-restaurant-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 297,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8414062274416,
#     'longitude': -73.9386532729438},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '561 W 169th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['561 W 169th St', 'New York, NY 10032']},
#    'phone': '+12127955995',
#    'display_phone': '(212) 795-5995',
#    'distance': 15827.569013841035}],
#  'total': 2600,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
data = response.json()

# %%
data
# Out:
# {'businesses': [{'id': '9WgsvzaiXNAmmQGD0uQxFQ',
#    'alias': 'thai-holic-brooklyn',
#    'name': 'Thai Holic',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iUqXan4GX7zWw8U7agjZBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-holic-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 455,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.693005, 'longitude': -73.971286},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '372 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['372 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17182229992',
#    'display_phone': '(718) 222-9992',
#    'distance': 2383.5456137420542},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'alias': 'thai-villa-new-york-2',
#    'name': 'Thai Villa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oELHjgVFiisZdXpn91cd5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 3544,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73902, 'longitude': -73.99065},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5 E 19th St',
#     'address2': 'G Floor',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003']},
#    'phone': '+12128029999',
#    'display_phone': '(212) 802-9999',
#    'distance': 3744.570399827637},
#   {'id': 'f_a1oO8-y2qorh_-K8xWHw',
#    'alias': 'thai-farm-kitchen-seaport-new-york',
#    'name': 'Thai Farm Kitchen Seaport',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xRN_veYjK9TmF5B1rA7pQA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-farm-kitchen-seaport-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 67,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70824, 'longitude': -74.0017},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'location': {'address1': '21 Peck Slip',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['21 Peck Slip', 'New York, NY 10038']},
#    'phone': '+12123494433',
#    'display_phone': '(212) 349-4433',
#    'distance': 697.4169959225349},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 5189,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730408722512074,
#     'longitude': -73.98612673033213},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2859.902795118878},
#   {'id': '-OixbLnFLCzQclxCSbUQ8w',
#    'alias': 'up-thai-new-york',
#    'name': 'Up Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i4TPZkTUWJn8aljC0UeU9Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/up-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2378,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7698275926665,
#     'longitude': -73.9576330868512},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1411 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1411 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12122561188',
#    'display_phone': '(212) 256-1188',
#    'distance': 7796.9126757590075},
#   {'id': 'wGFSTTB6b4MHJJUzBnVJeg',
#    'alias': 'top-thai-greenwich-new-york',
#    'name': 'Top Thai Greenwich',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4xK8iIj2rZrRvP9MMG7yOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-greenwich-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1536,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729771, 'longitude': -73.999392},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '235 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Sullivan St', 'New York, NY 10012']},
#    'phone': '+16467264418',
#    'display_phone': '(646) 726-4418',
#    'distance': 2739.489773141031},
#   {'id': 'feY7PgoRjCp2qReaIitRkQ',
#    'alias': 'boran-brooklyn-2',
#    'name': 'Boran',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DKm6I7QA_JNaEkwCUOgWyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boran-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 179,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6782327, 'longitude': -73.998062},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '462 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['462 Court St', 'Brooklyn, NY 11231']},
#    'phone': '+17184900207',
#    'display_phone': '(718) 490-0207',
#    'distance': 3042.489267250247},
#   {'id': '-XYp6w50XbZfS90YddS5ew',
#    'alias': 'soothr-new-york-2',
#    'name': 'Soothr',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Kg74WVsVfMB-2eG0I_QAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soothr-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 107,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.732318, 'longitude': -73.9873417},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '204 E 13th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 E 13th St', 'New York, NY 10003']},
#    'phone': '+12128449789',
#    'display_phone': '(212) 844-9789',
#    'distance': 3045.0417633367397},
#   {'id': 'qrydcGQpeDP_1oFvx3qOeg',
#    'alias': 'somtum-der-new-york',
#    'name': 'Somtum Der',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85AftnoxLOq0T0HKHPSdgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 753,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7252151982238,
#     'longitude': -73.9842741682317},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '85 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Ave A', 'New York, NY 10009']},
#    'phone': '+12122608570',
#    'display_phone': '(212) 260-8570',
#    'distance': 2354.956408341586},
#   {'id': 'MhceeLrM2_3mcKw5EGLY6A',
#    'alias': 'pure-thai-cookhouse-new-york',
#    'name': 'Pure Thai Cookhouse',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/QFYS-7MPGlOjUUy_2TkwLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pure-thai-cookhouse-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2566,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.764291, 'longitude': -73.988159},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '766 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['766 9th Ave', 'New York, NY 10019']},
#    'phone': '+12125810999',
#    'display_phone': '(212) 581-0999',
#    'distance': 6563.765009094688},
#   {'id': 'l_gQf_4NgPMJcx2OkjsMfg',
#    'alias': 'noods-n-chill-brooklyn',
#    'name': 'Noods n’ Chill',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aEbw8f72-M1la2L-ONR2pg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/noods-n-chill-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 76,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71194, 'longitude': -73.96121},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '170 S 3rd St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['170 S 3rd St', 'Brooklyn, NY 11211']},
#    'phone': '+17183887695',
#    'display_phone': '(718) 388-7695',
#    'distance': 2874.5347935406644},
#   {'id': 'XgiG7K7ubHsj2JJ-c2sXnw',
#    'alias': 'thai-diner-new-york',
#    'name': 'Thai Diner',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sABqmLTN1es_i4Ugu4DkpQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-diner-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 110,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720714, 'longitude': -73.9956057},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '186 Mott St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['186 Mott St', 'New York, NY 10012']},
#    'phone': '+16465594140',
#    'display_phone': '(646) 559-4140',
#    'distance': 1701.4484352726947},
#   {'id': 'O1fUmxt3kbV-rnyjBtzAfw',
#    'alias': 'thep-thai-restaurant-new-york-5',
#    'name': 'THEP Thai Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MKCdkV2v209he52ImIOSeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thep-thai-restaurant-new-york-5?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1337,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77078, 'longitude': -73.95727},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1439 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1439 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12128999995',
#    'display_phone': '(212) 899-9995',
#    'distance': 7904.787644740089},
#   {'id': 'liGIz8CzhyS1udx1aefjng',
#    'alias': 'williamsburg-thai-cuisine-brooklyn',
#    'name': 'Williamsburg Thai Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Rb4WdnfScKrktF0O_ZWqqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/williamsburg-thai-cuisine-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 238,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71699, 'longitude': -73.9588799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '212 Bedford Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['212 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+19293377651',
#    'display_phone': '(929) 337-7651',
#    'distance': 3250.468442566167},
#   {'id': 'RrPIJvmje1qb9iaYd6jH0g',
#    'alias': 'pinto-restaurant-brooklyn-heights-2',
#    'name': 'Pinto Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QzRfSeXdqIx4y7Vbov9vHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pinto-restaurant-brooklyn-heights-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 220,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6947735368336,
#     'longitude': -73.9943484261754},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '128 Montague St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn Heights',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['128 Montague St', 'Brooklyn Heights, NY 11201']},
#    'phone': '+19293377732',
#    'display_phone': '(929) 337-7732',
#    'distance': 1186.6053037950712},
#   {'id': 'VoAuIReq_cPUrFwxbWqG_Q',
#    'alias': 'salathai-restaurant-new-york',
#    'name': 'SalaThai Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rY-GxvSeet0K4kPzB44gXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salathai-restaurant-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 399,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7801199, 'longitude': -73.98032},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '307 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['307 Amsterdam Ave', 'New York, NY 10023']},
#    'phone': '+12124333999',
#    'display_phone': '(212) 433-3999',
#    'distance': 8383.821131514791},
#   {'id': '0IFDnYf3bhqxJR6hVrG7Gw',
#    'alias': 'top-thai-55-carmine-new-york-2',
#    'name': 'Top Thai 55 - Carmine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-ZoEVVSfXiLLw8NLKSF9BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-55-carmine-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 375,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'halal', 'title': 'Halal'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729967, 'longitude': -74.004229},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '55 Carmine St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Carmine St', 'New York, NY 10014']},
#    'phone': '+16466092272',
#    'display_phone': '(646) 609-2272',
#    'distance': 2850.6467662416635},
#   {'id': '5ZjNZd3Yg0jOkJ9WRx1r6g',
#    'alias': 'kor-tor-mor-brooklyn',
#    'name': 'Kor Tor Mor',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/g8vp1MFooFU7-mUZbnjOAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kor-tor-mor-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 259,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6846634, 'longitude': -73.9918633},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '204 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['204 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17187975100',
#    'display_phone': '(718) 797-5100',
#    'distance': 2319.8537216888553},
#   {'id': '0L03onqNwxWLrbb_FCK79A',
#    'alias': 'sripraphai-thai-restaurant-woodside',
#    'name': 'SriPraPhai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2380,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '64-13 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17188999599',
#    'display_phone': '(718) 899-9599',
#    'distance': 9219.94935152076},
#   {'id': 'dqjko5ndMGayALuhwq3ghQ',
#    'alias': 'thailicious-new-york-3',
#    'name': 'Thailicious',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zu4TCkvWV-DdvvCR6Vxo6A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thailicious-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 119,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71927, 'longitude': -73.98509},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '71 Clinton St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71 Clinton St', 'New York, NY 10002']},
#    'phone': '+16468820343',
#    'display_phone': '(646) 882-0343',
#    'distance': 1715.2935292450331},
#   {'id': 'AkoNWXRhZWyJInoWI1AaZw',
#    'alias': 'pad-thai-kitchen-brooklyn',
#    'name': 'Pad Thai Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PXIRNktDhsZAxP0oppcYYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pad-thai-kitchen-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 40,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.620614, 'longitude': -73.989027},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '6218 18th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11204',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6218 18th Ave', 'Brooklyn, NY 11204']},
#    'phone': '+17184840156',
#    'display_phone': '(718) 484-0156',
#    'distance': 9442.140183514946},
#   {'id': 'WJS06XxRdc6DD1s4LWE9HA',
#    'alias': 'fish-cheeks-new-york',
#    'name': 'Fish Cheeks',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pqupe3fe52869QQ23KkiBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fish-cheeks-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 718,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'raw_food', 'title': 'Live/Raw Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7258, 'longitude': -73.9927},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '55 Bond St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['55 Bond St', 'New York, NY 10012']},
#    'phone': '+12126772223',
#    'display_phone': '(212) 677-2223',
#    'distance': 2258.7720584764224},
#   {'id': '0GftSP2dRwEzujkv2VKIgA',
#    'alias': 'wok-wok-southeast-asian-kitchen-new-york',
#    'name': 'Wok Wok Southeast Asian Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XOc7n_rq6kYGXySwasouRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wok-wok-southeast-asian-kitchen-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 993,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140555, 'longitude': -73.9988387116394},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '11 Mott St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['11 Mott St', 'New York, NY 10013']},
#    'phone': '+19173883627',
#    'display_phone': '(917) 388-3627',
#    'distance': 1031.2690925773445},
#   {'id': 'p2sAfaFyfFj9nYPyqcmQdw',
#    'alias': 'thai-sidewalk-brooklyn-5',
#    'name': 'Thai Sidewalk',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8VY5opp0KuYAekshjrEl1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-sidewalk-brooklyn-5?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 39,
#    'categories': [{'alias': 'streetvendors', 'title': 'Street Vendors'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7024794, 'longitude': -73.9885649},
#    'transactions': [],
#    'location': {'address1': 'Adams St And Front St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['Adams St And Front St', 'Brooklyn, NY 11201']},
#    'phone': '+16466418333',
#    'display_phone': '(646) 641-8333',
#    'distance': 583.9836845783237},
#   {'id': 'No1PU4NbOdoaG1lSikfeNg',
#    'alias': '7-elephants-new-york',
#    'name': '7 Elephants',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RylEgFXmusdxb6sLLrxvBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/7-elephants-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 10,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.714099, 'longitude': -73.986987},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '221 East Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['221 East Broadway', 'New York, NY 10002']},
#    'phone': '+16467527940',
#    'display_phone': '(646) 752-7940',
#    'distance': 1142.856596202019},
#   {'id': 'xRvMOTMzDrMfyAWbYhkA8A',
#    'alias': 'terra-thai-new-york',
#    'name': 'Terra Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fQoIcwFwbbUOwx0VT-GS3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/terra-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 29,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.724896, 'longitude': -73.983031},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '518 E 6th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['518 E 6th St', 'New York, NY 10009']},
#    'phone': '+16464787415',
#    'display_phone': '(646) 478-7415',
#    'distance': 2361.9100123091093},
#   {'id': 'mpD_kUFo8POQDLoLgRSfCg',
#    'alias': 'sage-brooklyn',
#    'name': 'SAGE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8_3u0uJLvInOMgqwuUN8YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sage-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 607,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7129736, 'longitude': -73.9442765},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '299-301 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['299-301 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17182186644',
#    'display_phone': '(718) 218-6644',
#    'distance': 4298.170607587344},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'alias': 'wayla-new-york',
#    'name': 'Wayla',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Se9IRHfGW8z9-292HJyKsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wayla-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 298,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7183, 'longitude': -73.9926038},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '100 Forsyth St',
#     'address2': 'Basement',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['100 Forsyth St', 'Basement', 'New York, NY 10002']},
#    'phone': '+12122062500',
#    'display_phone': '(212) 206-2500',
#    'distance': 1436.4990587768912},
#   {'id': 'UC3n_0vZ5zI1fvi7UzNZAg',
#    'alias': 'sabai-thai-restaurant-new-york-3',
#    'name': 'Sabai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n7zcZ-9Z_m1zWtQO50y9Iw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sabai-thai-restaurant-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 290,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74422, 'longitude': -73.98365},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '432 Park Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['432 Park Ave S', 'New York, NY 10016']},
#    'phone': '+16464764521',
#    'display_phone': '(646) 476-4521',
#    'distance': 4412.21786588836},
#   {'id': 'StFf9fVnAlhwrUWan0C4Ww',
#    'alias': 'wanisa-home-kitchen-brooklyn',
#    'name': 'Wanisa Home Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/azd794dZJoROs5zyEizhrA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wanisa-home-kitchen-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 145,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.687, 'longitude': -73.99042},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '142 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17185223027',
#    'display_phone': '(718) 522-3027',
#    'distance': 2074.755884968529},
#   {'id': '1sEr-BDi2LD6HH6K960pfQ',
#    'alias': 'ace-thai-kitchen-brooklyn-3',
#    'name': 'ACE Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DDDufVScz4Ae3wjz_i0e1g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ace-thai-kitchen-brooklyn-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 101,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69315, 'longitude': -73.97328},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '330 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+13479874100',
#    'display_phone': '(347) 987-4100',
#    'distance': 2240.064612841999},
#   {'id': 'hSiTqxKKgvQSI5x5VdMjoQ',
#    'alias': 'top-thai-brooklyn-brooklyn',
#    'name': 'Top Thai - Brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XDqz5GxZC5X-msp2l4Cx3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-brooklyn-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 310,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.62325, 'longitude': -74.02838},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8510 4th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8510 4th Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17183335811',
#    'display_phone': '(718) 333-5811',
#    'distance': 9578.460130007345},
#   {'id': 'I4FWrwXDC91lsfQLXYSeXA',
#    'alias': 'malii-new-york',
#    'name': 'Malii',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eHpMGVExY1ed_MMasrSJ_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/malii-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 283,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.789432, 'longitude': -73.942962},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2028 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2028 2nd Ave', 'New York, NY 10029']},
#    'phone': '+12122892729',
#    'display_phone': '(212) 289-2729',
#    'distance': 10291.839523057411},
#   {'id': 'pSSajdYNKTyAGV8-fk7fWQ',
#    'alias': 'joya-brooklyn',
#    'name': 'Joya',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X4HbR16EFVcywHtrW7BPqQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joya-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1321,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.686672, 'longitude': -73.993544},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '215 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 Court St', 'Brooklyn, NY 11201']},
#    'phone': '+17182223484',
#    'display_phone': '(718) 222-3484',
#    'distance': 2087.041238313192},
#   {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#    'alias': 'pye-boat-noodle-astoria',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 837,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17186852329',
#    'display_phone': '(718) 685-2329',
#    'distance': 8656.427099874069},
#   {'id': 'tx-gxkns4uFyve7Eu5mYKA',
#    'alias': 'tana-thai-bronx',
#    'name': 'Tana Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FWqfkWekjDyGFV-xn4qcHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tana-thai-bronx?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 198,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.8513635, 'longitude': -73.8439993},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1890 Eastchester Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10461',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1890 Eastchester Rd', 'Bronx, NY 10461']},
#    'phone': '+17186841900',
#    'display_phone': '(718) 684-1900',
#    'distance': 20591.422965460595},
#   {'id': 'IdHZfmpp8MmQ4_KZL2qXbg',
#    'alias': 'makiinny-new-york-3',
#    'name': 'MAKIINNY',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k49zoEEai5yB9_D_0tnaSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/makiinny-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 59,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72831, 'longitude': -73.98914},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '32 E7th St',
#     'address2': 'Front 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 E7th St', 'Front 2', 'New York, NY 10003']},
#    'phone': '+12126734610',
#    'display_phone': '(212) 673-4610',
#    'distance': 2566.784676576643},
#   {'id': 'p2zm0HnXZkI2yCAuYLb45g',
#    'alias': 'thai-market-new-york',
#    'name': 'Thai Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jPGJaYsRiU_se_UJzphxkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-market-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1014,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80132, 'longitude': -73.96529},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '960 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['960 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+12122804575',
#    'display_phone': '(212) 280-4575',
#    'distance': 10940.010065176182},
#   {'id': 'RdGWCbcxA79G1ZMPVL3SGQ',
#    'alias': 'nora-thai-brooklyn-4',
#    'name': 'Nora Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pKgSo4nNsd0-FiRAvahoXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nora-thai-brooklyn-4?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 82,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71864, 'longitude': -73.95625},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '176 N 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['176 N 9th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183021499',
#    'display_phone': '(718) 302-1499',
#    'distance': 3511.550118914059},
#   {'id': 'SBy46BviyBKowPjbTjDsHQ',
#    'alias': 'lantern-brooklyn',
#    'name': 'Lantern',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YwkmxTrk3iZOELiCLfwecA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lantern-brooklyn?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 466,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.69533, 'longitude': -73.99544},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '101 Montague St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Montague St', 'Brooklyn, NY 11201']},
#    'phone': '+17182372594',
#    'display_phone': '(718) 237-2594',
#    'distance': 1132.8854453675879},
#   {'id': '83BXSwE0166sObnXLUE4bQ',
#    'alias': 'land-new-york',
#    'name': 'Land',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ptDV_QtdeLeSvBZs-tTqWA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/land-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1060,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78497, 'longitude': -73.9772182},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '450 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12125018121',
#    'display_phone': '(212) 501-8121',
#    'distance': 8959.014790043642},
#   {'id': 'dVR5KHPMZoU9rQvxhY5Otw',
#    'alias': 'thai-terminal-new-york-2',
#    'name': 'Thai Terminal',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pYpcqmmsmWS_wX2qOUEzVA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-terminal-new-york-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 570,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73039, 'longitude': -73.98381},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '349 E 12th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['349 E 12th St', 'New York, NY 10003']},
#    'phone': '+12126140155',
#    'display_phone': '(212) 614-0155',
#    'distance': 2909.1995849569603},
#   {'id': 'Nvhx093-K2xwHIZVnFstJw',
#    'alias': 'copper-throat-thai-cuisine-new-york',
#    'name': 'Copper Throat Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kU4KGhCSqEKP43D20XoZuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/copper-throat-thai-cuisine-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 117,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71978, 'longitude': -73.98877},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '123 Ludlow St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19172617891',
#    'display_phone': '(917) 261-7891',
#    'distance': 1664.2227246686566},
#   {'id': 'NN3mOWF5e_pnR1ArqM2bHQ',
#    'alias': 'obao-new-york-3',
#    'name': 'OBAO',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CpVI2XJLrvg09Fm83bfPog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/obao-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 2637,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7606544, 'longitude': -73.991332},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '647 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['647 9th Ave', 'New York, NY 10036']},
#    'phone': '+12122458880',
#    'display_phone': '(212) 245-8880',
#    'distance': 6144.081737145313},
#   {'id': 'TUoya6mwmxr0Zpr8oZSXlg',
#    'alias': 'thip-osha-brooklyn-2',
#    'name': 'Thip Osha',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AexQnAuV99JTkUsoe7edng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thip-osha-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 81,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712123, 'longitude': -73.941437},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '795 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['795 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183887787',
#    'display_phone': '(718) 388-7787',
#    'distance': 4514.165073687724},
#   {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#    'alias': 'kind-fresh-meadows',
#    'name': "Kin'd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 767,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '192-03 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184680888',
#    'display_phone': '(718) 468-0888',
#    'distance': 18401.011784437622},
#   {'id': 'UO4kyXfdQIlAhM-TRgM9cw',
#    'alias': 'look-by-plant-love-house-brooklyn-2',
#    'name': 'Look By Plant Love House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Mvx6ONrNJHgVhnqHxsxo6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/look-by-plant-love-house-brooklyn-2?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 328,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.679893, 'longitude': -73.964447},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '622 Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['622 Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186220026',
#    'display_phone': '(718) 622-0026',
#    'distance': 3798.9064789978547},
#   {'id': 'jfnDwWBGK4JoWE5jbeKxSw',
#    'alias': 'chu-ros-thai-new-york',
#    'name': 'Chu-Ros Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qf6j86VG_Fq8xP8N37Ep0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chu-ros-thai-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78922, 'longitude': -73.94873},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '1590 Lexington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1590 Lexington Ave', 'New York, NY 10029']},
#    'phone': '+19172658432',
#    'display_phone': '(917) 265-8432',
#    'distance': 10082.249947035149},
#   {'id': 'rKeLuHDI3PQZsPSVCEMHtw',
#    'alias': 'wondee-siam-new-york-3',
#    'name': 'Wondee Siam',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8S7WgzeqeS0Y-Hy1yESx_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wondee-siam-new-york-3?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 1027,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76495, 'longitude': -73.98747},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '792 9th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['792 9th Ave', 'New York, NY 10019']},
#    'phone': '+12124599057',
#    'display_phone': '(212) 459-9057',
#    'distance': 6639.674884696999},
#   {'id': '2AcDHuatOFXhqJDedZwGiA',
#    'alias': 'tung-thong-thai-restaurant-new-york',
#    'name': 'Tung Thong Thai Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hpS331DER9USvfRI2-WpSw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tung-thong-thai-restaurant-new-york?adjust_creative=YYinute8YoprX7XHYr6zhg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=YYinute8YoprX7XHYr6zhg',
#    'review_count': 297,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.8414062274416,
#     'longitude': -73.9386532729438},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '561 W 169th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10032',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['561 W 169th St', 'New York, NY 10032']},
#    'phone': '+12127955995',
#    'display_phone': '(212) 795-5995',
#    'distance': 15827.569013841035}],
#  'total': 2600,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])
